# %% [markdown]
# # 使用function：

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0428~0504 def版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

def crawltheweb_0428_0504():
    urlretrieve = "http://localhost/weekly_0428~0504.html"#每周排名
    data = requests.get(urlretrieve)
    data.encoding = 'utf-8'
    soup = BeautifulSoup(data.text,"lxml")#提取內容

    ####################取得所有標題####################
    weekly_title = []
    weekly_title_str = soup.select(".blog-item.ranking h4.title a")
    for i in range(len(weekly_title_str)):
        weekly_title.append(weekly_title_str[i].string)

    ####################取得各項餐廳名稱、評級####################
    weekly_restaurant = []
    weekly_rating = []
    weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
    weekly_rating_str = soup.select(".restaurant.item .rating")
    for i in range(len(weekly_restaurant_str)//2):
        restaurant = weekly_restaurant_str[i*2].text#這有40格，取一半
        rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else weekly_rating_str[i*2].text#這有40格，取一半
        weekly_restaurant.append(restaurant)
        weekly_rating.append(rating)
        
    ####################取得各項美食所在區域、產生日期####################
    weekly_district = []
    weekly_date = []
    weekly_date_str = soup.select("h5, .h5")
    for i in range(len(weekly_date_str)):
        date_DD_str = weekly_date_str[i].text.split(" ")
        district = date_DD_str[4].replace("(","").replace(")","") if(i==3)else date_DD_str[4].replace("(","").replace(")","") if(i==14)else date_DD_str[4].replace("(","").replace(")","") if(i==18)else date_DD_str[3].replace("(","").replace(")","")
        date = date_DD_str[2].replace("。","") if(i==3)else date_DD_str[2].replace("。","") if(i==14)else date_DD_str[2].replace("。","") if(i==18)else date_DD_str[1].replace("。","")
        weekly_district.append(district)
        weekly_date.append(date)

    ####################取得各項觀看、收藏、推薦次數####################
    weekly_watch = []
    weekly_collection = []
    weekly_recommend = []
    weekly_WCR_str = soup.select(".blog-item .stat-box")
    for i in range(len(weekly_WCR_str)):
        WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
        weekly_watch.append(WCR[2])
        weekly_collection.append(WCR[4])
        weekly_recommend.append(WCR[6])

    ####################取得各項來過人數、食記篇數####################
    weekly_visit = []
    weekly_foodrecord = []
    weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
    for i in range(len(weekly_VF_str)):
        visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0]
        foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1]
        weekly_visit.append(visit)
        weekly_foodrecord.append(foodrecord)

    ###################弄成DataFrame####################
    weekly_DF = pd.DataFrame(
        {'標題': weekly_title,
         '餐廳名稱': weekly_restaurant,
         '評級': weekly_rating,
         '美食所在區域': weekly_district,
         '產生日期': weekly_date,
         '觀看人數': weekly_watch,
         '收藏人數': weekly_collection,
         '推薦人數': weekly_recommend,
         '多少人來過': weekly_visit,
         '多少篇食記': weekly_foodrecord,
        })

    rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

    weekly_DF = weekly_DF.rename(index=rows)
    weekly_DF_reverse = weekly_DF.T
    weekly_DF.to_csv('weekly_0428~0504.csv', encoding='utf_8_sig')
    weekly_DF_reverse.to_csv('weekly_0428~0504_reverse.csv', encoding='utf_8_sig')

if __name__ == '__main__':
    crawltheweb_0428_0504()
# Out:
#                                                      標題  \
# 第一名                   王品集團最新品牌！懷舊料理說歷史，經典台菜大集合！丰禾日麗台式小館
# 第二名             原創花雕雞 一鍋三種吃法 酒香味濃 真材實料 熱炒也很好吃 喜愛重口味的好選擇
# 第三名                Lady nara 台北統一時代店，全球海外首店開幕嘍！信義區新網美餐廳
# 第四名                           台北中山 川渝小吃坊 重慶酸辣粉+口水雞開胃爽口
# 第五名                       台北美食mumi cafe｜約姐妹一起來烤吐司的韓系咖啡館
# 第六名            黃亞細肉骨茶台灣二號店~新加坡正宗肉骨茶名店,白胡椒湯頭香郁,潮州特色滷水美味！
# 第七名               台北小旺仔宜蘭蛋餅｜新口感！鋪了滿滿好料的香酥宜蘭蛋餅(景美夜市人氣美食)
# 第八名   浮誇又霸氣的料理/超平價無菜單竟然有鮮甜海膽 「東街日本料理」南京復興站/高cp值無菜單料理...
# 第九名                   噴汁雞腿可外送，99元大份量漢堡就在IA Captain 國際機長
# 第十名               BFF Gossip Brunch-台北公館網美最愛餐廳，姊妹聚會最佳選擇
# 第十一名                 烏石水產火鍋超市 自助吧吃到飽59元！火烤兩吃滿額再送哈根達斯冰淇淋
# 第十二名                 漂丿燒肉食堂～肉多到你喊怕！豐盛雙拼與震撼戰斧丼飯，還有超值商業午餐
# 第十三名       樂越phofun 越式河粉專門，吃一口就被圈粉的超澎湃道地河粉，還可以隨自己喜好加油添醋
# 第十四名  福來舖～30餘種中藥材層層調製低溫拌炒，加上大骨燉煮出香醇濃郁、麻而不辣的絕頂湯底！芝山美食...
# 第十五名          【新北  港龘港式飲茶】歐式自助百匯(泰山店)。平日中午365元吃到飽/附設停車場
# 第十六名           波記香港茶餐廳｜16年老店屹立不搖~老店新開重現經典港式美味｜東區必訪港式茶餐廳
# 第十七名              台北中山-良粟商號 好吃炭燒肉蛋吐司、雞腿排蛋、菇菇蛋，連日本觀光客都愛！
# 第十八名                               兩餐두끼 韓國年糕火鍋吃到飽│忠孝復興站
# 第十九名               Sugar Pea|火紅IG夢幻雪白玻璃屋/出乎意料的美味早午餐下午茶！
# 第二十名   台北泰式料理推薦，泰新潮！泰式法國麵包、熱壓吐司！？泰式料理新吃法！泰之霸Pretty Thai
#
#                         餐廳名稱   評級 美食所在區域         產生日期  觀看人數 收藏人數 推薦人數  多少人來過  \
# 第一名              丰禾日麗 台北南京東店  4.6    中山區  2019/05/01。  1577   87    3   9人來過
# 第二名                    原創花雕雞  4.2    松山區  2019/04/29。  1776   91    2  12人來過
# 第三名        Lady nara 台北統一時代店    4    信義區  2019/04/30。  1505   70    6   6人來過
# 第四名                    川渝小吃坊  4.4    大同區  2019/04/30。   893   92    5  10人來過
# 第五名                mumi cafe  無紀錄    大安區  2019/04/28。   898   63    1   6人來過
# 第六名                   黃亞細肉骨茶  無紀錄    中山區  2019/04/27。  1835   51    2   5人來過
# 第七名                  小旺仔宜蘭蛋餅  4.4    文山區  2019/04/30。  1670   55    1   2人來過
# 第八名                   東街日本料理  4.2    中山區  2019/05/03。  1340   60    3  29人來過
# 第九名           IA Captain國際機長  3.9    松山區  2019/04/27。  1130   66   13  53人來過
# 第十名   #BFF Gossip Brunch 早午餐  4.1    中正區  2019/05/01。   997   74    6   4人來過
# 第十一名         烏石水產火鍋超市(烤)-三創店    5    中山區  2019/05/02。  1097   43    1   3人來過
# 第十二名                  漂丿燒肉食堂  4.1    大安區  2019/04/30。   884   57    4  67人來過
# 第十三名        樂越PhoFun台北慶城街1號店  4.6    松山區  2019/05/01。   891   67    0   1人來過
# 第十四名               福來舖 麻辣個人鍋  4.7    士林區  2019/04/29。  1175   51    3   8人來過
# 第十五名        港龘港式飲茶歐式自助百匯 泰山店  3.7    泰山區  2019/05/01。   786   43    3   1人來過
# 第十六名                   波記茶餐廳  3.8    大安區  2019/04/30。   811   54    1  44人來過
# 第十七名                 良粟 朝食午膳  3.9    中山區  2019/04/30。   627   59    2  35人來過
# 第十八名            兩餐韓國年糕火鍋-忠孝店  3.6    大安區  2019/04/28。   605   31    2  14人來過
# 第十九名               Sugar Pea  4.4    大安區  2019/04/27。   807   57    2  23人來過
# 第二十名         Pretty Thai 泰之霸  4.6    大安區  2019/04/29。   758   50    1   4人來過
#
#       多少篇食記
# 第一名    5篇食記
# 第二名   12篇食記
# 第三名    4篇食記
# 第四名    5篇食記
# 第五名    4篇食記
# 第六名    4篇食記
# 第七名    2篇食記
# 第八名   22篇食記
# 第九名   15篇食記
# 第十名    3篇食記
# 第十一名   2篇食記
# 第十二名  38篇食記
# 第十三名   1篇食記
# 第十四名   6篇食記
# 第十五名   1篇食記
# 第十六名  20篇食記
# 第十七名  14篇食記
# 第十八名   7篇食記
# 第十九名  12篇食記
# 第二十名   2篇食記
# ----------
#                                       第一名  \
# 標題      王品集團最新品牌！懷舊料理說歷史，經典台菜大集合！丰禾日麗台式小館
# 餐廳名稱                          丰禾日麗 台北南京東店
# 評級                                    4.6
# 美食所在區域                                中山區
# 產生日期                          2019/05/01。
# 觀看人數                                 1577
# 收藏人數                                   87
# 推薦人數                                    3
# 多少人來過                                9人來過
# 多少篇食記                                5篇食記
#
#                                             第二名  \
# 標題      原創花雕雞 一鍋三種吃法 酒香味濃 真材實料 熱炒也很好吃 喜愛重口味的好選擇
# 餐廳名稱                                      原創花雕雞
# 評級                                          4.2
# 美食所在區域                                      松山區
# 產生日期                                2019/04/29。
# 觀看人數                                       1776
# 收藏人數                                         91
# 推薦人數                                          2
# 多少人來過                                     12人來過
# 多少篇食記                                     12篇食記
#
#                                          第三名                        第四名  \
# 標題      Lady nara 台北統一時代店，全球海外首店開幕嘍！信義區新網美餐廳  台北中山 川渝小吃坊 重慶酸辣粉+口水雞開胃爽口
# 餐廳名稱                       Lady nara 台北統一時代店                      川渝小吃坊
# 評級                                         4                        4.4
# 美食所在區域                                   信義區                        大同區
# 產生日期                             2019/04/30。                2019/04/30。
# 觀看人數                                    1505                        893
# 收藏人數                                      70                         92
# 推薦人數                                       6                          5
# 多少人來過                                   6人來過                      10人來過
# 多少篇食記                                   4篇食記                       5篇食記
#
#                                   第五名  \
# 標題      台北美食mumi cafe｜約姐妹一起來烤吐司的韓系咖啡館
# 餐廳名稱                        mumi cafe
# 評級                                無紀錄
# 美食所在區域                            大安區
# 產生日期                      2019/04/28。
# 觀看人數                              898
# 收藏人數                               63
# 推薦人數                                1
# 多少人來過                            6人來過
# 多少篇食記                            4篇食記
#
#                                              第六名  \
# 標題      黃亞細肉骨茶台灣二號店~新加坡正宗肉骨茶名店,白胡椒湯頭香郁,潮州特色滷水美味！
# 餐廳名稱                                      黃亞細肉骨茶
# 評級                                           無紀錄
# 美食所在區域                                       中山區
# 產生日期                                 2019/04/27。
# 觀看人數                                        1835
# 收藏人數                                          51
# 推薦人數                                           2
# 多少人來過                                       5人來過
# 多少篇食記                                       4篇食記
#
#                                           第七名  \
# 標題      台北小旺仔宜蘭蛋餅｜新口感！鋪了滿滿好料的香酥宜蘭蛋餅(景美夜市人氣美食)
# 餐廳名稱                                  小旺仔宜蘭蛋餅
# 評級                                        4.4
# 美食所在區域                                    文山區
# 產生日期                              2019/04/30。
# 觀看人數                                     1670
# 收藏人數                                       55
# 推薦人數                                        1
# 多少人來過                                    2人來過
# 多少篇食記                                    2篇食記
#
#                                                       第八名  \
# 標題      浮誇又霸氣的料理/超平價無菜單竟然有鮮甜海膽 「東街日本料理」南京復興站/高cp值無菜單料理...
# 餐廳名稱                                               東街日本料理
# 評級                                                    4.2
# 美食所在區域                                                中山區
# 產生日期                                          2019/05/03。
# 觀看人數                                                 1340
# 收藏人數                                                   60
# 推薦人數                                                    3
# 多少人來過                                               29人來過
# 多少篇食記                                               22篇食記
#
#                                       第九名  \
# 標題      噴汁雞腿可外送，99元大份量漢堡就在IA Captain 國際機長
# 餐廳名稱                       IA Captain國際機長
# 評級                                    3.9
# 美食所在區域                                松山區
# 產生日期                          2019/04/27。
# 觀看人數                                 1130
# 收藏人數                                   66
# 推薦人數                                   13
# 多少人來過                               53人來過
# 多少篇食記                               15篇食記
#
#                                           第十名  \
# 標題      BFF Gossip Brunch-台北公館網美最愛餐廳，姊妹聚會最佳選擇
# 餐廳名稱                   #BFF Gossip Brunch 早午餐
# 評級                                        4.1
# 美食所在區域                                    中正區
# 產生日期                              2019/05/01。
# 觀看人數                                      997
# 收藏人數                                       74
# 推薦人數                                        6
# 多少人來過                                    4人來過
# 多少篇食記                                    3篇食記
#
#                                       第十一名  \
# 標題      烏石水產火鍋超市 自助吧吃到飽59元！火烤兩吃滿額再送哈根達斯冰淇淋
# 餐廳名稱                       烏石水產火鍋超市(烤)-三創店
# 評級                                       5
# 美食所在區域                                 中山區
# 產生日期                           2019/05/02。
# 觀看人數                                  1097
# 收藏人數                                    43
# 推薦人數                                     1
# 多少人來過                                 3人來過
# 多少篇食記                                 2篇食記
#
#                                        第十二名  \
# 標題       漂丿燒肉食堂～肉多到你喊怕！豐盛雙拼與震撼戰斧丼飯，還有超值商業午餐
# 餐廳名稱                                 漂丿燒肉食堂
# 評級                                      4.1
# 美食所在區域                                  大安區
# 產生日期                            2019/04/30。
# 觀看人數                                    884
# 收藏人數                                     57
# 推薦人數                                      4
# 多少人來過                                 67人來過
# 多少篇食記                                 38篇食記
#
#                                                 第十三名  \
# 標題      樂越phofun 越式河粉專門，吃一口就被圈粉的超澎湃道地河粉，還可以隨自己喜好加油添醋
# 餐廳名稱                                樂越PhoFun台北慶城街1號店
# 評級                                               4.6
# 美食所在區域                                           松山區
# 產生日期                                     2019/05/01。
# 觀看人數                                             891
# 收藏人數                                              67
# 推薦人數                                               0
# 多少人來過                                           1人來過
# 多少篇食記                                           1篇食記
#
#                                                      第十四名  \
# 標題      福來舖～30餘種中藥材層層調製低溫拌炒，加上大骨燉煮出香醇濃郁、麻而不辣的絕頂湯底！芝山美食...
# 餐廳名稱                                            福來舖 麻辣個人鍋
# 評級                                                    4.7
# 美食所在區域                                                士林區
# 產生日期                                          2019/04/29。
# 觀看人數                                                 1175
# 收藏人數                                                   51
# 推薦人數                                                    3
# 多少人來過                                                8人來過
# 多少篇食記                                                6篇食記
#
#                                              第十五名  \
# 標題      【新北  港龘港式飲茶】歐式自助百匯(泰山店)。平日中午365元吃到飽/附設停車場
# 餐廳名稱                             港龘港式飲茶歐式自助百匯 泰山店
# 評級                                            3.7
# 美食所在區域                                        泰山區
# 產生日期                                  2019/05/01。
# 觀看人數                                          786
# 收藏人數                                           43
# 推薦人數                                            3
# 多少人來過                                        1人來過
# 多少篇食記                                        1篇食記
#
#                                             第十六名  \
# 標題      波記香港茶餐廳｜16年老店屹立不搖~老店新開重現經典港式美味｜東區必訪港式茶餐廳
# 餐廳名稱                                       波記茶餐廳
# 評級                                           3.8
# 美食所在區域                                       大安區
# 產生日期                                 2019/04/30。
# 觀看人數                                         811
# 收藏人數                                          54
# 推薦人數                                           1
# 多少人來過                                      44人來過
# 多少篇食記                                      20篇食記
#
#                                          第十七名                  第十八名  \
# 標題      台北中山-良粟商號 好吃炭燒肉蛋吐司、雞腿排蛋、菇菇蛋，連日本觀光客都愛！  兩餐두끼 韓國年糕火鍋吃到飽│忠孝復興站
# 餐廳名稱                                  良粟 朝食午膳          兩餐韓國年糕火鍋-忠孝店
# 評級                                        3.9                   3.6
# 美食所在區域                                    中山區                   大安區
# 產生日期                              2019/04/30。           2019/04/28。
# 觀看人數                                      627                   605
# 收藏人數                                       59                    31
# 推薦人數                                        2                     2
# 多少人來過                                   35人來過                 14人來過
# 多少篇食記                                   14篇食記                  7篇食記
#
#                                         第十九名  \
# 標題      Sugar Pea|火紅IG夢幻雪白玻璃屋/出乎意料的美味早午餐下午茶！
# 餐廳名稱                               Sugar Pea
# 評級                                       4.4
# 美食所在區域                                   大安區
# 產生日期                             2019/04/27。
# 觀看人數                                     807
# 收藏人數                                      57
# 推薦人數                                       2
# 多少人來過                                  23人來過
# 多少篇食記                                  12篇食記
#
#                                                     第二十名
# 標題      台北泰式料理推薦，泰新潮！泰式法國麵包、熱壓吐司！？泰式料理新吃法！泰之霸Pretty Thai
# 餐廳名稱                                     Pretty Thai 泰之霸
# 評級                                                   4.6
# 美食所在區域                                               大安區
# 產生日期                                         2019/04/29。
# 觀看人數                                                 758
# 收藏人數                                                  50
# 推薦人數                                                   1
# 多少人來過                                               4人來過
# 多少篇食記                                               2篇食記

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0505~0511 def版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0505~0511.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0505~0511.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0505~0511_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0512~0518 def版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0512~0518.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0512~0518.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0512~0518_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0519~0525 def版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0519~0525.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0519~0525.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0519~0525_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0526~0601 def版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0526~0601.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0526~0601.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0526~0601_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %% [markdown]
# # 原版資料：

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0428~0504 原版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0428~0504.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text#這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==3)else date_DD_str[4].replace("(","").replace(")","") if(i==14)else date_DD_str[4].replace("(","").replace(")","") if(i==18)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==3)else date_DD_str[2].replace("。","") if(i==14)else date_DD_str[2].replace("。","") if(i==18)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0]
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1]
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0428~0504.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0428~0504_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法
# Out:
#                                                      標題  \
# 第一名                   王品集團最新品牌！懷舊料理說歷史，經典台菜大集合！丰禾日麗台式小館
# 第二名             原創花雕雞 一鍋三種吃法 酒香味濃 真材實料 熱炒也很好吃 喜愛重口味的好選擇
# 第三名                Lady nara 台北統一時代店，全球海外首店開幕嘍！信義區新網美餐廳
# 第四名                           台北中山 川渝小吃坊 重慶酸辣粉+口水雞開胃爽口
# 第五名                       台北美食mumi cafe｜約姐妹一起來烤吐司的韓系咖啡館
# 第六名            黃亞細肉骨茶台灣二號店~新加坡正宗肉骨茶名店,白胡椒湯頭香郁,潮州特色滷水美味！
# 第七名               台北小旺仔宜蘭蛋餅｜新口感！鋪了滿滿好料的香酥宜蘭蛋餅(景美夜市人氣美食)
# 第八名   浮誇又霸氣的料理/超平價無菜單竟然有鮮甜海膽 「東街日本料理」南京復興站/高cp值無菜單料理...
# 第九名                   噴汁雞腿可外送，99元大份量漢堡就在IA Captain 國際機長
# 第十名               BFF Gossip Brunch-台北公館網美最愛餐廳，姊妹聚會最佳選擇
# 第十一名                 烏石水產火鍋超市 自助吧吃到飽59元！火烤兩吃滿額再送哈根達斯冰淇淋
# 第十二名                 漂丿燒肉食堂～肉多到你喊怕！豐盛雙拼與震撼戰斧丼飯，還有超值商業午餐
# 第十三名       樂越phofun 越式河粉專門，吃一口就被圈粉的超澎湃道地河粉，還可以隨自己喜好加油添醋
# 第十四名  福來舖～30餘種中藥材層層調製低溫拌炒，加上大骨燉煮出香醇濃郁、麻而不辣的絕頂湯底！芝山美食...
# 第十五名          【新北  港龘港式飲茶】歐式自助百匯(泰山店)。平日中午365元吃到飽/附設停車場
# 第十六名           波記香港茶餐廳｜16年老店屹立不搖~老店新開重現經典港式美味｜東區必訪港式茶餐廳
# 第十七名              台北中山-良粟商號 好吃炭燒肉蛋吐司、雞腿排蛋、菇菇蛋，連日本觀光客都愛！
# 第十八名                               兩餐두끼 韓國年糕火鍋吃到飽│忠孝復興站
# 第十九名               Sugar Pea|火紅IG夢幻雪白玻璃屋/出乎意料的美味早午餐下午茶！
# 第二十名   台北泰式料理推薦，泰新潮！泰式法國麵包、熱壓吐司！？泰式料理新吃法！泰之霸Pretty Thai
#
#                         餐廳名稱   評級 美食所在區域        產生日期  觀看人數 收藏人數 推薦人數  多少人來過  \
# 第一名              丰禾日麗 台北南京東店  4.6    中山區  2019/05/01  1577   87    3   9人來過
# 第二名                    原創花雕雞  4.2    松山區  2019/04/29  1776   91    2  12人來過
# 第三名        Lady nara 台北統一時代店    4    信義區  2019/04/30  1505   70    6   6人來過
# 第四名                    川渝小吃坊  4.4    大同區  2019/04/30   893   92    5  10人來過
# 第五名                mumi cafe  無紀錄    大安區  2019/04/28   898   63    1   6人來過
# 第六名                   黃亞細肉骨茶  無紀錄    中山區  2019/04/27  1835   51    2   5人來過
# 第七名                  小旺仔宜蘭蛋餅  4.4    文山區  2019/04/30  1670   55    1   2人來過
# 第八名                   東街日本料理  4.2    中山區  2019/05/03  1340   60    3  29人來過
# 第九名           IA Captain國際機長  3.9    松山區  2019/04/27  1130   66   13  53人來過
# 第十名   #BFF Gossip Brunch 早午餐  4.1    中正區  2019/05/01   997   74    6   4人來過
# 第十一名         烏石水產火鍋超市(烤)-三創店    5    中山區  2019/05/02  1097   43    1   3人來過
# 第十二名                  漂丿燒肉食堂  4.1    大安區  2019/04/30   884   57    4  67人來過
# 第十三名        樂越PhoFun台北慶城街1號店  4.6    松山區  2019/05/01   891   67    0   1人來過
# 第十四名               福來舖 麻辣個人鍋  4.7    士林區  2019/04/29  1175   51    3   8人來過
# 第十五名        港龘港式飲茶歐式自助百匯 泰山店  3.7    泰山區  2019/05/01   786   43    3   1人來過
# 第十六名                   波記茶餐廳  3.8    大安區  2019/04/30   811   54    1  44人來過
# 第十七名                 良粟 朝食午膳  3.9    中山區  2019/04/30   627   59    2  35人來過
# 第十八名            兩餐韓國年糕火鍋-忠孝店  3.6    大安區  2019/04/28   605   31    2  14人來過
# 第十九名               Sugar Pea  4.4    大安區  2019/04/27   807   57    2  23人來過
# 第二十名         Pretty Thai 泰之霸  4.6    大安區  2019/04/29   758   50    1   4人來過
#
#       多少篇食記
# 第一名    5篇食記
# 第二名   12篇食記
# 第三名    4篇食記
# 第四名    5篇食記
# 第五名    4篇食記
# 第六名    4篇食記
# 第七名    2篇食記
# 第八名   22篇食記
# 第九名   15篇食記
# 第十名    3篇食記
# 第十一名   2篇食記
# 第十二名  38篇食記
# 第十三名   1篇食記
# 第十四名   6篇食記
# 第十五名   1篇食記
# 第十六名  20篇食記
# 第十七名  14篇食記
# 第十八名   7篇食記
# 第十九名  12篇食記
# 第二十名   2篇食記
# ----------
#                                       第一名  \
# 標題      王品集團最新品牌！懷舊料理說歷史，經典台菜大集合！丰禾日麗台式小館
# 餐廳名稱                          丰禾日麗 台北南京東店
# 評級                                    4.6
# 美食所在區域                                中山區
# 產生日期                           2019/05/01
# 觀看人數                                 1577
# 收藏人數                                   87
# 推薦人數                                    3
# 多少人來過                                9人來過
# 多少篇食記                                5篇食記
#
#                                             第二名  \
# 標題      原創花雕雞 一鍋三種吃法 酒香味濃 真材實料 熱炒也很好吃 喜愛重口味的好選擇
# 餐廳名稱                                      原創花雕雞
# 評級                                          4.2
# 美食所在區域                                      松山區
# 產生日期                                 2019/04/29
# 觀看人數                                       1776
# 收藏人數                                         91
# 推薦人數                                          2
# 多少人來過                                     12人來過
# 多少篇食記                                     12篇食記
#
#                                          第三名                        第四名  \
# 標題      Lady nara 台北統一時代店，全球海外首店開幕嘍！信義區新網美餐廳  台北中山 川渝小吃坊 重慶酸辣粉+口水雞開胃爽口
# 餐廳名稱                       Lady nara 台北統一時代店                      川渝小吃坊
# 評級                                         4                        4.4
# 美食所在區域                                   信義區                        大同區
# 產生日期                              2019/04/30                 2019/04/30
# 觀看人數                                    1505                        893
# 收藏人數                                      70                         92
# 推薦人數                                       6                          5
# 多少人來過                                   6人來過                      10人來過
# 多少篇食記                                   4篇食記                       5篇食記
#
#                                   第五名  \
# 標題      台北美食mumi cafe｜約姐妹一起來烤吐司的韓系咖啡館
# 餐廳名稱                        mumi cafe
# 評級                                無紀錄
# 美食所在區域                            大安區
# 產生日期                       2019/04/28
# 觀看人數                              898
# 收藏人數                               63
# 推薦人數                                1
# 多少人來過                            6人來過
# 多少篇食記                            4篇食記
#
#                                              第六名  \
# 標題      黃亞細肉骨茶台灣二號店~新加坡正宗肉骨茶名店,白胡椒湯頭香郁,潮州特色滷水美味！
# 餐廳名稱                                      黃亞細肉骨茶
# 評級                                           無紀錄
# 美食所在區域                                       中山區
# 產生日期                                  2019/04/27
# 觀看人數                                        1835
# 收藏人數                                          51
# 推薦人數                                           2
# 多少人來過                                       5人來過
# 多少篇食記                                       4篇食記
#
#                                           第七名  \
# 標題      台北小旺仔宜蘭蛋餅｜新口感！鋪了滿滿好料的香酥宜蘭蛋餅(景美夜市人氣美食)
# 餐廳名稱                                  小旺仔宜蘭蛋餅
# 評級                                        4.4
# 美食所在區域                                    文山區
# 產生日期                               2019/04/30
# 觀看人數                                     1670
# 收藏人數                                       55
# 推薦人數                                        1
# 多少人來過                                    2人來過
# 多少篇食記                                    2篇食記
#
#                                                       第八名  \
# 標題      浮誇又霸氣的料理/超平價無菜單竟然有鮮甜海膽 「東街日本料理」南京復興站/高cp值無菜單料理...
# 餐廳名稱                                               東街日本料理
# 評級                                                    4.2
# 美食所在區域                                                中山區
# 產生日期                                           2019/05/03
# 觀看人數                                                 1340
# 收藏人數                                                   60
# 推薦人數                                                    3
# 多少人來過                                               29人來過
# 多少篇食記                                               22篇食記
#
#                                       第九名  \
# 標題      噴汁雞腿可外送，99元大份量漢堡就在IA Captain 國際機長
# 餐廳名稱                       IA Captain國際機長
# 評級                                    3.9
# 美食所在區域                                松山區
# 產生日期                           2019/04/27
# 觀看人數                                 1130
# 收藏人數                                   66
# 推薦人數                                   13
# 多少人來過                               53人來過
# 多少篇食記                               15篇食記
#
#                                           第十名  \
# 標題      BFF Gossip Brunch-台北公館網美最愛餐廳，姊妹聚會最佳選擇
# 餐廳名稱                   #BFF Gossip Brunch 早午餐
# 評級                                        4.1
# 美食所在區域                                    中正區
# 產生日期                               2019/05/01
# 觀看人數                                      997
# 收藏人數                                       74
# 推薦人數                                        6
# 多少人來過                                    4人來過
# 多少篇食記                                    3篇食記
#
#                                       第十一名  \
# 標題      烏石水產火鍋超市 自助吧吃到飽59元！火烤兩吃滿額再送哈根達斯冰淇淋
# 餐廳名稱                       烏石水產火鍋超市(烤)-三創店
# 評級                                       5
# 美食所在區域                                 中山區
# 產生日期                            2019/05/02
# 觀看人數                                  1097
# 收藏人數                                    43
# 推薦人數                                     1
# 多少人來過                                 3人來過
# 多少篇食記                                 2篇食記
#
#                                        第十二名  \
# 標題       漂丿燒肉食堂～肉多到你喊怕！豐盛雙拼與震撼戰斧丼飯，還有超值商業午餐
# 餐廳名稱                                 漂丿燒肉食堂
# 評級                                      4.1
# 美食所在區域                                  大安區
# 產生日期                             2019/04/30
# 觀看人數                                    884
# 收藏人數                                     57
# 推薦人數                                      4
# 多少人來過                                 67人來過
# 多少篇食記                                 38篇食記
#
#                                                 第十三名  \
# 標題      樂越phofun 越式河粉專門，吃一口就被圈粉的超澎湃道地河粉，還可以隨自己喜好加油添醋
# 餐廳名稱                                樂越PhoFun台北慶城街1號店
# 評級                                               4.6
# 美食所在區域                                           松山區
# 產生日期                                      2019/05/01
# 觀看人數                                             891
# 收藏人數                                              67
# 推薦人數                                               0
# 多少人來過                                           1人來過
# 多少篇食記                                           1篇食記
#
#                                                      第十四名  \
# 標題      福來舖～30餘種中藥材層層調製低溫拌炒，加上大骨燉煮出香醇濃郁、麻而不辣的絕頂湯底！芝山美食...
# 餐廳名稱                                            福來舖 麻辣個人鍋
# 評級                                                    4.7
# 美食所在區域                                                士林區
# 產生日期                                           2019/04/29
# 觀看人數                                                 1175
# 收藏人數                                                   51
# 推薦人數                                                    3
# 多少人來過                                                8人來過
# 多少篇食記                                                6篇食記
#
#                                              第十五名  \
# 標題      【新北  港龘港式飲茶】歐式自助百匯(泰山店)。平日中午365元吃到飽/附設停車場
# 餐廳名稱                             港龘港式飲茶歐式自助百匯 泰山店
# 評級                                            3.7
# 美食所在區域                                        泰山區
# 產生日期                                   2019/05/01
# 觀看人數                                          786
# 收藏人數                                           43
# 推薦人數                                            3
# 多少人來過                                        1人來過
# 多少篇食記                                        1篇食記
#
#                                             第十六名  \
# 標題      波記香港茶餐廳｜16年老店屹立不搖~老店新開重現經典港式美味｜東區必訪港式茶餐廳
# 餐廳名稱                                       波記茶餐廳
# 評級                                           3.8
# 美食所在區域                                       大安區
# 產生日期                                  2019/04/30
# 觀看人數                                         811
# 收藏人數                                          54
# 推薦人數                                           1
# 多少人來過                                      44人來過
# 多少篇食記                                      20篇食記
#
#                                          第十七名                  第十八名  \
# 標題      台北中山-良粟商號 好吃炭燒肉蛋吐司、雞腿排蛋、菇菇蛋，連日本觀光客都愛！  兩餐두끼 韓國年糕火鍋吃到飽│忠孝復興站
# 餐廳名稱                                  良粟 朝食午膳          兩餐韓國年糕火鍋-忠孝店
# 評級                                        3.9                   3.6
# 美食所在區域                                    中山區                   大安區
# 產生日期                               2019/04/30            2019/04/28
# 觀看人數                                      627                   605
# 收藏人數                                       59                    31
# 推薦人數                                        2                     2
# 多少人來過                                   35人來過                 14人來過
# 多少篇食記                                   14篇食記                  7篇食記
#
#                                         第十九名  \
# 標題      Sugar Pea|火紅IG夢幻雪白玻璃屋/出乎意料的美味早午餐下午茶！
# 餐廳名稱                               Sugar Pea
# 評級                                       4.4
# 美食所在區域                                   大安區
# 產生日期                              2019/04/27
# 觀看人數                                     807
# 收藏人數                                      57
# 推薦人數                                       2
# 多少人來過                                  23人來過
# 多少篇食記                                  12篇食記
#
#                                                     第二十名
# 標題      台北泰式料理推薦，泰新潮！泰式法國麵包、熱壓吐司！？泰式料理新吃法！泰之霸Pretty Thai
# 餐廳名稱                                     Pretty Thai 泰之霸
# 評級                                                   4.6
# 美食所在區域                                               大安區
# 產生日期                                          2019/04/29
# 觀看人數                                                 758
# 收藏人數                                                  50
# 推薦人數                                                   1
# 多少人來過                                               4人來過
# 多少篇食記                                               2篇食記

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0505~0511 原版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0505~0511.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0505~0511.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0505~0511_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0512~0518 原版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0512~0518.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0512~0518.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0512~0518_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0519~0525 原版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0519~0525.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0519~0525.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0519~0525_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#weekly0526~0601 原版
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

urlretrieve = "http://localhost/weekly_0526~0601.html"#每周排名
data = requests.get(urlretrieve)
data.encoding = 'utf-8'
#print(data.apparent_encoding)#查看網頁目前編碼
#print(data.text)#查看網頁

soup = BeautifulSoup(data.text,"lxml")#提取內容

####################取得所有標題####################
weekly_title = []
weekly_title_str = soup.select(".blog-item.ranking h4.title a")
#print(len(weekly_title_str))#共20名
for i in range(len(weekly_title_str)):
    weekly_title.append(weekly_title_str[i].string)
#print("-"*10)
#print(weekly_title)

####################取得各項餐廳名稱、評級####################
weekly_restaurant = []
weekly_rating = []
weekly_restaurant_str = soup.select(".blog-item .restaurant.a, .blog-item .restaurant a")
weekly_rating_str = soup.select(".restaurant.item .rating")
#print(weekly_restaurant_str[0].text)
#print(weekly_rating_str[0].text)
for i in range(len(weekly_restaurant_str)//2):
    restaurant = weekly_restaurant_str[i*2].text if(i!=13)else weekly_title_str[13].string.split("|")[1].split(" ")[0] #這有40格，取一半
    rating = "無紀錄" if(weekly_rating_str[i*2].text=="0")else "無紀錄" if(i==13)else "無紀錄" if(i==16)else weekly_rating_str[i*2].text#這有40格，取一半
    weekly_restaurant.append(restaurant)
    weekly_rating.append(rating) 
#print("-"*10)
#print(weekly_restaurant)
#print(weekly_rating)

####################取得各項美食所在區域、產生日期####################
weekly_district = []
weekly_date = []
weekly_date_str = soup.select("h5, .h5")
#print(weekly_date_str)
for i in range(len(weekly_date_str)):
    date_DD_str = weekly_date_str[i].text.split(" ")
    #print(date_DD_str)
    district = date_DD_str[4].replace("(","").replace(")","") if(i==0)else date_DD_str[5].replace("(","").replace(")","") if(i==4)else date_DD_str[4].replace("(","").replace(")","") if(i==9)else date_DD_str[3].replace("(","").replace(")","")
    date = date_DD_str[2].replace("。","") if(i==0)else date_DD_str[3].replace("。","") if(i==4)else date_DD_str[2].replace("。","") if(i==9)else date_DD_str[1].replace("。","")
    weekly_district.append(district)
    weekly_date.append(date)
#print("-"*10)
#print(weekly_district)
#print("-"*10)
#print(weekly_date)

####################取得各項觀看、收藏、推薦次數####################
weekly_watch = []
weekly_collection = []
weekly_recommend = []
weekly_WCR_str = soup.select(".blog-item .stat-box")
#print(weekly_WCR_str)
for i in range(len(weekly_WCR_str)):
    WCR = weekly_WCR_str[i].text.replace("\n","").split(" ")
    weekly_watch.append(WCR[2])
    weekly_collection.append(WCR[4])
    weekly_recommend.append(WCR[6])
#print("-"*10)
#print(weekly_watch)
#print(weekly_collection)
#print(weekly_recommend)

####################取得各項來過人數、食記篇數####################
weekly_visit = []
weekly_foodrecord = []
weekly_VF_str = soup.select(".restaurant.right.item > .ng-binding")
#print(weekly_VF_str)
#print(weekly_VF_str[0].text)
for i in range(len(weekly_VF_str)):
    visit = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[0] if(i!=13)else "無紀錄"
    foodrecord = weekly_VF_str[i].text.split("\n")[3].replace("\t","").replace("\r","").split(" ")[1] if(i!=13)else "無紀錄"
    weekly_visit.append(visit)
    weekly_foodrecord.append(foodrecord)
#print("-"*10)
#print(weekly_visit)
#print(weekly_foodrecord)

###################弄成DataFrame####################
#原本
#cols = "第N名"
#rows = "標籤名稱(共十個)"
#反轉
#cols = "標籤名稱(共十個)"
#rows = "第N名"

weekly_DF = pd.DataFrame(
    {'標題': weekly_title,
     '餐廳名稱': weekly_restaurant,
     '評級': weekly_rating,
     '美食所在區域': weekly_district,
     '產生日期': weekly_date,
     '觀看人數': weekly_watch,
     '收藏人數': weekly_collection,
     '推薦人數': weekly_recommend,
     '多少人來過': weekly_visit,
     '多少篇食記': weekly_foodrecord,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

weekly_DF = weekly_DF.rename(index=rows)
print(weekly_DF)
print("-"*10)
weekly_DF_reverse = weekly_DF.T
print(weekly_DF_reverse)
weekly_DF.to_csv('weekly_0526~0601.csv', encoding='utf_8_sig')
weekly_DF_reverse.to_csv('weekly_0526~0601_reverse.csv', encoding='utf_8_sig')

############################################

#print(soup.prettify())#把排版後的 html 印出來
#response.css('.blog-item.ranking h4.title').extract()#scrapy方法
