# %% [markdown]
# # 概況：
# 各月各名次的評級、觀看收藏推薦次數(單月-直方圖)(統整好-箱型圖)(跟統整好的整月做比較)

# %% [markdown]
# # 先進行資料處理：

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#視覺化圖表
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import math
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use('ggplot')
warnings.filterwarnings('ignore')
####################讀取檔案####################
df_0331_0406 = pd.read_csv('weekly_0331~0406.csv')
df_0407_0413 = pd.read_csv('weekly_0407~0413.csv')
df_0414_0420 = pd.read_csv('weekly_0414~0420.csv')
df_0421_0427 = pd.read_csv('weekly_0421~0427.csv')
df_0428_0504 = pd.read_csv('weekly_0428~0504.csv')
df_0505_0511 = pd.read_csv('weekly_0505~0511.csv')
df_0512_0518 = pd.read_csv('weekly_0512~0518.csv')
df_0519_0525 = pd.read_csv('weekly_0519~0525.csv')
df_0526_0601 = pd.read_csv('weekly_0526~0601.csv')
df_03 = pd.read_csv('monthly_03.csv')
df_04 = pd.read_csv('monthly_04.csv')
df_05 = pd.read_csv('monthly_05.csv')

####################資料處理####################0331_0406
rating_mean = "%.1f" % df_0331_0406.loc[df_0331_0406['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0331_0406['評級'][13] = df_0331_0406['評級'][13].replace("無紀錄", rating_mean)
df_0331_0406['評級'][16] = df_0331_0406['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0331_0406['多少人來過'][i] = df_0331_0406['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0331_0406.loc[df_0331_0406['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0331_0406['多少人來過'][13] = df_0331_0406['多少人來過'][13].replace("無紀錄", str(round(float(visit_mean))))
for i in range(0,20):
    df_0331_0406['多少篇食記'][i] = df_0331_0406['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0331_0406.loc[df_0331_0406['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0331_0406['多少篇食記'][13] = df_0331_0406['多少篇食記'][13].replace("無紀錄", str(round(float(visit_mean))))
##print(df_0331_0406)

####################資料處理####################0407_0413
rating_mean = "%.1f" % df_0407_0413.loc[df_0407_0413['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0407_0413['評級'][1] = df_0407_0413['評級'][1].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0407_0413['評級'][3] = df_0407_0413['評級'][3].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0407_0413['評級'][15] = df_0407_0413['評級'][15].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0407_0413['評級'][18] = df_0407_0413['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0407_0413['評級'][19] = df_0407_0413['評級'][19].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0407_0413['多少人來過'][i] = df_0407_0413['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_0407_0413['多少篇食記'][i] = df_0407_0413['多少篇食記'][i].replace("篇食記", "")
#print(df_0407_0413)

####################資料處理####################0414_0420
rating_mean = "%.1f" % df_0414_0420.loc[df_0414_0420['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0414_0420['評級'][3] = df_0414_0420['評級'][3].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0414_0420['評級'][16] = df_0414_0420['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0414_0420['評級'][19] = df_0414_0420['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0414_0420['多少人來過'][i] = df_0414_0420['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0414_0420.loc[df_0414_0420['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0414_0420['多少人來過'][19] = df_0414_0420['多少人來過'][19].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0414_0420['多少篇食記'][i] = df_0414_0420['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0414_0420.loc[df_0414_0420['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0414_0420['多少篇食記'][19] = df_0414_0420['多少篇食記'][19].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0414_0420)

####################資料處理####################0421_0427
rating_mean = "%.1f" % df_0421_0427.loc[df_0421_0427['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0421_0427['評級'][2] = df_0421_0427['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0421_0427['評級'][5] = df_0421_0427['評級'][5].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0421_0427['評級'][17] = df_0421_0427['評級'][17].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0421_0427['評級'][18] = df_0421_0427['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0421_0427['多少人來過'][i] = df_0421_0427['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_0421_0427['多少篇食記'][i] = df_0421_0427['多少篇食記'][i].replace("篇食記", "")
#print(df_0421_0427)

####################資料處理####################0428_0504
rating_mean = "%.1f" % df_0428_0504.loc[df_0428_0504['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0428_0504['評級'][4] = df_0428_0504['評級'][4].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0428_0504['評級'][5] = df_0428_0504['評級'][5].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
for i in range(0,20):
    df_0428_0504['多少人來過'][i] = df_0428_0504['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_0428_0504['多少篇食記'][i] = df_0428_0504['多少篇食記'][i].replace("篇食記", "")
#print(df_0428_0504)

####################資料處理####################0505_0511
df_0505_0511['評級'][6] = df_0505_0511['評級'][6].replace("無紀錄", rating_mean)
df_0505_0511['評級'][16] = df_0505_0511['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0505_0511['評級'][17] = df_0505_0511['評級'][17].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0505_0511['評級'][18] = df_0505_0511['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0505_0511['多少人來過'][i] = df_0505_0511['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0505_0511.loc[df_0505_0511['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0505_0511['多少人來過'][16] = df_0505_0511['多少人來過'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
df_0505_0511['多少人來過'][18] = df_0505_0511['多少人來過'][18].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0505_0511['多少篇食記'][i] = df_0505_0511['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0505_0511.loc[df_0505_0511['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0505_0511['多少篇食記'][16] = df_0505_0511['多少篇食記'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
df_0505_0511['多少篇食記'][18] = df_0505_0511['多少篇食記'][18].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0505_0511)

####################資料處理####################0512_0518
rating_mean = "%.1f" % df_0512_0518.loc[df_0512_0518['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0512_0518['評級'][2] = df_0512_0518['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0512_0518['評級'][5] = df_0512_0518['評級'][5].replace("無紀錄", rating_mean)
df_0512_0518['評級'][11] = df_0512_0518['評級'][11].replace("無紀錄", rating_mean)
df_0512_0518['評級'][16] = df_0512_0518['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0512_0518['評級'][18] = df_0512_0518['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0512_0518['多少人來過'][i] = df_0512_0518['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0512_0518.loc[df_0512_0518['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0512_0518['多少人來過'][11] = df_0512_0518['多少人來過'][11].replace("無紀錄", str(int(float(visit_mean))))
df_0512_0518['多少人來過'][16] = df_0512_0518['多少人來過'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0512_0518['多少篇食記'][i] = df_0512_0518['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0512_0518.loc[df_0512_0518['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0512_0518['多少篇食記'][11] = df_0512_0518['多少篇食記'][11].replace("無紀錄", str(int(float(visit_mean))))
df_0512_0518['多少篇食記'][16] = df_0512_0518['多少篇食記'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0512_0518)

####################資料處理####################0519_0525
rating_mean = "%.1f" % df_0519_0525.loc[df_0519_0525['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0519_0525['評級'][6] = df_0519_0525['評級'][6].replace("無紀錄", rating_mean)
df_0519_0525['評級'][15] = df_0519_0525['評級'][15].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0519_0525['多少人來過'][i] = df_0519_0525['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0519_0525.loc[df_0519_0525['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0519_0525['多少人來過'][6] = df_0519_0525['多少人來過'][6].replace("無紀錄", str(int(float(visit_mean))))
df_0519_0525['多少人來過'][15] = df_0519_0525['多少人來過'][15].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0519_0525['多少篇食記'][i] = df_0519_0525['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0519_0525.loc[df_0519_0525['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0519_0525['多少篇食記'][6] = df_0519_0525['多少篇食記'][6].replace("無紀錄", str(int(float(visit_mean))))
df_0519_0525['多少篇食記'][15] = df_0519_0525['多少篇食記'][15].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0519_0525)

####################資料處理####################0526_0601
rating_mean = "%.1f" % df_0526_0601.loc[df_0526_0601['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0526_0601['評級'][1] = df_0526_0601['評級'][1].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0526_0601['評級'][14] = df_0526_0601['評級'][14].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_0526_0601['多少人來過'][i] = df_0526_0601['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0526_0601.loc[df_0526_0601['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0526_0601['多少人來過'][1] = df_0526_0601['多少人來過'][1].replace("無紀錄", str(int(float(visit_mean)*1.2)))
df_0526_0601['多少人來過'][14] = df_0526_0601['多少人來過'][14].replace("無紀錄", str(int(float(visit_mean))))
for i in range(0,20):
    df_0526_0601['多少篇食記'][i] = df_0526_0601['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0526_0601.loc[df_0526_0601['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0526_0601['多少篇食記'][1] = df_0526_0601['多少篇食記'][1].replace("無紀錄", str(int(float(visit_mean)*1.2)))
df_0526_0601['多少篇食記'][14] = df_0526_0601['多少篇食記'][14].replace("無紀錄", str(int(float(visit_mean))))
#print(df_0526_0601)

####################資料處理####################03
rating_mean = "%.1f" % df_03.loc[df_03['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_03['評級'][2] = df_03['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_03['評級'][11] = df_03['評級'][11].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_03['多少人來過'][i] = df_03['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_03.loc[df_03['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_03['多少人來過'][11] = df_03['多少人來過'][11].replace("無紀錄", str(round(float(visit_mean))))
for i in range(0,20):
    df_03['多少篇食記'][i] = df_03['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_03.loc[df_03['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_03['多少篇食記'][11] = df_03['多少篇食記'][11].replace("無紀錄", str(round(float(visit_mean))))
#print(df_03)

####################資料處理####################04
rating_mean = "%.1f" % df_04.loc[df_04['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_04['評級'][5] = df_04['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_04['評級'][11] = df_04['評級'][11].replace("無紀錄", rating_mean)
df_04['評級'][12] = df_04['評級'][12].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_04['多少人來過'][i] = df_04['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_04['多少篇食記'][i] = df_04['多少篇食記'][i].replace("篇食記", "")
#print(df_04)

####################資料處理####################05
rating_mean = "%.1f" % df_05.loc[df_05['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_05['評級'][7] = df_05['評級'][7].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_05['多少人來過'][i] = df_05['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_05['多少篇食記'][i] = df_05['多少篇食記'][i].replace("篇食記", "")
#print(df_05)

########################################
#0331_0406
#0407_0413
#0414_0420
#0421_0427
#0428_0504
#0505_0511
#0512_0518
#0519_0525
#0526_0601
#03
#04
#05

#print(df_0331_0406.loc[df_0331_0406['評級'] == "無紀錄",'評級'].values[0])#某個row的值
#print(df_0331_0406[df_0331_0406['評級'] == "無紀錄"].index.tolist()[0])#列出目標是在哪個row
#print(df_0331_0406.iloc[:,3])#取出該column的所有row

# %% [markdown]
# # 概況：三月份：

# %%
####################視覺化圖表####################
####################概況：單個月各名次的評級####################
from numpy import array

monthly_rating_03 = df_03['評級'].astype("float64")

ALL_monthly_rating_DF = pd.DataFrame(
    {'monthly_rating_03': monthly_rating_03,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_rating_DF = ALL_monthly_rating_DF.rename(index=rows)

data = ALL_monthly_rating_DF['monthly_rating_03'].astype("float64").values

#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='rating')
#plt.title('每月各名次的評級')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % float(height), ha='center', va='bottom')

ax.set_title('monthly rating_03')
ax.set_xlabel('Ranking')
ax.set_ylabel('rating')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的觀看人數####################
from numpy import array

monthly_watch_03 = df_03['觀看人數'].astype("float64")

ALL_monthly_watch_DF = pd.DataFrame(
    {'monthly_watch_03': monthly_watch_03,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_watch_DF = ALL_monthly_watch_DF.rename(index=rows)

data = ALL_monthly_watch_DF['monthly_watch_03'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='watch')
#plt.title('每月各名次的觀看人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly watch_03')
ax.set_xlabel('Ranking')
ax.set_ylabel('watch')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的收藏人數####################
from numpy import array

monthly_collection_03 = df_03['收藏人數'].astype("float64")

ALL_monthly_collection_DF = pd.DataFrame(
    {'monthly_collection_03': monthly_collection_03,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_collection_DF = ALL_monthly_collection_DF.rename(index=rows)

data = ALL_monthly_collection_DF['monthly_collection_03'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='collection')
#plt.title('每月各名次的收藏人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly collection_03')
ax.set_xlabel('Ranking')
ax.set_ylabel('collection')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的推薦人數####################
from numpy import array

monthly_recommend_03 = df_03['推薦人數'].astype("float64")

ALL_monthly_recommend_DF = pd.DataFrame(
    {'monthly_recommend_03': monthly_recommend_03,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_recommend_DF = ALL_monthly_recommend_DF.rename(index=rows)

data = ALL_monthly_recommend_DF['monthly_recommend_03'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='recommend')
#plt.title('每月各名次的推薦人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly recommend_03')
ax.set_xlabel('Ranking')
ax.set_ylabel('recommend')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的多少人來過####################
from numpy import array

monthly_visit_03 = df_03['多少人來過'].astype("float64")

ALL_monthly_visit_DF = pd.DataFrame(
    {'monthly_visit_03': monthly_visit_03,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_visit_DF = ALL_monthly_visit_DF.rename(index=rows)

data = ALL_monthly_visit_DF['monthly_visit_03'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='visit')
#plt.title('每月各名次的多少人來過')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly visit_03')
ax.set_xlabel('Ranking')
ax.set_ylabel('visit')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的多少篇食記####################
from numpy import array

monthly_foodrecord_03 = df_03['多少篇食記'].astype("float64")

ALL_monthly_foodrecord_DF = pd.DataFrame(
    {'monthly_foodrecord_03': monthly_foodrecord_03,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_foodrecord_DF = ALL_monthly_foodrecord_DF.rename(index=rows)

data = ALL_monthly_foodrecord_DF['monthly_foodrecord_03'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='foodrecord')
#plt.title('每月各名次的多少篇食記')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly foodrecord_03')
ax.set_xlabel('Ranking')
ax.set_ylabel('foodrecord')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 概況：四月份：

# %%
####################視覺化圖表####################
####################概況：單個月各名次的評級####################
from numpy import array

monthly_rating_04 = df_04['評級'].astype("float64")

ALL_monthly_rating_DF = pd.DataFrame(
    {'monthly_rating_04': monthly_rating_04,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_rating_DF = ALL_monthly_rating_DF.rename(index=rows)

data = ALL_monthly_rating_DF['monthly_rating_04'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='rating')
#plt.title('每月各名次的評級')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % float(height), ha='center', va='bottom')

ax.set_title('monthly rating_04')
ax.set_xlabel('Ranking')
ax.set_ylabel('rating')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的觀看人數####################
from numpy import array

monthly_watch_04 = df_04['觀看人數'].astype("float64")

ALL_monthly_watch_DF = pd.DataFrame(
    {'monthly_watch_04': monthly_watch_04,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_watch_DF = ALL_monthly_watch_DF.rename(index=rows)

data = ALL_monthly_watch_DF['monthly_watch_04'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='watch')
#plt.title('每月各名次的觀看人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly watch_04')
ax.set_xlabel('Ranking')
ax.set_ylabel('watch')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的收藏人數####################
from numpy import array

monthly_collection_04 = df_04['收藏人數'].astype("float64")

ALL_monthly_collection_DF = pd.DataFrame(
    {'monthly_collection_04': monthly_collection_04,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_collection_DF = ALL_monthly_collection_DF.rename(index=rows)

data = ALL_monthly_collection_DF['monthly_collection_04'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='collection')
#plt.title('每月各名次的收藏人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly collection_04')
ax.set_xlabel('Ranking')
ax.set_ylabel('collection')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的推薦人數####################
from numpy import array

monthly_recommend_04 = df_04['推薦人數'].astype("float64")

ALL_monthly_recommend_DF = pd.DataFrame(
    {'monthly_recommend_04': monthly_recommend_04,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_recommend_DF = ALL_monthly_recommend_DF.rename(index=rows)

data = ALL_monthly_recommend_DF['monthly_recommend_04'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='recommend')
#plt.title('每月各名次的推薦人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly recommend_04')
ax.set_xlabel('Ranking')
ax.set_ylabel('recommend')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的多少人來過####################
from numpy import array

monthly_visit_04 = df_04['多少人來過'].astype("float64")

ALL_monthly_visit_DF = pd.DataFrame(
    {'monthly_visit_04': monthly_visit_04,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_visit_DF = ALL_monthly_visit_DF.rename(index=rows)

data = ALL_monthly_visit_DF['monthly_visit_04'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='visit')
#plt.title('每月各名次的多少人來過')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly visit_04')
ax.set_xlabel('Ranking')
ax.set_ylabel('visit')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的多少篇食記####################
from numpy import array

monthly_foodrecord_04 = df_04['多少篇食記'].astype("float64")

ALL_monthly_foodrecord_DF = pd.DataFrame(
    {'monthly_foodrecord_04': monthly_foodrecord_04,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_foodrecord_DF = ALL_monthly_foodrecord_DF.rename(index=rows)

data = ALL_monthly_foodrecord_DF['monthly_foodrecord_04'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='foodrecord')
#plt.title('每月各名次的多少篇食記')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly foodrecord_04')
ax.set_xlabel('Ranking')
ax.set_ylabel('foodrecord')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 概況：五月份：

# %%
####################視覺化圖表####################
####################概況：單個月各名次的評級####################
from numpy import array

monthly_rating_05 = df_05['評級'].astype("float64")

ALL_monthly_rating_DF = pd.DataFrame(
    {'monthly_rating_05': monthly_rating_05,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_rating_DF = ALL_monthly_rating_DF.rename(index=rows)

data = ALL_monthly_rating_DF['monthly_rating_05'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='rating')
#plt.title('每月各名次的評級')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % float(height), ha='center', va='bottom')

ax.set_title('monthly rating_05')
ax.set_xlabel('Ranking')
ax.set_ylabel('rating')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的觀看人數####################
from numpy import array

monthly_watch_05 = df_05['觀看人數'].astype("float64")

ALL_monthly_watch_DF = pd.DataFrame(
    {'monthly_watch_05': monthly_watch_05,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_watch_DF = ALL_monthly_watch_DF.rename(index=rows)

data = ALL_monthly_watch_DF['monthly_watch_05'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='watch')
#plt.title('每月各名次的觀看人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly watch_05')
ax.set_xlabel('Ranking')
ax.set_ylabel('watch')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的收藏人數####################
from numpy import array

monthly_collection_05 = df_05['收藏人數'].astype("float64")

ALL_monthly_collection_DF = pd.DataFrame(
    {'monthly_collection_05': monthly_collection_05,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_collection_DF = ALL_monthly_collection_DF.rename(index=rows)

data = ALL_monthly_collection_DF['monthly_collection_05'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='collection')
#plt.title('每月各名次的收藏人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly collection_05')
ax.set_xlabel('Ranking')
ax.set_ylabel('collection')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的推薦人數####################
from numpy import array

monthly_recommend_05 = df_05['推薦人數'].astype("float64")

ALL_monthly_recommend_DF = pd.DataFrame(
    {'monthly_recommend_05': monthly_recommend_05,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_recommend_DF = ALL_monthly_recommend_DF.rename(index=rows)

data = ALL_monthly_recommend_DF['monthly_recommend_05'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='recommend')
#plt.title('每月各名次的推薦人數')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly recommend_05')
ax.set_xlabel('Ranking')
ax.set_ylabel('recommend')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的多少人來過####################
from numpy import array

monthly_visit_05 = df_05['多少人來過'].astype("float64")

ALL_monthly_visit_DF = pd.DataFrame(
    {'monthly_visit_05': monthly_visit_05,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_visit_DF = ALL_monthly_visit_DF.rename(index=rows)

data = ALL_monthly_visit_DF['monthly_visit_05'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='visit')
#plt.title('每月各名次的多少人來過')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly visit_05')
ax.set_xlabel('Ranking')
ax.set_ylabel('visit')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
####################視覺化圖表####################
####################概況：單個月各名次的多少篇食記####################
from numpy import array

monthly_foodrecord_05 = df_05['多少篇食記'].astype("float64")

ALL_monthly_foodrecord_DF = pd.DataFrame(
    {'monthly_foodrecord_05': monthly_foodrecord_05,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_monthly_foodrecord_DF = ALL_monthly_foodrecord_DF.rename(index=rows)

data = ALL_monthly_foodrecord_DF['monthly_foodrecord_05'].astype("float64").values
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']
xlabellen = np.arange(len(data))

fig, ax = plt.subplots(figsize=(12,6))
plotbar = ax.bar(xlabellen,data, color='SkyBlue', label='foodrecord')
#plt.title('每月各名次的多少篇食記')
for rect in plotbar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

ax.set_title('monthly foodrecord_05')
ax.set_xlabel('Ranking')
ax.set_ylabel('foodrecord')
ax.set_xticks(xlabellen)
ax.set_xticklabels(labels,rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 概況：每週資料整合(四月份)：

# %%
####################概況：每週各名次的評級####################

weekly_rating_0331_0406 = df_0331_0406['評級'].astype("float64")
weekly_rating_0407_0413 = df_0407_0413['評級'].astype("float64")
weekly_rating_0414_0420 = df_0414_0420['評級'].astype("float64")
weekly_rating_0421_0427 = df_0421_0427['評級'].astype("float64")
weekly_rating_0428_0504 = df_0428_0504['評級'].astype("float64")

ALL_weekly_rating_DF = pd.DataFrame(
    {'weekly_rating_0331_0406': weekly_rating_0331_0406,
     'weekly_rating_0407_0413': weekly_rating_0407_0413,
     'weekly_rating_0414_0420': weekly_rating_0414_0420,
     'weekly_rating_0421_0427': weekly_rating_0421_0427,
     'weekly_rating_0428_0504': weekly_rating_0428_0504,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_rating_DF = ALL_weekly_rating_DF.rename(index=rows)
ALL_weekly_rating_DF_reverse = ALL_weekly_rating_DF.T

data = [ALL_weekly_rating_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的評級')
plt.title('Weekly rating_04')
plt.xlabel('Ranking')
plt.ylabel('rating')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly rating_04')
plt.xlabel('Ranking')
plt.ylabel('rating')
plt.show()

# %%
####################概況：每週各名次的觀看人數####################

weekly_watch_0331_0406 = df_0331_0406['觀看人數'].astype("float64")
weekly_watch_0407_0413 = df_0407_0413['觀看人數'].astype("float64")
weekly_watch_0414_0420 = df_0414_0420['觀看人數'].astype("float64")
weekly_watch_0421_0427 = df_0421_0427['觀看人數'].astype("float64")
weekly_watch_0428_0504 = df_0428_0504['觀看人數'].astype("float64")

ALL_weekly_watch_DF = pd.DataFrame(
    {'weekly_watch_0331_0406': weekly_watch_0331_0406,
     'weekly_watch_0407_0413': weekly_watch_0407_0413,
     'weekly_watch_0414_0420': weekly_watch_0414_0420,
     'weekly_watch_0421_0427': weekly_watch_0421_0427,
     'weekly_watch_0428_0504': weekly_watch_0428_0504,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_watch_DF = ALL_weekly_watch_DF.rename(index=rows)
ALL_weekly_watch_DF_reverse = ALL_weekly_watch_DF.T

data = [ALL_weekly_watch_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的觀看人數')
plt.title('Weekly watch_04')
plt.xlabel('Ranking')
plt.ylabel('watch')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly watch_04')
plt.xlabel('Ranking')
plt.ylabel('watch')
plt.show()

# %%
####################概況：每週各名次的收藏人數####################

weekly_collection_0331_0406 = df_0331_0406['收藏人數'].astype("float64")
weekly_collection_0407_0413 = df_0407_0413['收藏人數'].astype("float64")
weekly_collection_0414_0420 = df_0414_0420['收藏人數'].astype("float64")
weekly_collection_0421_0427 = df_0421_0427['收藏人數'].astype("float64")
weekly_collection_0428_0504 = df_0428_0504['收藏人數'].astype("float64")

ALL_weekly_collection_DF = pd.DataFrame(
    {'weekly_collection_0331_0406': weekly_collection_0331_0406,
     'weekly_collection_0407_0413': weekly_collection_0407_0413,
     'weekly_collection_0414_0420': weekly_collection_0414_0420,
     'weekly_collection_0421_0427': weekly_collection_0421_0427,
     'weekly_collection_0428_0504': weekly_collection_0428_0504,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_collection_DF = ALL_weekly_collection_DF.rename(index=rows)
ALL_weekly_collection_DF_reverse = ALL_weekly_collection_DF.T

data = [ALL_weekly_collection_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的收藏人數')
plt.title('Weekly collection_04')
plt.xlabel('Ranking')
plt.ylabel('collection')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly collection_04')
plt.xlabel('Ranking')
plt.ylabel('collection')
plt.show()

# %%
####################概況：每週各名次的推薦人數####################

weekly_recommend_0331_0406 = df_0331_0406['推薦人數'].astype("float64")
weekly_recommend_0407_0413 = df_0407_0413['推薦人數'].astype("float64")
weekly_recommend_0414_0420 = df_0414_0420['推薦人數'].astype("float64")
weekly_recommend_0421_0427 = df_0421_0427['推薦人數'].astype("float64")
weekly_recommend_0428_0504 = df_0428_0504['推薦人數'].astype("float64")

ALL_weekly_recommend_DF = pd.DataFrame(
    {'weekly_recommend_0331_0406': weekly_recommend_0331_0406,
     'weekly_recommend_0407_0413': weekly_recommend_0407_0413,
     'weekly_recommend_0414_0420': weekly_recommend_0414_0420,
     'weekly_recommend_0421_0427': weekly_recommend_0421_0427,
     'weekly_recommend_0428_0504': weekly_recommend_0428_0504,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_recommend_DF = ALL_weekly_recommend_DF.rename(index=rows)
ALL_weekly_recommend_DF_reverse = ALL_weekly_recommend_DF.T

data = [ALL_weekly_recommend_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的推薦人數')
plt.title('Weekly recommend_04')
plt.xlabel('Ranking')
plt.ylabel('recommend')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly recommend_04')
plt.xlabel('Ranking')
plt.ylabel('recommend')
plt.show()

# %%
####################概況：每週各名次的多少人來過####################

weekly_visit_0331_0406 = df_0331_0406['多少人來過'].astype("float64")
weekly_visit_0407_0413 = df_0407_0413['多少人來過'].astype("float64")
weekly_visit_0414_0420 = df_0414_0420['多少人來過'].astype("float64")
weekly_visit_0421_0427 = df_0421_0427['多少人來過'].astype("float64")
weekly_visit_0428_0504 = df_0428_0504['多少人來過'].astype("float64")

ALL_weekly_visit_DF = pd.DataFrame(
    {'weekly_visit_0331_0406': weekly_visit_0331_0406,
     'weekly_visit_0407_0413': weekly_visit_0407_0413,
     'weekly_visit_0414_0420': weekly_visit_0414_0420,
     'weekly_visit_0421_0427': weekly_visit_0421_0427,
     'weekly_visit_0428_0504': weekly_visit_0428_0504,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_visit_DF = ALL_weekly_visit_DF.rename(index=rows)
ALL_weekly_visit_DF_reverse = ALL_weekly_visit_DF.T

data = [ALL_weekly_visit_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的多少人來過')
plt.title('Weekly visit_04')
plt.xlabel('Ranking')
plt.ylabel('visit')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly visit_04')
plt.xlabel('Ranking')
plt.ylabel('visit')
plt.show()

# %%
####################概況：每週各名次的多少篇食記####################

weekly_foodrecord_0331_0406 = df_0331_0406['多少篇食記'].astype("float64")
weekly_foodrecord_0407_0413 = df_0407_0413['多少篇食記'].astype("float64")
weekly_foodrecord_0414_0420 = df_0414_0420['多少篇食記'].astype("float64")
weekly_foodrecord_0421_0427 = df_0421_0427['多少篇食記'].astype("float64")
weekly_foodrecord_0428_0504 = df_0428_0504['多少篇食記'].astype("float64")

ALL_weekly_foodrecord_DF = pd.DataFrame(
    {'weekly_foodrecord_0331_0406': weekly_foodrecord_0331_0406,
     'weekly_foodrecord_0407_0413': weekly_foodrecord_0407_0413,
     'weekly_foodrecord_0414_0420': weekly_foodrecord_0414_0420,
     'weekly_foodrecord_0421_0427': weekly_foodrecord_0421_0427,
     'weekly_foodrecord_0428_0504': weekly_foodrecord_0428_0504,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_foodrecord_DF = ALL_weekly_foodrecord_DF.rename(index=rows)
ALL_weekly_foodrecord_DF_reverse = ALL_weekly_foodrecord_DF.T

data = [ALL_weekly_foodrecord_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的多少篇食記')
plt.title('Weekly foodrecord_04')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly foodrecord_04')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
plt.show()

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.ylim((0, 10))
#plt.title('每週各名次的多少篇食記')
plt.title('Weekly foodrecord_04(0~10)')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly foodrecord_04(0~10)')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
plt.show()

# %% [markdown]
# # 概況：每週資料整合(五月份)：

# %%
####################視覺化圖表####################
####################概況：每週各名次的評級####################

weekly_rating_0505_0511 = df_0505_0511['評級'].astype("float64")
weekly_rating_0512_0518 = df_0512_0518['評級'].astype("float64")
weekly_rating_0519_0525 = df_0519_0525['評級'].astype("float64")
weekly_rating_0526_0601 = df_0526_0601['評級'].astype("float64")

ALL_weekly_rating_DF = pd.DataFrame(
    {'weekly_rating_0505_0511': weekly_rating_0505_0511,
     'weekly_rating_0512_0518': weekly_rating_0512_0518,
     'weekly_rating_0519_0525': weekly_rating_0519_0525,
     'weekly_rating_0526_0601': weekly_rating_0526_0601,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_rating_DF = ALL_weekly_rating_DF.rename(index=rows)
ALL_weekly_rating_DF_reverse = ALL_weekly_rating_DF.T

data = [ALL_weekly_rating_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的評級')
plt.title('Weekly rating_05')
plt.xlabel('Ranking')
plt.ylabel('rating')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly rating_05')
plt.xlabel('Ranking')
plt.ylabel('rating')
plt.show()

# %%
####################概況：每週各名次的觀看人數####################

weekly_watch_0505_0511 = df_0505_0511['觀看人數'].astype("float64")
weekly_watch_0512_0518 = df_0512_0518['觀看人數'].astype("float64")
weekly_watch_0519_0525 = df_0519_0525['觀看人數'].astype("float64")
weekly_watch_0526_0601 = df_0526_0601['觀看人數'].astype("float64")

ALL_weekly_watch_DF = pd.DataFrame(
    {'weekly_watch_0505_0511': weekly_watch_0505_0511,
     'weekly_watch_0512_0518': weekly_watch_0512_0518,
     'weekly_watch_0519_0525': weekly_watch_0519_0525,
     'weekly_watch_0526_0601': weekly_watch_0526_0601,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_watch_DF = ALL_weekly_watch_DF.rename(index=rows)
ALL_weekly_watch_DF_reverse = ALL_weekly_watch_DF.T

data = [ALL_weekly_watch_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的觀看人數')
plt.title('Weekly watch_05')
plt.xlabel('Ranking')
plt.ylabel('watch')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly watch_05')
plt.xlabel('Ranking')
plt.ylabel('watch')
plt.show()

# %%
####################概況：每週各名次的收藏人數####################

weekly_collection_0505_0511 = df_0505_0511['收藏人數'].astype("float64")
weekly_collection_0512_0518 = df_0512_0518['收藏人數'].astype("float64")
weekly_collection_0519_0525 = df_0519_0525['收藏人數'].astype("float64")
weekly_collection_0526_0601 = df_0526_0601['收藏人數'].astype("float64")

ALL_weekly_collection_DF = pd.DataFrame(
    {'weekly_collection_0505_0511': weekly_collection_0505_0511,
     'weekly_collection_0512_0518': weekly_collection_0512_0518,
     'weekly_collection_0519_0525': weekly_collection_0519_0525,
     'weekly_collection_0526_0601': weekly_collection_0526_0601,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_collection_DF = ALL_weekly_collection_DF.rename(index=rows)
ALL_weekly_collection_DF_reverse = ALL_weekly_collection_DF.T

data = [ALL_weekly_collection_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的收藏人數')
plt.title('Weekly collection_05')
plt.xlabel('Ranking')
plt.ylabel('collection')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly collection_05')
plt.xlabel('Ranking')
plt.ylabel('collection')
plt.show()

# %%
####################概況：每週各名次的推薦人數####################

weekly_recommend_0505_0511 = df_0505_0511['推薦人數'].astype("float64")
weekly_recommend_0512_0518 = df_0512_0518['推薦人數'].astype("float64")
weekly_recommend_0519_0525 = df_0519_0525['推薦人數'].astype("float64")
weekly_recommend_0526_0601 = df_0526_0601['推薦人數'].astype("float64")

ALL_weekly_recommend_DF = pd.DataFrame(
    {'weekly_recommend_0505_0511': weekly_recommend_0505_0511,
     'weekly_recommend_0512_0518': weekly_recommend_0512_0518,
     'weekly_recommend_0519_0525': weekly_recommend_0519_0525,
     'weekly_recommend_0526_0601': weekly_recommend_0526_0601,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_recommend_DF = ALL_weekly_recommend_DF.rename(index=rows)
ALL_weekly_recommend_DF_reverse = ALL_weekly_recommend_DF.T

data = [ALL_weekly_recommend_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的推薦人數')
plt.title('Weekly recommend_05')
plt.xlabel('Ranking')
plt.ylabel('recommend')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly recommend_05')
plt.xlabel('Ranking')
plt.ylabel('recommend')
plt.show()

# %%
####################概況：每週各名次的多少人來過####################

weekly_visit_0505_0511 = df_0505_0511['多少人來過'].astype("float64")
weekly_visit_0512_0518 = df_0512_0518['多少人來過'].astype("float64")
weekly_visit_0519_0525 = df_0519_0525['多少人來過'].astype("float64")
weekly_visit_0526_0601 = df_0526_0601['多少人來過'].astype("float64")

ALL_weekly_visit_DF = pd.DataFrame(
    {'weekly_visit_0505_0511': weekly_visit_0505_0511,
     'weekly_visit_0512_0518': weekly_visit_0512_0518,
     'weekly_visit_0519_0525': weekly_visit_0519_0525,
     'weekly_visit_0526_0601': weekly_visit_0526_0601,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_visit_DF = ALL_weekly_visit_DF.rename(index=rows)
ALL_weekly_visit_DF_reverse = ALL_weekly_visit_DF.T

data = [ALL_weekly_visit_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的多少人來過')
plt.title('Weekly visit_05')
plt.xlabel('Ranking')
plt.ylabel('visit')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly visit_05')
plt.xlabel('Ranking')
plt.ylabel('visit')
plt.show()

# %%
####################概況：每週各名次的多少篇食記####################

weekly_foodrecord_0505_0511 = df_0505_0511['多少篇食記'].astype("float64")
weekly_foodrecord_0512_0518 = df_0512_0518['多少篇食記'].astype("float64")
weekly_foodrecord_0519_0525 = df_0519_0525['多少篇食記'].astype("float64")
weekly_foodrecord_0526_0601 = df_0526_0601['多少篇食記'].astype("float64")

ALL_weekly_foodrecord_DF = pd.DataFrame(
    {'weekly_foodrecord_0505_0511': weekly_foodrecord_0505_0511,
     'weekly_foodrecord_0512_0518': weekly_foodrecord_0512_0518,
     'weekly_foodrecord_0519_0525': weekly_foodrecord_0519_0525,
     'weekly_foodrecord_0526_0601': weekly_foodrecord_0526_0601,
    })

rows = {0:'第一名',1:'第二名',2:'第三名',3:'第四名',4:'第五名',5:'第六名',6:'第七名',7:'第八名',8:'第九名',9:'第十名',10:'第十一名',11:'第十二名',12:'第十三名',13:'第十四名',14:'第十五名',15:'第十六名',16:'第十七名',17:'第十八名',18:'第十九名',19:'第二十名'} 

ALL_weekly_foodrecord_DF = ALL_weekly_foodrecord_DF.rename(index=rows)
ALL_weekly_foodrecord_DF_reverse = ALL_weekly_foodrecord_DF.T

data = [ALL_weekly_foodrecord_DF_reverse.iloc[:,i].astype("float64") for i in range(0,20)]
#labels = ['第一名','第二名','第三名','第四名','第五名','第六名','第七名','第八名','第九名','第十名','第十一名','第十二名','第十三名','第十四名','第十五名','第十六名','第十七名','第十八名','第十九名','第二十名']
labels = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
#plt.ylim((2.5, 5.1))
#plt.title('每週各名次的多少篇食記')
plt.title('Weekly foodrecord_05')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly foodrecord_05')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
plt.show()

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.ylim((0, 10))
#plt.title('每週各名次的多少篇食記')
plt.title('Weekly foodrecord_05(0~10)')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels)
plt.title('Weekly foodrecord_05(0~10)')
plt.xlabel('Ranking')
plt.ylabel('foodrecord')
plt.show()
