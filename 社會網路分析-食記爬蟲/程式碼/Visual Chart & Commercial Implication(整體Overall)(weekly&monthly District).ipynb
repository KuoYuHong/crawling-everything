# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#視覺化圖表
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import math
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use('ggplot')
warnings.filterwarnings('ignore')
####################讀取檔案####################
df_0331_0406 = pd.read_csv('weekly_0331~0406.csv')
df_0407_0413 = pd.read_csv('weekly_0407~0413.csv')
df_0414_0420 = pd.read_csv('weekly_0414~0420.csv')
df_0421_0427 = pd.read_csv('weekly_0421~0427.csv')
df_0428_0504 = pd.read_csv('weekly_0428~0504.csv')
df_0505_0511 = pd.read_csv('weekly_0505~0511.csv')
df_0512_0518 = pd.read_csv('weekly_0512~0518.csv')
df_0519_0525 = pd.read_csv('weekly_0519~0525.csv')
df_0526_0601 = pd.read_csv('weekly_0526~0601.csv')
df_03 = pd.read_csv('monthly_03.csv')
df_04 = pd.read_csv('monthly_04.csv')
df_05 = pd.read_csv('monthly_05.csv')

####################資料處理####################0331_0406
rating_mean = "%.1f" % df_0331_0406.loc[df_0331_0406['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0331_0406['評級'][13] = df_0331_0406['評級'][13].replace("無紀錄", rating_mean)
df_0331_0406['評級'][16] = df_0331_0406['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0331_0406['多少人來過'][i] = df_0331_0406['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0331_0406.loc[df_0331_0406['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0331_0406['多少人來過'][13] = df_0331_0406['多少人來過'][13].replace("無紀錄", str(round(float(visit_mean))))
for i in range(0,20):
    df_0331_0406['多少篇食記'][i] = df_0331_0406['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0331_0406.loc[df_0331_0406['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0331_0406['多少篇食記'][13] = df_0331_0406['多少篇食記'][13].replace("無紀錄", str(round(float(visit_mean))))
##print(df_0331_0406)

####################資料處理####################0407_0413
rating_mean = "%.1f" % df_0407_0413.loc[df_0407_0413['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0407_0413['評級'][1] = df_0407_0413['評級'][1].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0407_0413['評級'][3] = df_0407_0413['評級'][3].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0407_0413['評級'][15] = df_0407_0413['評級'][15].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0407_0413['評級'][18] = df_0407_0413['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0407_0413['評級'][19] = df_0407_0413['評級'][19].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0407_0413['多少人來過'][i] = df_0407_0413['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_0407_0413['多少篇食記'][i] = df_0407_0413['多少篇食記'][i].replace("篇食記", "")
#print(df_0407_0413)

####################資料處理####################0414_0420
rating_mean = "%.1f" % df_0414_0420.loc[df_0414_0420['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0414_0420['評級'][3] = df_0414_0420['評級'][3].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0414_0420['評級'][16] = df_0414_0420['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0414_0420['評級'][19] = df_0414_0420['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0414_0420['多少人來過'][i] = df_0414_0420['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0414_0420.loc[df_0414_0420['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0414_0420['多少人來過'][19] = df_0414_0420['多少人來過'][19].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0414_0420['多少篇食記'][i] = df_0414_0420['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0414_0420.loc[df_0414_0420['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0414_0420['多少篇食記'][19] = df_0414_0420['多少篇食記'][19].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0414_0420)

####################資料處理####################0421_0427
rating_mean = "%.1f" % df_0421_0427.loc[df_0421_0427['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0421_0427['評級'][2] = df_0421_0427['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0421_0427['評級'][5] = df_0421_0427['評級'][5].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0421_0427['評級'][17] = df_0421_0427['評級'][17].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0421_0427['評級'][18] = df_0421_0427['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0421_0427['多少人來過'][i] = df_0421_0427['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_0421_0427['多少篇食記'][i] = df_0421_0427['多少篇食記'][i].replace("篇食記", "")
#print(df_0421_0427)

####################資料處理####################0428_0504
rating_mean = "%.1f" % df_0428_0504.loc[df_0428_0504['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0428_0504['評級'][4] = df_0428_0504['評級'][4].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0428_0504['評級'][5] = df_0428_0504['評級'][5].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
for i in range(0,20):
    df_0428_0504['多少人來過'][i] = df_0428_0504['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_0428_0504['多少篇食記'][i] = df_0428_0504['多少篇食記'][i].replace("篇食記", "")
#print(df_0428_0504)

####################資料處理####################0505_0511
df_0505_0511['評級'][6] = df_0505_0511['評級'][6].replace("無紀錄", rating_mean)
df_0505_0511['評級'][16] = df_0505_0511['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0505_0511['評級'][17] = df_0505_0511['評級'][17].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0505_0511['評級'][18] = df_0505_0511['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0505_0511['多少人來過'][i] = df_0505_0511['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0505_0511.loc[df_0505_0511['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0505_0511['多少人來過'][16] = df_0505_0511['多少人來過'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
df_0505_0511['多少人來過'][18] = df_0505_0511['多少人來過'][18].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0505_0511['多少篇食記'][i] = df_0505_0511['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0505_0511.loc[df_0505_0511['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0505_0511['多少篇食記'][16] = df_0505_0511['多少篇食記'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
df_0505_0511['多少篇食記'][18] = df_0505_0511['多少篇食記'][18].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0505_0511)

####################資料處理####################0512_0518
rating_mean = "%.1f" % df_0512_0518.loc[df_0512_0518['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0512_0518['評級'][2] = df_0512_0518['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0512_0518['評級'][5] = df_0512_0518['評級'][5].replace("無紀錄", rating_mean)
df_0512_0518['評級'][11] = df_0512_0518['評級'][11].replace("無紀錄", rating_mean)
df_0512_0518['評級'][16] = df_0512_0518['評級'][16].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
df_0512_0518['評級'][18] = df_0512_0518['評級'][18].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0512_0518['多少人來過'][i] = df_0512_0518['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0512_0518.loc[df_0512_0518['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0512_0518['多少人來過'][11] = df_0512_0518['多少人來過'][11].replace("無紀錄", str(int(float(visit_mean))))
df_0512_0518['多少人來過'][16] = df_0512_0518['多少人來過'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0512_0518['多少篇食記'][i] = df_0512_0518['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0512_0518.loc[df_0512_0518['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0512_0518['多少篇食記'][11] = df_0512_0518['多少篇食記'][11].replace("無紀錄", str(int(float(visit_mean))))
df_0512_0518['多少篇食記'][16] = df_0512_0518['多少篇食記'][16].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0512_0518)

####################資料處理####################0519_0525
rating_mean = "%.1f" % df_0519_0525.loc[df_0519_0525['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0519_0525['評級'][6] = df_0519_0525['評級'][6].replace("無紀錄", rating_mean)
df_0519_0525['評級'][15] = df_0519_0525['評級'][15].replace("無紀錄", str(round(float(rating_mean)*0.95,1)))
for i in range(0,20):
    df_0519_0525['多少人來過'][i] = df_0519_0525['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0519_0525.loc[df_0519_0525['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0519_0525['多少人來過'][6] = df_0519_0525['多少人來過'][6].replace("無紀錄", str(int(float(visit_mean))))
df_0519_0525['多少人來過'][15] = df_0519_0525['多少人來過'][15].replace("無紀錄", str(int(float(visit_mean)*0.8)))
for i in range(0,20):
    df_0519_0525['多少篇食記'][i] = df_0519_0525['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0519_0525.loc[df_0519_0525['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0519_0525['多少篇食記'][6] = df_0519_0525['多少篇食記'][6].replace("無紀錄", str(int(float(visit_mean))))
df_0519_0525['多少篇食記'][15] = df_0519_0525['多少篇食記'][15].replace("無紀錄", str(int(float(visit_mean)*0.8)))
#print(df_0519_0525)

####################資料處理####################0526_0601
rating_mean = "%.1f" % df_0526_0601.loc[df_0526_0601['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_0526_0601['評級'][1] = df_0526_0601['評級'][1].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_0526_0601['評級'][14] = df_0526_0601['評級'][14].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_0526_0601['多少人來過'][i] = df_0526_0601['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_0526_0601.loc[df_0526_0601['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_0526_0601['多少人來過'][1] = df_0526_0601['多少人來過'][1].replace("無紀錄", str(int(float(visit_mean)*1.2)))
df_0526_0601['多少人來過'][14] = df_0526_0601['多少人來過'][14].replace("無紀錄", str(int(float(visit_mean))))
for i in range(0,20):
    df_0526_0601['多少篇食記'][i] = df_0526_0601['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_0526_0601.loc[df_0526_0601['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_0526_0601['多少篇食記'][1] = df_0526_0601['多少篇食記'][1].replace("無紀錄", str(int(float(visit_mean)*1.2)))
df_0526_0601['多少篇食記'][14] = df_0526_0601['多少篇食記'][14].replace("無紀錄", str(int(float(visit_mean))))
#print(df_0526_0601)

####################資料處理####################03
rating_mean = "%.1f" % df_03.loc[df_03['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_03['評級'][2] = df_03['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_03['評級'][11] = df_03['評級'][11].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_03['多少人來過'][i] = df_03['多少人來過'][i].replace("人來過", "")
visit_mean = "%.1f" % df_03.loc[df_03['多少人來過'] != "無紀錄",'多少人來過'].astype("float64").mean()
df_03['多少人來過'][11] = df_03['多少人來過'][11].replace("無紀錄", str(round(float(visit_mean))))
for i in range(0,20):
    df_03['多少篇食記'][i] = df_03['多少篇食記'][i].replace("篇食記", "")
visit_mean = "%.1f" % df_03.loc[df_03['多少篇食記'] != "無紀錄",'多少篇食記'].astype("float64").mean()
df_03['多少篇食記'][11] = df_03['多少篇食記'][11].replace("無紀錄", str(round(float(visit_mean))))
#print(df_03)

####################資料處理####################04
rating_mean = "%.1f" % df_04.loc[df_04['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_04['評級'][5] = df_04['評級'][2].replace("無紀錄", str(round(float(rating_mean)*1.05,1)))
df_04['評級'][11] = df_04['評級'][11].replace("無紀錄", rating_mean)
df_04['評級'][12] = df_04['評級'][12].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_04['多少人來過'][i] = df_04['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_04['多少篇食記'][i] = df_04['多少篇食記'][i].replace("篇食記", "")
#print(df_04)

####################資料處理####################05
rating_mean = "%.1f" % df_05.loc[df_05['評級'] != "無紀錄",'評級'].astype("float64").mean()
df_05['評級'][7] = df_05['評級'][7].replace("無紀錄", rating_mean)
for i in range(0,20):
    df_05['多少人來過'][i] = df_05['多少人來過'][i].replace("人來過", "")
for i in range(0,20):
    df_05['多少篇食記'][i] = df_05['多少篇食記'][i].replace("篇食記", "")
#print(df_05)

########################################
#0331_0406
#0407_0413
#0414_0420
#0421_0427
#0428_0504
#0505_0511
#0512_0518
#0519_0525
#0526_0601
#03
#04
#05

#print(df_0331_0406.loc[df_0331_0406['評級'] == "無紀錄",'評級'].values[0])#某個row的值
#print(df_0331_0406[df_0331_0406['評級'] == "無紀錄"].index.tolist()[0])#列出目標是在哪個row
#print(df_0331_0406.iloc[:,3])#取出該column的所有row

# %%
print(df_0526_0601['美食所在區域'].value_counts())
# Out:
# 松山區    4
# 中正區    3
# 士林區    3
# 大安區    3
# 中山區    2
# 信義區    2
# 板橋區    1
# 大同區    1
# 萬華區    1
# Name: 美食所在區域, dtype: int64

# %% [markdown]
# # 整體：每週各區域：

# %%
####################視覺化圖表####################
####################整體：每週各區域的評級####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有評級####################
weekly_rating_0331_0406_district_Daan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Zhongzheng_District = df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Zhongshan_Area = df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Datong_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Songshan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Yonghe_District = df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Shilin_District = df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['評級'].to_frame()
weekly_rating_0331_0406_district_Banqiao_District = df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['評級'].to_frame()

weekly_rating_0407_0413_district_Shilin_District = df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Zhongshan_Area = df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Triple_area = df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Xinyi_District = df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Daan_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Wanhua_District = df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Zhongzheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Datong_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Yonghe_District = df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Tucheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['評級'].to_frame()
weekly_rating_0407_0413_district_Banqiao_District = df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['評級'].to_frame()

weekly_rating_0414_0420_district_Zhongshan_Area = df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0414_0420_district_Daan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0414_0420_district_Songshan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['評級'].to_frame()
weekly_rating_0414_0420_district_Shilin_District = df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['評級'].to_frame()
weekly_rating_0414_0420_district_Wanhua_District = df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['評級'].to_frame()
weekly_rating_0414_0420_district_Datong_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0414_0420_district_Zhongzheng_District = df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['評級'].to_frame()

weekly_rating_0421_0427_district_Zhongshan_Area = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Datong_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Daan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Zhongzheng_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Songshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Neihu_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Shilin_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Wanhua_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Linkou_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0421_0427_district_Wenshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame()

weekly_rating_0428_0504_district_Daan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Zhongshan_Area = df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Songshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Datong_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Xinyi_District = df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Taishan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Shilin_District = df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Zhongzheng_District = df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0428_0504_district_Wenshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['評級'].to_frame()

weekly_rating_0505_0511_district_Songshan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Zhongzheng_District = df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Yonghe_District = df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Wanhua_District = df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Xinyi_District = df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Zhongshan_Area = df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Datong_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Triple_area = df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Daan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0505_0511_district_Neihu_District = df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['評級'].to_frame()

weekly_rating_0512_0518_district_Zhongshan_Area = df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Daan_District = df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Triple_area = df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Zhongzheng_District = df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Xinyi_District = df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Shilin_District = df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Xindian_District = df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Linkou_District = df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['評級'].to_frame()
weekly_rating_0512_0518_district_Yonghe_District = df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['評級'].to_frame()

weekly_rating_0519_0525_district_Zhongshan_Area = df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Daan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Songshan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Zhongzheng_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Banqiao_District = df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Triple_area = df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Wanhua_District = df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Datong_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Xinyi_District = df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['評級'].to_frame()
weekly_rating_0519_0525_district_Zhonghe_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['評級'].to_frame()

weekly_rating_0526_0601_district_Songshan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Zhongzheng_District = df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Shilin_District = df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Daan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Zhongshan_Area = df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Xinyi_District = df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Banqiao_District = df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Datong_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['評級'].to_frame()
weekly_rating_0526_0601_district_Wanhua_District = df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['評級'].to_frame()

####################將同一區域的所有評級整合起來####################
weekly_rating_district_Zhongzheng_District = pd.concat([weekly_rating_0331_0406_district_Zhongzheng_District,weekly_rating_0407_0413_district_Zhongzheng_District,weekly_rating_0414_0420_district_Zhongzheng_District,weekly_rating_0421_0427_district_Zhongzheng_District,weekly_rating_0428_0504_district_Zhongzheng_District,weekly_rating_0505_0511_district_Zhongzheng_District,weekly_rating_0512_0518_district_Zhongzheng_District,weekly_rating_0519_0525_district_Zhongzheng_District,weekly_rating_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'評級':'Zhongzheng_District'})
weekly_rating_district_Shilin_District = pd.concat([weekly_rating_0331_0406_district_Shilin_District,weekly_rating_0407_0413_district_Shilin_District,weekly_rating_0414_0420_district_Shilin_District,weekly_rating_0421_0427_district_Shilin_District,weekly_rating_0428_0504_district_Shilin_District,weekly_rating_0512_0518_district_Shilin_District,weekly_rating_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'評級':'Shilin_District'})
weekly_rating_district_Zhongshan_Area = pd.concat([weekly_rating_0331_0406_district_Zhongshan_Area,weekly_rating_0407_0413_district_Zhongshan_Area,weekly_rating_0414_0420_district_Zhongshan_Area,weekly_rating_0421_0427_district_Zhongshan_Area,weekly_rating_0428_0504_district_Zhongshan_Area,weekly_rating_0505_0511_district_Zhongshan_Area,weekly_rating_0512_0518_district_Zhongshan_Area,weekly_rating_0519_0525_district_Zhongshan_Area,weekly_rating_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'評級':'Zhongshan_Area'})
weekly_rating_district_Datong_District = pd.concat([weekly_rating_0331_0406_district_Datong_District,weekly_rating_0407_0413_district_Datong_District,weekly_rating_0414_0420_district_Datong_District,weekly_rating_0421_0427_district_Datong_District,weekly_rating_0428_0504_district_Datong_District,weekly_rating_0505_0511_district_Datong_District,weekly_rating_0519_0525_district_Datong_District,weekly_rating_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'評級':'Datong_District'})
weekly_rating_district_Daan_District = pd.concat([weekly_rating_0331_0406_district_Daan_District,weekly_rating_0407_0413_district_Daan_District,weekly_rating_0414_0420_district_Daan_District,weekly_rating_0421_0427_district_Daan_District,weekly_rating_0428_0504_district_Daan_District,weekly_rating_0505_0511_district_Daan_District,weekly_rating_0512_0518_district_Daan_District,weekly_rating_0519_0525_district_Daan_District,weekly_rating_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'評級':'Daan_District'})
weekly_rating_district_Songshan_District = pd.concat([weekly_rating_0331_0406_district_Songshan_District,weekly_rating_0414_0420_district_Songshan_District,weekly_rating_0421_0427_district_Songshan_District,weekly_rating_0428_0504_district_Songshan_District,weekly_rating_0505_0511_district_Songshan_District,weekly_rating_0519_0525_district_Songshan_District,weekly_rating_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'評級':'Songshan_District'})
weekly_rating_district_Wanhua_District = pd.concat([weekly_rating_0407_0413_district_Wanhua_District,weekly_rating_0414_0420_district_Wanhua_District,weekly_rating_0421_0427_district_Wanhua_District,weekly_rating_0505_0511_district_Wanhua_District,weekly_rating_0519_0525_district_Wanhua_District,weekly_rating_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'評級':'Wanhua_District'})
weekly_rating_district_Xinyi_District = pd.concat([weekly_rating_0407_0413_district_Xinyi_District,weekly_rating_0428_0504_district_Xinyi_District,weekly_rating_0505_0511_district_Xinyi_District,weekly_rating_0512_0518_district_Xinyi_District,weekly_rating_0519_0525_district_Xinyi_District,weekly_rating_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'評級':'Xinyi_District'})
weekly_rating_district_Yonghe_District = pd.concat([weekly_rating_0331_0406_district_Yonghe_District,weekly_rating_0407_0413_district_Yonghe_District,weekly_rating_0505_0511_district_Yonghe_District,weekly_rating_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'評級':'Yonghe_District'})
weekly_rating_district_Wenshan_District = pd.concat([weekly_rating_0421_0427_district_Wenshan_District,weekly_rating_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'評級':'Wenshan_District'})
weekly_rating_district_Banqiao_District = pd.concat([weekly_rating_0331_0406_district_Banqiao_District,weekly_rating_0407_0413_district_Banqiao_District,weekly_rating_0519_0525_district_Banqiao_District,weekly_rating_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'評級':'Banqiao_District'})
weekly_rating_district_Neihu_District = pd.concat([weekly_rating_0421_0427_district_Neihu_District,weekly_rating_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'評級':'Neihu_District'})
weekly_rating_district_Triple_area = pd.concat([weekly_rating_0407_0413_district_Triple_area,weekly_rating_0505_0511_district_Triple_area,weekly_rating_0512_0518_district_Triple_area,weekly_rating_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'評級':'Triple_area'})
weekly_rating_district_Tucheng_District = pd.concat([weekly_rating_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'評級':'Tucheng_District'})
weekly_rating_district_Taishan_District = pd.concat([weekly_rating_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'評級':'Taishan_District'})
weekly_rating_district_Linkou_District = pd.concat([weekly_rating_0421_0427_district_Linkou_District,weekly_rating_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'評級':'Linkou_District'})
weekly_rating_district_Xindian_District = pd.concat([weekly_rating_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'評級':'Xindian_District'})
weekly_rating_district_Zhonghe_District = pd.concat([weekly_rating_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'評級':'Zhonghe_District'})

data = [weekly_rating_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_rating_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_rating_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_rating_district_Datong_District['Datong_District'].astype("float64").values,weekly_rating_district_Daan_District['Daan_District'].astype("float64").values,weekly_rating_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_rating_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_rating_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_rating_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_rating_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_rating_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_rating_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_rating_district_Triple_area['Triple_area'].astype("float64").values,weekly_rating_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_rating_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_rating_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_rating_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_rating_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每週各區域的美食評級')
plt.title('District Weekly rating')
plt.xlabel('district')
plt.ylabel('rating')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District Weekly rating')
plt.xlabel('district')
plt.ylabel('rating')
plt.show()

'''0331_0406
大安區 Daan_District
中正區 Zhongzheng_District
中山區 Zhongshan_Area
大同區 Datong_District
松山區 Songshan_District
永和區 Yonghe_District
士林區 Shilin_District
板橋區 Banqiao_District
'''
'''0407_0413
士林區 Shilin_District
中山區 Zhongshan_Area
三重區 Triple_area
信義區 Xinyi_District
大安區 Daan_District
萬華區 Wanhua_District
中正區 Zhongzheng_District
大同區 Datong_District
永和區 Yonghe_District
土城區 Tucheng_District
板橋區 Banqiao_District
'''
'''0414_0420
中山區 Zhongshan_Area
大安區 Daan_District
松山區 Songshan_District
士林區 Shilin_District
萬華區 Wanhua_District
大同區 Datong_District
中正區 Zhongzheng_District
'''
'''0421_0427
中山區 Zhongshan_Area
大同區 Datong_District
大安區 Daan_District
中正區 Zhongzheng_District
松山區 Songshan_District
內湖區 Neihu_District
士林區 Shilin_District
萬華區 Wanhua_District
林口區 Linkou_District
文山區 Wenshan_District
'''
'''0428_0504
大安區 Daan_District
中山區 Zhongshan_Area
松山區 Songshan_District
大同區 Datong_District
信義區 Xinyi_District
泰山區 Taishan_District
士林區 Shilin_District
中正區 Zhongzheng_District
文山區 Wenshan_District
'''
'''0505_0511
松山區 Songshan District
中正區 Zhongzheng District
永和區 Yonghe District
萬華區 Wanhua District
信義區 Xinyi District
中山區 Zhongshan Area
大同區 Datong District
三重區 Triple area
大安區 Daan District
內湖區 Neihu District
'''
'''0512_0518
中山區 Zhongshan Area
大安區 Daan District
三重區 Triple area
中正區 Zhongzheng District
信義區 Xinyi District
士林區 Shilin District
新店區 Xindian District
林口區 Linkou District
永和區 Yonghe District
'''
'''0519_0525
中山區 Zhong han_Area
大安區 Daan District
松山區 Songshan District
中正區 Zhongzheng District
板橋區 Banqiao District
三重區 Triple area
萬華區 Wanhua District
大同區 Datong District
信義區 Xinyi District
中和區 Zhonghe District
'''
'''0526_0601
松山區 Songshan District
中正區 Zhongzheng District
士林區 Shilin District
大安區 Daan District
中山區 Zhongshan Area
信義區 Xinyi District
板橋區 Banqiao District
大同區 Datong District
萬華區 Wanhua District
'''
# Out:
# '0526_0601\n松山區 Songshan District\n中正區 Zhongzheng District\n士林區 Shilin District\n大安區 Daan District\n中山區 Zhongshan Area\n信義區 Xinyi District\n板橋區 Banqiao District\n大同區 Datong District\n萬華區 Wanhua District\n'

# %%
#查看所有週數當中總共有哪些不重複行政區
a = ['大安區','中正區','中山區','大同區','松山區','永和區','士林區','板橋區','士林區','中山區','三重區','信義區','大安區','萬華區','中正區','大同區','永和區','土城區','板橋區','中山區','大安區','松山區','士林區','萬華區','大同區','中正區','中山區','大同區','大安區','中正區','松山區','內湖區','士林區','萬華區','林口區','文山區','大安區','中山區','松山區','大同區','信義區','泰山區','士林區','中正區','文山區','松山區','中正區','永和區','萬華區','信義區','中山區','大同區','三重區','大安區','內湖區']
a = pd.DataFrame(a) 
#print(a)
print(type(a))
print(a[0].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 大安區    6
# 中正區    6
# 中山區    6
# 大同區    6
# 松山區    5
# 士林區    5
# 萬華區    4
# 信義區    3
# 永和區    3
# 文山區    2
# 三重區    2
# 板橋區    2
# 內湖區    2
# 泰山區    1
# 林口區    1
# 土城區    1
# Name: 0, dtype: int64

# %%
####################視覺化圖表####################
####################整體：每週各區域的觀看人數####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有觀看人數####################
weekly_watch_0331_0406_district_Daan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Zhongzheng_District = df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Zhongshan_Area = df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Datong_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Songshan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Yonghe_District = df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Shilin_District = df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
weekly_watch_0331_0406_district_Banqiao_District = df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['觀看人數'].to_frame()

weekly_watch_0407_0413_district_Shilin_District = df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Zhongshan_Area = df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Triple_area = df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Xinyi_District = df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Daan_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Wanhua_District = df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Zhongzheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Datong_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Yonghe_District = df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Tucheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['觀看人數'].to_frame()
weekly_watch_0407_0413_district_Banqiao_District = df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['觀看人數'].to_frame()

weekly_watch_0414_0420_district_Zhongshan_Area = df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0414_0420_district_Daan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0414_0420_district_Songshan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
weekly_watch_0414_0420_district_Shilin_District = df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
weekly_watch_0414_0420_district_Wanhua_District = df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()
weekly_watch_0414_0420_district_Datong_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0414_0420_district_Zhongzheng_District = df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['觀看人數'].to_frame()

weekly_watch_0421_0427_district_Zhongshan_Area = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Datong_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Daan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Zhongzheng_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Songshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Neihu_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Shilin_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Wanhua_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Linkou_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0421_0427_district_Wenshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['觀看人數'].to_frame()

weekly_watch_0428_0504_district_Daan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Zhongshan_Area = df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Songshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Datong_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Xinyi_District = df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Taishan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Shilin_District = df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Zhongzheng_District = df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0428_0504_district_Wenshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['觀看人數'].to_frame()

weekly_watch_0505_0511_district_Songshan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Zhongzheng_District = df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Yonghe_District = df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Wanhua_District = df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Xinyi_District = df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Zhongshan_Area = df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Datong_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Triple_area = df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Daan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0505_0511_district_Neihu_District = df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['觀看人數'].to_frame()

weekly_watch_0512_0518_district_Zhongshan_Area = df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Daan_District = df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Triple_area = df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Zhongzheng_District = df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Xinyi_District = df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Shilin_District = df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Xindian_District = df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Linkou_District = df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['觀看人數'].to_frame()
weekly_watch_0512_0518_district_Yonghe_District = df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['觀看人數'].to_frame()

weekly_watch_0519_0525_district_Zhongshan_Area = df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Daan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Songshan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Zhongzheng_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Banqiao_District = df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Triple_area = df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Wanhua_District = df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Datong_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Xinyi_District = df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
weekly_watch_0519_0525_district_Zhonghe_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['觀看人數'].to_frame()

weekly_watch_0526_0601_district_Songshan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Zhongzheng_District = df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Shilin_District = df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Daan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Zhongshan_Area = df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Xinyi_District = df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Banqiao_District = df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Datong_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
weekly_watch_0526_0601_district_Wanhua_District = df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()

####################將同一區域的所有觀看人數整合起來####################
weekly_watch_district_Zhongzheng_District = pd.concat([weekly_watch_0331_0406_district_Zhongzheng_District,weekly_watch_0407_0413_district_Zhongzheng_District,weekly_watch_0414_0420_district_Zhongzheng_District,weekly_watch_0421_0427_district_Zhongzheng_District,weekly_watch_0428_0504_district_Zhongzheng_District,weekly_watch_0505_0511_district_Zhongzheng_District,weekly_watch_0512_0518_district_Zhongzheng_District,weekly_watch_0519_0525_district_Zhongzheng_District,weekly_watch_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'觀看人數':'Zhongzheng_District'})
weekly_watch_district_Shilin_District = pd.concat([weekly_watch_0331_0406_district_Shilin_District,weekly_watch_0407_0413_district_Shilin_District,weekly_watch_0414_0420_district_Shilin_District,weekly_watch_0421_0427_district_Shilin_District,weekly_watch_0428_0504_district_Shilin_District,weekly_watch_0512_0518_district_Shilin_District,weekly_watch_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'觀看人數':'Shilin_District'})
weekly_watch_district_Zhongshan_Area = pd.concat([weekly_watch_0331_0406_district_Zhongshan_Area,weekly_watch_0407_0413_district_Zhongshan_Area,weekly_watch_0414_0420_district_Zhongshan_Area,weekly_watch_0421_0427_district_Zhongshan_Area,weekly_watch_0428_0504_district_Zhongshan_Area,weekly_watch_0505_0511_district_Zhongshan_Area,weekly_watch_0512_0518_district_Zhongshan_Area,weekly_watch_0519_0525_district_Zhongshan_Area,weekly_watch_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'觀看人數':'Zhongshan_Area'})
weekly_watch_district_Datong_District = pd.concat([weekly_watch_0331_0406_district_Datong_District,weekly_watch_0407_0413_district_Datong_District,weekly_watch_0414_0420_district_Datong_District,weekly_watch_0421_0427_district_Datong_District,weekly_watch_0428_0504_district_Datong_District,weekly_watch_0505_0511_district_Datong_District,weekly_watch_0519_0525_district_Datong_District,weekly_watch_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'觀看人數':'Datong_District'})
weekly_watch_district_Daan_District = pd.concat([weekly_watch_0331_0406_district_Daan_District,weekly_watch_0407_0413_district_Daan_District,weekly_watch_0414_0420_district_Daan_District,weekly_watch_0421_0427_district_Daan_District,weekly_watch_0428_0504_district_Daan_District,weekly_watch_0505_0511_district_Daan_District,weekly_watch_0512_0518_district_Daan_District,weekly_watch_0519_0525_district_Daan_District,weekly_watch_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'觀看人數':'Daan_District'})
weekly_watch_district_Songshan_District = pd.concat([weekly_watch_0331_0406_district_Songshan_District,weekly_watch_0414_0420_district_Songshan_District,weekly_watch_0421_0427_district_Songshan_District,weekly_watch_0428_0504_district_Songshan_District,weekly_watch_0505_0511_district_Songshan_District,weekly_watch_0519_0525_district_Songshan_District,weekly_watch_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'觀看人數':'Songshan_District'})
weekly_watch_district_Wanhua_District = pd.concat([weekly_watch_0407_0413_district_Wanhua_District,weekly_watch_0414_0420_district_Wanhua_District,weekly_watch_0421_0427_district_Wanhua_District,weekly_watch_0505_0511_district_Wanhua_District,weekly_watch_0519_0525_district_Wanhua_District,weekly_watch_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'觀看人數':'Wanhua_District'})
weekly_watch_district_Xinyi_District = pd.concat([weekly_watch_0407_0413_district_Xinyi_District,weekly_watch_0428_0504_district_Xinyi_District,weekly_watch_0505_0511_district_Xinyi_District,weekly_watch_0512_0518_district_Xinyi_District,weekly_watch_0519_0525_district_Xinyi_District,weekly_watch_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'觀看人數':'Xinyi_District'})
weekly_watch_district_Yonghe_District = pd.concat([weekly_watch_0331_0406_district_Yonghe_District,weekly_watch_0407_0413_district_Yonghe_District,weekly_watch_0505_0511_district_Yonghe_District,weekly_watch_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'觀看人數':'Yonghe_District'})
weekly_watch_district_Wenshan_District = pd.concat([weekly_watch_0421_0427_district_Wenshan_District,weekly_watch_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'觀看人數':'Wenshan_District'})
weekly_watch_district_Banqiao_District = pd.concat([weekly_watch_0331_0406_district_Banqiao_District,weekly_watch_0407_0413_district_Banqiao_District,weekly_watch_0519_0525_district_Banqiao_District,weekly_watch_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'觀看人數':'Banqiao_District'})
weekly_watch_district_Neihu_District = pd.concat([weekly_watch_0421_0427_district_Neihu_District,weekly_watch_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'觀看人數':'Neihu_District'})
weekly_watch_district_Triple_area = pd.concat([weekly_watch_0407_0413_district_Triple_area,weekly_watch_0505_0511_district_Triple_area,weekly_watch_0512_0518_district_Triple_area,weekly_watch_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'觀看人數':'Triple_area'})
weekly_watch_district_Tucheng_District = pd.concat([weekly_watch_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'觀看人數':'Tucheng_District'})
weekly_watch_district_Taishan_District = pd.concat([weekly_watch_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'觀看人數':'Taishan_District'})
weekly_watch_district_Linkou_District = pd.concat([weekly_watch_0421_0427_district_Linkou_District,weekly_watch_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'觀看人數':'Linkou_District'})
weekly_watch_district_Xindian_District = pd.concat([weekly_watch_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'觀看人數':'Xindian_District'})
weekly_watch_district_Zhonghe_District = pd.concat([weekly_watch_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'觀看人數':'Zhonghe_District'})

data = [weekly_watch_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_watch_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_watch_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_watch_district_Datong_District['Datong_District'].astype("float64").values,weekly_watch_district_Daan_District['Daan_District'].astype("float64").values,weekly_watch_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_watch_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_watch_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_watch_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_watch_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_watch_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_watch_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_watch_district_Triple_area['Triple_area'].astype("float64").values,weekly_watch_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_watch_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_watch_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_watch_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_watch_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每週各區域的美食觀看人數')
plt.title('District Weekly watch')
plt.xlabel('district')
plt.ylabel('watch')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District Weekly watch')
plt.xlabel('district')
plt.ylabel('watch')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每週各區域的收藏人數####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有收藏人數####################
weekly_collection_0331_0406_district_Daan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Zhongzheng_District = df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Zhongshan_Area = df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Datong_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Songshan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Yonghe_District = df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Shilin_District = df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
weekly_collection_0331_0406_district_Banqiao_District = df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['收藏人數'].to_frame()

weekly_collection_0407_0413_district_Shilin_District = df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Zhongshan_Area = df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Triple_area = df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Xinyi_District = df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Daan_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Wanhua_District = df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Zhongzheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Datong_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Yonghe_District = df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Tucheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['收藏人數'].to_frame()
weekly_collection_0407_0413_district_Banqiao_District = df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['收藏人數'].to_frame()

weekly_collection_0414_0420_district_Zhongshan_Area = df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0414_0420_district_Daan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0414_0420_district_Songshan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
weekly_collection_0414_0420_district_Shilin_District = df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
weekly_collection_0414_0420_district_Wanhua_District = df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()
weekly_collection_0414_0420_district_Datong_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0414_0420_district_Zhongzheng_District = df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['收藏人數'].to_frame()

weekly_collection_0421_0427_district_Zhongshan_Area = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Datong_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Daan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Zhongzheng_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Songshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Neihu_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Shilin_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Wanhua_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Linkou_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0421_0427_district_Wenshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['收藏人數'].to_frame()

weekly_collection_0428_0504_district_Daan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Zhongshan_Area = df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Songshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Datong_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Xinyi_District = df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Taishan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Shilin_District = df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Zhongzheng_District = df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0428_0504_district_Wenshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['收藏人數'].to_frame()

weekly_collection_0505_0511_district_Songshan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Zhongzheng_District = df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Yonghe_District = df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Wanhua_District = df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Xinyi_District = df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Zhongshan_Area = df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Datong_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Triple_area = df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Daan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0505_0511_district_Neihu_District = df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['收藏人數'].to_frame()

weekly_collection_0512_0518_district_Zhongshan_Area = df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Daan_District = df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Triple_area = df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Zhongzheng_District = df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Xinyi_District = df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Shilin_District = df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Xindian_District = df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Linkou_District = df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['收藏人數'].to_frame()
weekly_collection_0512_0518_district_Yonghe_District = df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['收藏人數'].to_frame()

weekly_collection_0519_0525_district_Zhongshan_Area = df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Daan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Songshan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Zhongzheng_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Banqiao_District = df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Triple_area = df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Wanhua_District = df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Datong_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Xinyi_District = df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
weekly_collection_0519_0525_district_Zhonghe_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['收藏人數'].to_frame()

weekly_collection_0526_0601_district_Songshan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Zhongzheng_District = df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Shilin_District = df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Daan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Zhongshan_Area = df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Xinyi_District = df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Banqiao_District = df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Datong_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
weekly_collection_0526_0601_district_Wanhua_District = df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()

####################將同一區域的所有收藏人數整合起來####################
weekly_collection_district_Zhongzheng_District = pd.concat([weekly_collection_0331_0406_district_Zhongzheng_District,weekly_collection_0407_0413_district_Zhongzheng_District,weekly_collection_0414_0420_district_Zhongzheng_District,weekly_collection_0421_0427_district_Zhongzheng_District,weekly_collection_0428_0504_district_Zhongzheng_District,weekly_collection_0505_0511_district_Zhongzheng_District,weekly_collection_0512_0518_district_Zhongzheng_District,weekly_collection_0519_0525_district_Zhongzheng_District,weekly_collection_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'收藏人數':'Zhongzheng_District'})
weekly_collection_district_Shilin_District = pd.concat([weekly_collection_0331_0406_district_Shilin_District,weekly_collection_0407_0413_district_Shilin_District,weekly_collection_0414_0420_district_Shilin_District,weekly_collection_0421_0427_district_Shilin_District,weekly_collection_0428_0504_district_Shilin_District,weekly_collection_0512_0518_district_Shilin_District,weekly_collection_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'收藏人數':'Shilin_District'})
weekly_collection_district_Zhongshan_Area = pd.concat([weekly_collection_0331_0406_district_Zhongshan_Area,weekly_collection_0407_0413_district_Zhongshan_Area,weekly_collection_0414_0420_district_Zhongshan_Area,weekly_collection_0421_0427_district_Zhongshan_Area,weekly_collection_0428_0504_district_Zhongshan_Area,weekly_collection_0505_0511_district_Zhongshan_Area,weekly_collection_0512_0518_district_Zhongshan_Area,weekly_collection_0519_0525_district_Zhongshan_Area,weekly_collection_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'收藏人數':'Zhongshan_Area'})
weekly_collection_district_Datong_District = pd.concat([weekly_collection_0331_0406_district_Datong_District,weekly_collection_0407_0413_district_Datong_District,weekly_collection_0414_0420_district_Datong_District,weekly_collection_0421_0427_district_Datong_District,weekly_collection_0428_0504_district_Datong_District,weekly_collection_0505_0511_district_Datong_District,weekly_collection_0519_0525_district_Datong_District,weekly_collection_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'收藏人數':'Datong_District'})
weekly_collection_district_Daan_District = pd.concat([weekly_collection_0331_0406_district_Daan_District,weekly_collection_0407_0413_district_Daan_District,weekly_collection_0414_0420_district_Daan_District,weekly_collection_0421_0427_district_Daan_District,weekly_collection_0428_0504_district_Daan_District,weekly_collection_0505_0511_district_Daan_District,weekly_collection_0512_0518_district_Daan_District,weekly_collection_0519_0525_district_Daan_District,weekly_collection_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'收藏人數':'Daan_District'})
weekly_collection_district_Songshan_District = pd.concat([weekly_collection_0331_0406_district_Songshan_District,weekly_collection_0414_0420_district_Songshan_District,weekly_collection_0421_0427_district_Songshan_District,weekly_collection_0428_0504_district_Songshan_District,weekly_collection_0505_0511_district_Songshan_District,weekly_collection_0519_0525_district_Songshan_District,weekly_collection_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'收藏人數':'Songshan_District'})
weekly_collection_district_Wanhua_District = pd.concat([weekly_collection_0407_0413_district_Wanhua_District,weekly_collection_0414_0420_district_Wanhua_District,weekly_collection_0421_0427_district_Wanhua_District,weekly_collection_0505_0511_district_Wanhua_District,weekly_collection_0519_0525_district_Wanhua_District,weekly_collection_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'收藏人數':'Wanhua_District'})
weekly_collection_district_Xinyi_District = pd.concat([weekly_collection_0407_0413_district_Xinyi_District,weekly_collection_0428_0504_district_Xinyi_District,weekly_collection_0505_0511_district_Xinyi_District,weekly_collection_0512_0518_district_Xinyi_District,weekly_collection_0519_0525_district_Xinyi_District,weekly_collection_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'收藏人數':'Xinyi_District'})
weekly_collection_district_Yonghe_District = pd.concat([weekly_collection_0331_0406_district_Yonghe_District,weekly_collection_0407_0413_district_Yonghe_District,weekly_collection_0505_0511_district_Yonghe_District,weekly_collection_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'收藏人數':'Yonghe_District'})
weekly_collection_district_Wenshan_District = pd.concat([weekly_collection_0421_0427_district_Wenshan_District,weekly_collection_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'收藏人數':'Wenshan_District'})
weekly_collection_district_Banqiao_District = pd.concat([weekly_collection_0331_0406_district_Banqiao_District,weekly_collection_0407_0413_district_Banqiao_District,weekly_collection_0519_0525_district_Banqiao_District,weekly_collection_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'收藏人數':'Banqiao_District'})
weekly_collection_district_Neihu_District = pd.concat([weekly_collection_0421_0427_district_Neihu_District,weekly_collection_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'收藏人數':'Neihu_District'})
weekly_collection_district_Triple_area = pd.concat([weekly_collection_0407_0413_district_Triple_area,weekly_collection_0505_0511_district_Triple_area,weekly_collection_0512_0518_district_Triple_area,weekly_collection_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'收藏人數':'Triple_area'})
weekly_collection_district_Tucheng_District = pd.concat([weekly_collection_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'收藏人數':'Tucheng_District'})
weekly_collection_district_Taishan_District = pd.concat([weekly_collection_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'收藏人數':'Taishan_District'})
weekly_collection_district_Linkou_District = pd.concat([weekly_collection_0421_0427_district_Linkou_District,weekly_collection_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'收藏人數':'Linkou_District'})
weekly_collection_district_Xindian_District = pd.concat([weekly_collection_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'收藏人數':'Xindian_District'})
weekly_collection_district_Zhonghe_District = pd.concat([weekly_collection_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'收藏人數':'Zhonghe_District'})

data = [weekly_collection_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_collection_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_collection_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_collection_district_Datong_District['Datong_District'].astype("float64").values,weekly_collection_district_Daan_District['Daan_District'].astype("float64").values,weekly_collection_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_collection_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_collection_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_collection_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_collection_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_collection_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_collection_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_collection_district_Triple_area['Triple_area'].astype("float64").values,weekly_collection_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_collection_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_collection_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_collection_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_collection_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每週各區域的美食收藏人數')
plt.title('District Weekly collection')
plt.xlabel('district')
plt.ylabel('collection')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District Weekly collection')
plt.xlabel('district')
plt.ylabel('collection')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每週各區域的推薦人數####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有推薦人數####################
weekly_recommend_0331_0406_district_Daan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Zhongzheng_District = df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Zhongshan_Area = df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Datong_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Songshan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Yonghe_District = df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Shilin_District = df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
weekly_recommend_0331_0406_district_Banqiao_District = df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['推薦人數'].to_frame()

weekly_recommend_0407_0413_district_Shilin_District = df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Zhongshan_Area = df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Triple_area = df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Xinyi_District = df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Daan_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Wanhua_District = df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Zhongzheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Datong_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Yonghe_District = df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Tucheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['推薦人數'].to_frame()
weekly_recommend_0407_0413_district_Banqiao_District = df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['推薦人數'].to_frame()

weekly_recommend_0414_0420_district_Zhongshan_Area = df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0414_0420_district_Daan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0414_0420_district_Songshan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
weekly_recommend_0414_0420_district_Shilin_District = df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
weekly_recommend_0414_0420_district_Wanhua_District = df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()
weekly_recommend_0414_0420_district_Datong_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0414_0420_district_Zhongzheng_District = df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['推薦人數'].to_frame()

weekly_recommend_0421_0427_district_Zhongshan_Area = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Datong_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Daan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Zhongzheng_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Songshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Neihu_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Shilin_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Wanhua_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Linkou_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0421_0427_district_Wenshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['推薦人數'].to_frame()

weekly_recommend_0428_0504_district_Daan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Zhongshan_Area = df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Songshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Datong_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Xinyi_District = df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Taishan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Shilin_District = df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Zhongzheng_District = df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0428_0504_district_Wenshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['推薦人數'].to_frame()

weekly_recommend_0505_0511_district_Songshan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Zhongzheng_District = df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Yonghe_District = df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Wanhua_District = df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Xinyi_District = df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Zhongshan_Area = df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Datong_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Triple_area = df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Daan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0505_0511_district_Neihu_District = df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['推薦人數'].to_frame()

weekly_recommend_0512_0518_district_Zhongshan_Area = df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Daan_District = df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Triple_area = df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Zhongzheng_District = df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Xinyi_District = df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Shilin_District = df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Xindian_District = df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Linkou_District = df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['推薦人數'].to_frame()
weekly_recommend_0512_0518_district_Yonghe_District = df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['推薦人數'].to_frame()

weekly_recommend_0519_0525_district_Zhongshan_Area = df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Daan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Songshan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Zhongzheng_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Banqiao_District = df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Triple_area = df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Wanhua_District = df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Datong_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Xinyi_District = df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
weekly_recommend_0519_0525_district_Zhonghe_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['推薦人數'].to_frame()

weekly_recommend_0526_0601_district_Songshan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Zhongzheng_District = df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Shilin_District = df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Daan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Zhongshan_Area = df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Xinyi_District = df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Banqiao_District = df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Datong_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
weekly_recommend_0526_0601_district_Wanhua_District = df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()

####################將同一區域的所有推薦人數整合起來####################
weekly_recommend_district_Zhongzheng_District = pd.concat([weekly_recommend_0331_0406_district_Zhongzheng_District,weekly_recommend_0407_0413_district_Zhongzheng_District,weekly_recommend_0414_0420_district_Zhongzheng_District,weekly_recommend_0421_0427_district_Zhongzheng_District,weekly_recommend_0428_0504_district_Zhongzheng_District,weekly_recommend_0505_0511_district_Zhongzheng_District,weekly_recommend_0512_0518_district_Zhongzheng_District,weekly_recommend_0519_0525_district_Zhongzheng_District,weekly_recommend_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'推薦人數':'Zhongzheng_District'})
weekly_recommend_district_Shilin_District = pd.concat([weekly_recommend_0331_0406_district_Shilin_District,weekly_recommend_0407_0413_district_Shilin_District,weekly_recommend_0414_0420_district_Shilin_District,weekly_recommend_0421_0427_district_Shilin_District,weekly_recommend_0428_0504_district_Shilin_District,weekly_recommend_0512_0518_district_Shilin_District,weekly_recommend_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'推薦人數':'Shilin_District'})
weekly_recommend_district_Zhongshan_Area = pd.concat([weekly_recommend_0331_0406_district_Zhongshan_Area,weekly_recommend_0407_0413_district_Zhongshan_Area,weekly_recommend_0414_0420_district_Zhongshan_Area,weekly_recommend_0421_0427_district_Zhongshan_Area,weekly_recommend_0428_0504_district_Zhongshan_Area,weekly_recommend_0505_0511_district_Zhongshan_Area,weekly_recommend_0512_0518_district_Zhongshan_Area,weekly_recommend_0519_0525_district_Zhongshan_Area,weekly_recommend_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'推薦人數':'Zhongshan_Area'})
weekly_recommend_district_Datong_District = pd.concat([weekly_recommend_0331_0406_district_Datong_District,weekly_recommend_0407_0413_district_Datong_District,weekly_recommend_0414_0420_district_Datong_District,weekly_recommend_0421_0427_district_Datong_District,weekly_recommend_0428_0504_district_Datong_District,weekly_recommend_0505_0511_district_Datong_District,weekly_recommend_0519_0525_district_Datong_District,weekly_recommend_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'推薦人數':'Datong_District'})
weekly_recommend_district_Daan_District = pd.concat([weekly_recommend_0331_0406_district_Daan_District,weekly_recommend_0407_0413_district_Daan_District,weekly_recommend_0414_0420_district_Daan_District,weekly_recommend_0421_0427_district_Daan_District,weekly_recommend_0428_0504_district_Daan_District,weekly_recommend_0505_0511_district_Daan_District,weekly_recommend_0512_0518_district_Daan_District,weekly_recommend_0519_0525_district_Daan_District,weekly_recommend_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'推薦人數':'Daan_District'})
weekly_recommend_district_Songshan_District = pd.concat([weekly_recommend_0331_0406_district_Songshan_District,weekly_recommend_0414_0420_district_Songshan_District,weekly_recommend_0421_0427_district_Songshan_District,weekly_recommend_0428_0504_district_Songshan_District,weekly_recommend_0505_0511_district_Songshan_District,weekly_recommend_0519_0525_district_Songshan_District,weekly_recommend_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'推薦人數':'Songshan_District'})
weekly_recommend_district_Wanhua_District = pd.concat([weekly_recommend_0407_0413_district_Wanhua_District,weekly_recommend_0414_0420_district_Wanhua_District,weekly_recommend_0421_0427_district_Wanhua_District,weekly_recommend_0505_0511_district_Wanhua_District,weekly_recommend_0519_0525_district_Wanhua_District,weekly_recommend_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'推薦人數':'Wanhua_District'})
weekly_recommend_district_Xinyi_District = pd.concat([weekly_recommend_0407_0413_district_Xinyi_District,weekly_recommend_0428_0504_district_Xinyi_District,weekly_recommend_0505_0511_district_Xinyi_District,weekly_recommend_0512_0518_district_Xinyi_District,weekly_recommend_0519_0525_district_Xinyi_District,weekly_recommend_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'推薦人數':'Xinyi_District'})
weekly_recommend_district_Yonghe_District = pd.concat([weekly_recommend_0331_0406_district_Yonghe_District,weekly_recommend_0407_0413_district_Yonghe_District,weekly_recommend_0505_0511_district_Yonghe_District,weekly_recommend_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'推薦人數':'Yonghe_District'})
weekly_recommend_district_Wenshan_District = pd.concat([weekly_recommend_0421_0427_district_Wenshan_District,weekly_recommend_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'推薦人數':'Wenshan_District'})
weekly_recommend_district_Banqiao_District = pd.concat([weekly_recommend_0331_0406_district_Banqiao_District,weekly_recommend_0407_0413_district_Banqiao_District,weekly_recommend_0519_0525_district_Banqiao_District,weekly_recommend_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'推薦人數':'Banqiao_District'})
weekly_recommend_district_Neihu_District = pd.concat([weekly_recommend_0421_0427_district_Neihu_District,weekly_recommend_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'推薦人數':'Neihu_District'})
weekly_recommend_district_Triple_area = pd.concat([weekly_recommend_0407_0413_district_Triple_area,weekly_recommend_0505_0511_district_Triple_area,weekly_recommend_0512_0518_district_Triple_area,weekly_recommend_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'推薦人數':'Triple_area'})
weekly_recommend_district_Tucheng_District = pd.concat([weekly_recommend_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'推薦人數':'Tucheng_District'})
weekly_recommend_district_Taishan_District = pd.concat([weekly_recommend_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'推薦人數':'Taishan_District'})
weekly_recommend_district_Linkou_District = pd.concat([weekly_recommend_0421_0427_district_Linkou_District,weekly_recommend_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'推薦人數':'Linkou_District'})
weekly_recommend_district_Xindian_District = pd.concat([weekly_recommend_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'推薦人數':'Xindian_District'})
weekly_recommend_district_Zhonghe_District = pd.concat([weekly_recommend_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'推薦人數':'Zhonghe_District'})

data = [weekly_recommend_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_recommend_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_recommend_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_recommend_district_Datong_District['Datong_District'].astype("float64").values,weekly_recommend_district_Daan_District['Daan_District'].astype("float64").values,weekly_recommend_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_recommend_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_recommend_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_recommend_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_recommend_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_recommend_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_recommend_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_recommend_district_Triple_area['Triple_area'].astype("float64").values,weekly_recommend_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_recommend_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_recommend_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_recommend_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_recommend_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每週各區域的美食推薦人數')
plt.title('District Weekly recommend')
plt.xlabel('district')
plt.ylabel('recommend')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District Weekly recommend')
plt.xlabel('district')
plt.ylabel('recommend')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每週各區域的多少人來過####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有多少人來過####################
weekly_visit_0331_0406_district_Daan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Zhongzheng_District = df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Zhongshan_Area = df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Datong_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Songshan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Yonghe_District = df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Shilin_District = df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
weekly_visit_0331_0406_district_Banqiao_District = df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['多少人來過'].to_frame()

weekly_visit_0407_0413_district_Shilin_District = df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Zhongshan_Area = df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Triple_area = df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Xinyi_District = df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Daan_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Wanhua_District = df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Zhongzheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Datong_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Yonghe_District = df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Tucheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['多少人來過'].to_frame()
weekly_visit_0407_0413_district_Banqiao_District = df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['多少人來過'].to_frame()

weekly_visit_0414_0420_district_Zhongshan_Area = df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0414_0420_district_Daan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0414_0420_district_Songshan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
weekly_visit_0414_0420_district_Shilin_District = df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
weekly_visit_0414_0420_district_Wanhua_District = df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()
weekly_visit_0414_0420_district_Datong_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0414_0420_district_Zhongzheng_District = df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['多少人來過'].to_frame()

weekly_visit_0421_0427_district_Zhongshan_Area = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Datong_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Daan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Zhongzheng_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Songshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Neihu_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Shilin_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Wanhua_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Linkou_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0421_0427_district_Wenshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少人來過'].to_frame()

weekly_visit_0428_0504_district_Daan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Zhongshan_Area = df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Songshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Datong_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Xinyi_District = df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Taishan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Shilin_District = df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Zhongzheng_District = df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0428_0504_district_Wenshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['多少人來過'].to_frame()

weekly_visit_0505_0511_district_Songshan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Zhongzheng_District = df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Yonghe_District = df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Wanhua_District = df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Xinyi_District = df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Zhongshan_Area = df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Datong_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Triple_area = df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Daan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0505_0511_district_Neihu_District = df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['多少人來過'].to_frame()

weekly_visit_0512_0518_district_Zhongshan_Area = df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Daan_District = df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Triple_area = df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Zhongzheng_District = df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Xinyi_District = df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Shilin_District = df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Xindian_District = df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Linkou_District = df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['多少人來過'].to_frame()
weekly_visit_0512_0518_district_Yonghe_District = df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['多少人來過'].to_frame()

weekly_visit_0519_0525_district_Zhongshan_Area = df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Daan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Songshan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Zhongzheng_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Banqiao_District = df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Triple_area = df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Wanhua_District = df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Datong_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Xinyi_District = df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
weekly_visit_0519_0525_district_Zhonghe_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['多少人來過'].to_frame()

weekly_visit_0526_0601_district_Songshan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Zhongzheng_District = df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Shilin_District = df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Daan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Zhongshan_Area = df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Xinyi_District = df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Banqiao_District = df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Datong_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
weekly_visit_0526_0601_district_Wanhua_District = df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()

####################將同一區域的所有多少人來過整合起來####################
weekly_visit_district_Zhongzheng_District = pd.concat([weekly_visit_0331_0406_district_Zhongzheng_District,weekly_visit_0407_0413_district_Zhongzheng_District,weekly_visit_0414_0420_district_Zhongzheng_District,weekly_visit_0421_0427_district_Zhongzheng_District,weekly_visit_0428_0504_district_Zhongzheng_District,weekly_visit_0505_0511_district_Zhongzheng_District,weekly_visit_0512_0518_district_Zhongzheng_District,weekly_visit_0519_0525_district_Zhongzheng_District,weekly_visit_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'多少人來過':'Zhongzheng_District'})
weekly_visit_district_Shilin_District = pd.concat([weekly_visit_0331_0406_district_Shilin_District,weekly_visit_0407_0413_district_Shilin_District,weekly_visit_0414_0420_district_Shilin_District,weekly_visit_0421_0427_district_Shilin_District,weekly_visit_0428_0504_district_Shilin_District,weekly_visit_0512_0518_district_Shilin_District,weekly_visit_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'多少人來過':'Shilin_District'})
weekly_visit_district_Zhongshan_Area = pd.concat([weekly_visit_0331_0406_district_Zhongshan_Area,weekly_visit_0407_0413_district_Zhongshan_Area,weekly_visit_0414_0420_district_Zhongshan_Area,weekly_visit_0421_0427_district_Zhongshan_Area,weekly_visit_0428_0504_district_Zhongshan_Area,weekly_visit_0505_0511_district_Zhongshan_Area,weekly_visit_0512_0518_district_Zhongshan_Area,weekly_visit_0519_0525_district_Zhongshan_Area,weekly_visit_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'多少人來過':'Zhongshan_Area'})
weekly_visit_district_Datong_District = pd.concat([weekly_visit_0331_0406_district_Datong_District,weekly_visit_0407_0413_district_Datong_District,weekly_visit_0414_0420_district_Datong_District,weekly_visit_0421_0427_district_Datong_District,weekly_visit_0428_0504_district_Datong_District,weekly_visit_0505_0511_district_Datong_District,weekly_visit_0519_0525_district_Datong_District,weekly_visit_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'多少人來過':'Datong_District'})
weekly_visit_district_Daan_District = pd.concat([weekly_visit_0331_0406_district_Daan_District,weekly_visit_0407_0413_district_Daan_District,weekly_visit_0414_0420_district_Daan_District,weekly_visit_0421_0427_district_Daan_District,weekly_visit_0428_0504_district_Daan_District,weekly_visit_0505_0511_district_Daan_District,weekly_visit_0512_0518_district_Daan_District,weekly_visit_0519_0525_district_Daan_District,weekly_visit_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'多少人來過':'Daan_District'})
weekly_visit_district_Songshan_District = pd.concat([weekly_visit_0331_0406_district_Songshan_District,weekly_visit_0414_0420_district_Songshan_District,weekly_visit_0421_0427_district_Songshan_District,weekly_visit_0428_0504_district_Songshan_District,weekly_visit_0505_0511_district_Songshan_District,weekly_visit_0519_0525_district_Songshan_District,weekly_visit_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'多少人來過':'Songshan_District'})
weekly_visit_district_Wanhua_District = pd.concat([weekly_visit_0407_0413_district_Wanhua_District,weekly_visit_0414_0420_district_Wanhua_District,weekly_visit_0421_0427_district_Wanhua_District,weekly_visit_0505_0511_district_Wanhua_District,weekly_visit_0519_0525_district_Wanhua_District,weekly_visit_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'多少人來過':'Wanhua_District'})
weekly_visit_district_Xinyi_District = pd.concat([weekly_visit_0407_0413_district_Xinyi_District,weekly_visit_0428_0504_district_Xinyi_District,weekly_visit_0505_0511_district_Xinyi_District,weekly_visit_0512_0518_district_Xinyi_District,weekly_visit_0519_0525_district_Xinyi_District,weekly_visit_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'多少人來過':'Xinyi_District'})
weekly_visit_district_Yonghe_District = pd.concat([weekly_visit_0331_0406_district_Yonghe_District,weekly_visit_0407_0413_district_Yonghe_District,weekly_visit_0505_0511_district_Yonghe_District,weekly_visit_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'多少人來過':'Yonghe_District'})
weekly_visit_district_Wenshan_District = pd.concat([weekly_visit_0421_0427_district_Wenshan_District,weekly_visit_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'多少人來過':'Wenshan_District'})
weekly_visit_district_Banqiao_District = pd.concat([weekly_visit_0331_0406_district_Banqiao_District,weekly_visit_0407_0413_district_Banqiao_District,weekly_visit_0519_0525_district_Banqiao_District,weekly_visit_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'多少人來過':'Banqiao_District'})
weekly_visit_district_Neihu_District = pd.concat([weekly_visit_0421_0427_district_Neihu_District,weekly_visit_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'多少人來過':'Neihu_District'})
weekly_visit_district_Triple_area = pd.concat([weekly_visit_0407_0413_district_Triple_area,weekly_visit_0505_0511_district_Triple_area,weekly_visit_0512_0518_district_Triple_area,weekly_visit_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'多少人來過':'Triple_area'})
weekly_visit_district_Tucheng_District = pd.concat([weekly_visit_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'多少人來過':'Tucheng_District'})
weekly_visit_district_Taishan_District = pd.concat([weekly_visit_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'多少人來過':'Taishan_District'})
weekly_visit_district_Linkou_District = pd.concat([weekly_visit_0421_0427_district_Linkou_District,weekly_visit_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'多少人來過':'Linkou_District'})
weekly_visit_district_Xindian_District = pd.concat([weekly_visit_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'多少人來過':'Xindian_District'})
weekly_visit_district_Zhonghe_District = pd.concat([weekly_visit_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'多少人來過':'Zhonghe_District'})

data = [weekly_visit_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_visit_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_visit_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_visit_district_Datong_District['Datong_District'].astype("float64").values,weekly_visit_district_Daan_District['Daan_District'].astype("float64").values,weekly_visit_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_visit_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_visit_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_visit_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_visit_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_visit_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_visit_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_visit_district_Triple_area['Triple_area'].astype("float64").values,weekly_visit_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_visit_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_visit_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_visit_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_visit_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每週各區域的美食多少人來過')
plt.title('District Weekly visit')
plt.xlabel('district')
plt.ylabel('visit')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District Weekly visit')
plt.xlabel('district')
plt.ylabel('visit')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每週各區域的多少篇食記####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有多少篇食記####################
weekly_foodrecord_0331_0406_district_Daan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Zhongzheng_District = df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Zhongshan_Area = df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Datong_District = df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Songshan_District = df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Yonghe_District = df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Shilin_District = df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
weekly_foodrecord_0331_0406_district_Banqiao_District = df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['多少篇食記'].to_frame()

weekly_foodrecord_0407_0413_district_Shilin_District = df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Zhongshan_Area = df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Triple_area = df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Xinyi_District = df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Daan_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Wanhua_District = df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Zhongzheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Datong_District = df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Yonghe_District = df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Tucheng_District = df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['多少篇食記'].to_frame()
weekly_foodrecord_0407_0413_district_Banqiao_District = df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['多少篇食記'].to_frame()

weekly_foodrecord_0414_0420_district_Zhongshan_Area = df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0414_0420_district_Daan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0414_0420_district_Songshan_District = df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0414_0420_district_Shilin_District = df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
weekly_foodrecord_0414_0420_district_Wanhua_District = df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()
weekly_foodrecord_0414_0420_district_Datong_District = df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0414_0420_district_Zhongzheng_District = df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()

weekly_foodrecord_0421_0427_district_Zhongshan_Area = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Datong_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Daan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Zhongzheng_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Songshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Neihu_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Shilin_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Wanhua_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Linkou_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0421_0427_district_Wenshan_District = df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()

weekly_foodrecord_0428_0504_district_Daan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Zhongshan_Area = df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Songshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Datong_District = df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Xinyi_District = df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Taishan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Shilin_District = df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Zhongzheng_District = df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0428_0504_district_Wenshan_District = df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['多少篇食記'].to_frame()

weekly_foodrecord_0505_0511_district_Songshan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Zhongzheng_District = df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Yonghe_District = df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Wanhua_District = df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Xinyi_District = df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Zhongshan_Area = df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Datong_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Triple_area = df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Daan_District = df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0505_0511_district_Neihu_District = df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['多少篇食記'].to_frame()

weekly_foodrecord_0512_0518_district_Zhongshan_Area = df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Daan_District = df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Triple_area = df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Zhongzheng_District = df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Xinyi_District = df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Shilin_District = df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Xindian_District = df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Linkou_District = df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['多少篇食記'].to_frame()
weekly_foodrecord_0512_0518_district_Yonghe_District = df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['多少篇食記'].to_frame()

weekly_foodrecord_0519_0525_district_Zhongshan_Area = df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Daan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Songshan_District = df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Zhongzheng_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Banqiao_District = df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Triple_area = df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Wanhua_District = df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Datong_District = df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Xinyi_District = df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
weekly_foodrecord_0519_0525_district_Zhonghe_District = df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['多少篇食記'].to_frame()

weekly_foodrecord_0526_0601_district_Songshan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Zhongzheng_District = df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Shilin_District = df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Daan_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Zhongshan_Area = df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Xinyi_District = df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Banqiao_District = df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Datong_District = df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
weekly_foodrecord_0526_0601_district_Wanhua_District = df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()

####################將同一區域的所有多少篇食記整合起來####################
weekly_foodrecord_district_Zhongzheng_District = pd.concat([weekly_foodrecord_0331_0406_district_Zhongzheng_District,weekly_foodrecord_0407_0413_district_Zhongzheng_District,weekly_foodrecord_0414_0420_district_Zhongzheng_District,weekly_foodrecord_0421_0427_district_Zhongzheng_District,weekly_foodrecord_0428_0504_district_Zhongzheng_District,weekly_foodrecord_0505_0511_district_Zhongzheng_District,weekly_foodrecord_0512_0518_district_Zhongzheng_District,weekly_foodrecord_0519_0525_district_Zhongzheng_District,weekly_foodrecord_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'多少篇食記':'Zhongzheng_District'})
weekly_foodrecord_district_Shilin_District = pd.concat([weekly_foodrecord_0331_0406_district_Shilin_District,weekly_foodrecord_0407_0413_district_Shilin_District,weekly_foodrecord_0414_0420_district_Shilin_District,weekly_foodrecord_0421_0427_district_Shilin_District,weekly_foodrecord_0428_0504_district_Shilin_District,weekly_foodrecord_0512_0518_district_Shilin_District,weekly_foodrecord_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'多少篇食記':'Shilin_District'})
weekly_foodrecord_district_Zhongshan_Area = pd.concat([weekly_foodrecord_0331_0406_district_Zhongshan_Area,weekly_foodrecord_0407_0413_district_Zhongshan_Area,weekly_foodrecord_0414_0420_district_Zhongshan_Area,weekly_foodrecord_0421_0427_district_Zhongshan_Area,weekly_foodrecord_0428_0504_district_Zhongshan_Area,weekly_foodrecord_0505_0511_district_Zhongshan_Area,weekly_foodrecord_0512_0518_district_Zhongshan_Area,weekly_foodrecord_0519_0525_district_Zhongshan_Area,weekly_foodrecord_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'多少篇食記':'Zhongshan_Area'})
weekly_foodrecord_district_Datong_District = pd.concat([weekly_foodrecord_0331_0406_district_Datong_District,weekly_foodrecord_0407_0413_district_Datong_District,weekly_foodrecord_0414_0420_district_Datong_District,weekly_foodrecord_0421_0427_district_Datong_District,weekly_foodrecord_0428_0504_district_Datong_District,weekly_foodrecord_0505_0511_district_Datong_District,weekly_foodrecord_0519_0525_district_Datong_District,weekly_foodrecord_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'多少篇食記':'Datong_District'})
weekly_foodrecord_district_Daan_District = pd.concat([weekly_foodrecord_0331_0406_district_Daan_District,weekly_foodrecord_0407_0413_district_Daan_District,weekly_foodrecord_0414_0420_district_Daan_District,weekly_foodrecord_0421_0427_district_Daan_District,weekly_foodrecord_0428_0504_district_Daan_District,weekly_foodrecord_0505_0511_district_Daan_District,weekly_foodrecord_0512_0518_district_Daan_District,weekly_foodrecord_0519_0525_district_Daan_District,weekly_foodrecord_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'多少篇食記':'Daan_District'})
weekly_foodrecord_district_Songshan_District = pd.concat([weekly_foodrecord_0331_0406_district_Songshan_District,weekly_foodrecord_0414_0420_district_Songshan_District,weekly_foodrecord_0421_0427_district_Songshan_District,weekly_foodrecord_0428_0504_district_Songshan_District,weekly_foodrecord_0505_0511_district_Songshan_District,weekly_foodrecord_0519_0525_district_Songshan_District,weekly_foodrecord_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'多少篇食記':'Songshan_District'})
weekly_foodrecord_district_Wanhua_District = pd.concat([weekly_foodrecord_0407_0413_district_Wanhua_District,weekly_foodrecord_0414_0420_district_Wanhua_District,weekly_foodrecord_0421_0427_district_Wanhua_District,weekly_foodrecord_0505_0511_district_Wanhua_District,weekly_foodrecord_0519_0525_district_Wanhua_District,weekly_foodrecord_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'多少篇食記':'Wanhua_District'})
weekly_foodrecord_district_Xinyi_District = pd.concat([weekly_foodrecord_0407_0413_district_Xinyi_District,weekly_foodrecord_0428_0504_district_Xinyi_District,weekly_foodrecord_0505_0511_district_Xinyi_District,weekly_foodrecord_0512_0518_district_Xinyi_District,weekly_foodrecord_0519_0525_district_Xinyi_District,weekly_foodrecord_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'多少篇食記':'Xinyi_District'})
weekly_foodrecord_district_Yonghe_District = pd.concat([weekly_foodrecord_0331_0406_district_Yonghe_District,weekly_foodrecord_0407_0413_district_Yonghe_District,weekly_foodrecord_0505_0511_district_Yonghe_District,weekly_foodrecord_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'多少篇食記':'Yonghe_District'})
weekly_foodrecord_district_Wenshan_District = pd.concat([weekly_foodrecord_0421_0427_district_Wenshan_District,weekly_foodrecord_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'多少篇食記':'Wenshan_District'})
weekly_foodrecord_district_Banqiao_District = pd.concat([weekly_foodrecord_0331_0406_district_Banqiao_District,weekly_foodrecord_0407_0413_district_Banqiao_District,weekly_foodrecord_0519_0525_district_Banqiao_District,weekly_foodrecord_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'多少篇食記':'Banqiao_District'})
weekly_foodrecord_district_Neihu_District = pd.concat([weekly_foodrecord_0421_0427_district_Neihu_District,weekly_foodrecord_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'多少篇食記':'Neihu_District'})
weekly_foodrecord_district_Triple_area = pd.concat([weekly_foodrecord_0407_0413_district_Triple_area,weekly_foodrecord_0505_0511_district_Triple_area,weekly_foodrecord_0512_0518_district_Triple_area,weekly_foodrecord_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'多少篇食記':'Triple_area'})
weekly_foodrecord_district_Tucheng_District = pd.concat([weekly_foodrecord_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'多少篇食記':'Tucheng_District'})
weekly_foodrecord_district_Taishan_District = pd.concat([weekly_foodrecord_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'多少篇食記':'Taishan_District'})
weekly_foodrecord_district_Linkou_District = pd.concat([weekly_foodrecord_0421_0427_district_Linkou_District,weekly_foodrecord_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'多少篇食記':'Linkou_District'})
weekly_foodrecord_district_Xindian_District = pd.concat([weekly_foodrecord_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'多少篇食記':'Xindian_District'})
weekly_foodrecord_district_Zhonghe_District = pd.concat([weekly_foodrecord_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'多少篇食記':'Zhonghe_District'})

data = [weekly_foodrecord_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_foodrecord_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_foodrecord_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_foodrecord_district_Datong_District['Datong_District'].astype("float64").values,weekly_foodrecord_district_Daan_District['Daan_District'].astype("float64").values,weekly_foodrecord_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_foodrecord_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_foodrecord_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_foodrecord_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_foodrecord_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_foodrecord_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_foodrecord_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_foodrecord_district_Triple_area['Triple_area'].astype("float64").values,weekly_foodrecord_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_foodrecord_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_foodrecord_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_foodrecord_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_foodrecord_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每週各區域的美食多少篇食記')
plt.title('District Weekly foodrecord')
plt.xlabel('district')
plt.ylabel('foodrecord')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District Weekly foodrecord')
plt.xlabel('district')
plt.ylabel('foodrecord')
plt.show()

# %% [markdown]
# # 整體：每月各區域：

# %%
print(df_05['美食所在區域'].value_counts())
# Out:
# 中山區    5
# 大安區    5
# 松山區    3
# 中正區    3
# 大同區    1
# 萬華區    1
# 新店區    1
# 信義區    1
# Name: 美食所在區域, dtype: int64

# %%
####################視覺化圖表####################
####################整體：每月各區域的評級####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有評級####################
monthly_rating_03_district_Zhongshan_Area = df_03[df_03['美食所在區域'] == "中山區"]['評級'].to_frame()
monthly_rating_03_district_Daan_District = df_03[df_03['美食所在區域'] == "大安區"]['評級'].to_frame()
monthly_rating_03_district_Zhongzheng_District = df_03[df_03['美食所在區域'] == "中正區"]['評級'].to_frame()
monthly_rating_03_district_Wanhua_District = df_03[df_03['美食所在區域'] == "萬華區"]['評級'].to_frame()
monthly_rating_03_district_Songshan_District = df_03[df_03['美食所在區域'] == "松山區"]['評級'].to_frame()
monthly_rating_03_district_Nangang_District = df_03[df_03['美食所在區域'] == "南港區"]['評級'].to_frame()
monthly_rating_03_district_Xinyi_District = df_03[df_03['美食所在區域'] == "信義區"]['評級'].to_frame()

monthly_rating_04_district_Zhongshan_Area = df_04[df_04['美食所在區域'] == "中山區"]['評級'].to_frame()
monthly_rating_04_district_Daan_District = df_04[df_04['美食所在區域'] == "大安區"]['評級'].to_frame()
monthly_rating_04_district_Zhongzheng_District = df_04[df_04['美食所在區域'] == "中正區"]['評級'].to_frame()
monthly_rating_04_district_Datong_District = df_04[df_04['美食所在區域'] == "大同區"]['評級'].to_frame()
monthly_rating_04_district_Songshan_District = df_04[df_04['美食所在區域'] == "松山區"]['評級'].to_frame()
monthly_rating_04_district_Shilin_District = df_04[df_04['美食所在區域'] == "士林區"]['評級'].to_frame()
monthly_rating_04_district_Linkou_District = df_04[df_04['美食所在區域'] == "林口區"]['評級'].to_frame()
monthly_rating_04_district_Yonghe_District = df_04[df_04['美食所在區域'] == "永和區"]['評級'].to_frame()
monthly_rating_04_district_Banqiao_District = df_04[df_04['美食所在區域'] == "板橋區"]['評級'].to_frame()

monthly_rating_05_district_Zhongshan_Area = df_05[df_05['美食所在區域'] == "中山區"]['評級'].to_frame()
monthly_rating_05_district_Daan_District = df_05[df_05['美食所在區域'] == "大安區"]['評級'].to_frame()
monthly_rating_05_district_Zhongzheng_District = df_05[df_05['美食所在區域'] == "中正區"]['評級'].to_frame()
monthly_rating_05_district_Songshan_District = df_05[df_05['美食所在區域'] == "松山區"]['評級'].to_frame()
monthly_rating_05_district_Xinyi_District = df_05[df_05['美食所在區域'] == "信義區"]['評級'].to_frame()
monthly_rating_05_district_Datong_District = df_05[df_05['美食所在區域'] == "大同區"]['評級'].to_frame()
monthly_rating_05_district_Xindian_District = df_05[df_05['美食所在區域'] == "新店區"]['評級'].to_frame()
monthly_rating_05_district_Wanhua_District = df_05[df_05['美食所在區域'] == "萬華區"]['評級'].to_frame()

####################將同一區域的所有評級整合起來####################
monthly_rating_district_Zhongzheng_District = pd.concat([monthly_rating_03_district_Zhongzheng_District,monthly_rating_04_district_Zhongzheng_District,monthly_rating_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'評級':'Zhongzheng_District'})
monthly_rating_district_Daan_District = pd.concat([monthly_rating_03_district_Daan_District,monthly_rating_04_district_Daan_District,monthly_rating_05_district_Daan_District],ignore_index=True).rename(columns={'評級':'Daan_District'})
monthly_rating_district_Songshan_District = pd.concat([monthly_rating_03_district_Songshan_District,monthly_rating_04_district_Songshan_District,monthly_rating_05_district_Songshan_District],ignore_index=True).rename(columns={'評級':'Songshan_District'})
monthly_rating_district_Zhongshan_Area = pd.concat([monthly_rating_03_district_Zhongshan_Area,monthly_rating_04_district_Zhongshan_Area,monthly_rating_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'評級':'Zhongshan_Area'})
monthly_rating_district_Yonghe_District = pd.concat([monthly_rating_04_district_Yonghe_District],ignore_index=True).rename(columns={'評級':'Yonghe_District'})
monthly_rating_district_Datong_District = pd.concat([monthly_rating_04_district_Datong_District,monthly_rating_05_district_Datong_District],ignore_index=True).rename(columns={'評級':'Datong_District'})
monthly_rating_district_Linkou_District = pd.concat([monthly_rating_04_district_Linkou_District],ignore_index=True).rename(columns={'評級':'Linkou_District'})
monthly_rating_district_Nangang_District = pd.concat([monthly_rating_03_district_Nangang_District],ignore_index=True).rename(columns={'評級':'Nangang_District'})
monthly_rating_district_Xinyi_District = pd.concat([monthly_rating_03_district_Xinyi_District,monthly_rating_05_district_Xinyi_District],ignore_index=True).rename(columns={'評級':'Xinyi_District'})
monthly_rating_district_Shilin_District = pd.concat([monthly_rating_04_district_Shilin_District],ignore_index=True).rename(columns={'評級':'Shilin_District'})
monthly_rating_district_Wanhua_District = pd.concat([monthly_rating_03_district_Wanhua_District,monthly_rating_05_district_Wanhua_District],ignore_index=True).rename(columns={'評級':'Wanhua_District'})
monthly_rating_district_Banqiao_District = pd.concat([monthly_rating_04_district_Banqiao_District],ignore_index=True).rename(columns={'評級':'Banqiao_District'})
monthly_rating_district_Xindian_District = pd.concat([monthly_rating_05_district_Xindian_District],ignore_index=True).rename(columns={'評級':'Xindian_District'})

data = [monthly_rating_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_rating_district_Daan_District['Daan_District'].astype("float64").values,monthly_rating_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_rating_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_rating_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_rating_district_Datong_District['Datong_District'].astype("float64").values,monthly_rating_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_rating_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_rating_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_rating_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_rating_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_rating_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_rating_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每月各區域的美食評級')
plt.title('District monthly rating')
plt.xlabel('district')
plt.ylabel('rating')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District monthly rating')
plt.xlabel('district')
plt.ylabel('rating')
plt.show()

'''03
中山區 Zhongshan_Area
大安區 Daan_District
中正區 Zhongzheng_District
萬華區 Wanhua_District
松山區 Songshan_District
南港區 Nangang_District
信義區 Xinyi_District
'''
'''04
中山區 Zhongshan_Area
大安區 Daan_District
中正區 Zhongzheng_District
大同區 Datong_District
松山區 Songshan_District
士林區 Shilin_District
林口區 Linkou_District
永和區 Yonghe_District
板橋區 Banqiao_District
'''
'''05
中山區 Zhongshan Area
大安區 Daan District
中正區 Zhongzheng District
松山區 Songshan District
信義區 Xinyi District
大同區 Datong District
新店區 Xindian District
萬華區 Wanhua District
'''
# Out:
# '05\n中山區 Zhongshan Area\n大安區 Daan District\n中正區 Zhongzheng District\n松山區 Songshan District\n信義區 Xinyi District\n大同區 Datong District\n新店區 Xindian District\n萬華區 Wanhua District\n'

# %%
#查看所有月份當中總共有哪些不重複行政區
b = ['中山區','大安區','中正區','萬華區','松山區','南港區','信義區','中山區','大安區','中正區','大同區','松山區','士林區','林口區','永和區','板橋區']
b = pd.DataFrame(b) 
#print(b)
print(type(b))
print(b[0].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 中正區    2
# 大安區    2
# 松山區    2
# 中山區    2
# 永和區    1
# 大同區    1
# 林口區    1
# 南港區    1
# 信義區    1
# 士林區    1
# 萬華區    1
# 板橋區    1
# Name: 0, dtype: int64

# %%
####################視覺化圖表####################
####################整體：每月各區域的觀看人數####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有觀看人數####################
monthly_watch_03_district_Zhongshan_Area = df_03[df_03['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
monthly_watch_03_district_Daan_District = df_03[df_03['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
monthly_watch_03_district_Zhongzheng_District = df_03[df_03['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
monthly_watch_03_district_Wanhua_District = df_03[df_03['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()
monthly_watch_03_district_Songshan_District = df_03[df_03['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
monthly_watch_03_district_Nangang_District = df_03[df_03['美食所在區域'] == "南港區"]['觀看人數'].to_frame()
monthly_watch_03_district_Xinyi_District = df_03[df_03['美食所在區域'] == "信義區"]['觀看人數'].to_frame()

monthly_watch_04_district_Zhongshan_Area = df_04[df_04['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
monthly_watch_04_district_Daan_District = df_04[df_04['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
monthly_watch_04_district_Zhongzheng_District = df_04[df_04['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
monthly_watch_04_district_Datong_District = df_04[df_04['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
monthly_watch_04_district_Songshan_District = df_04[df_04['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
monthly_watch_04_district_Shilin_District = df_04[df_04['美食所在區域'] == "士林區"]['觀看人數'].to_frame()
monthly_watch_04_district_Linkou_District = df_04[df_04['美食所在區域'] == "林口區"]['觀看人數'].to_frame()
monthly_watch_04_district_Yonghe_District = df_04[df_04['美食所在區域'] == "永和區"]['觀看人數'].to_frame()
monthly_watch_04_district_Banqiao_District = df_04[df_04['美食所在區域'] == "板橋區"]['觀看人數'].to_frame()

monthly_watch_05_district_Zhongshan_Area = df_05[df_05['美食所在區域'] == "中山區"]['觀看人數'].to_frame()
monthly_watch_05_district_Daan_District = df_05[df_05['美食所在區域'] == "大安區"]['觀看人數'].to_frame()
monthly_watch_05_district_Zhongzheng_District = df_05[df_05['美食所在區域'] == "中正區"]['觀看人數'].to_frame()
monthly_watch_05_district_Songshan_District = df_05[df_05['美食所在區域'] == "松山區"]['觀看人數'].to_frame()
monthly_watch_05_district_Xinyi_District = df_05[df_05['美食所在區域'] == "信義區"]['觀看人數'].to_frame()
monthly_watch_05_district_Datong_District = df_05[df_05['美食所在區域'] == "大同區"]['觀看人數'].to_frame()
monthly_watch_05_district_Xindian_District = df_05[df_05['美食所在區域'] == "新店區"]['觀看人數'].to_frame()
monthly_watch_05_district_Wanhua_District = df_05[df_05['美食所在區域'] == "萬華區"]['觀看人數'].to_frame()

####################將同一區域的所有觀看人數整合起來####################
monthly_watch_district_Zhongzheng_District = pd.concat([monthly_watch_03_district_Zhongzheng_District,monthly_watch_04_district_Zhongzheng_District,monthly_watch_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'觀看人數':'Zhongzheng_District'})
monthly_watch_district_Daan_District = pd.concat([monthly_watch_03_district_Daan_District,monthly_watch_04_district_Daan_District,monthly_watch_05_district_Daan_District],ignore_index=True).rename(columns={'觀看人數':'Daan_District'})
monthly_watch_district_Songshan_District = pd.concat([monthly_watch_03_district_Songshan_District,monthly_watch_04_district_Songshan_District,monthly_watch_05_district_Songshan_District],ignore_index=True).rename(columns={'觀看人數':'Songshan_District'})
monthly_watch_district_Zhongshan_Area = pd.concat([monthly_watch_03_district_Zhongshan_Area,monthly_watch_04_district_Zhongshan_Area,monthly_watch_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'觀看人數':'Zhongshan_Area'})
monthly_watch_district_Yonghe_District = pd.concat([monthly_watch_04_district_Yonghe_District],ignore_index=True).rename(columns={'觀看人數':'Yonghe_District'})
monthly_watch_district_Datong_District = pd.concat([monthly_watch_04_district_Datong_District,monthly_watch_05_district_Datong_District],ignore_index=True).rename(columns={'觀看人數':'Datong_District'})
monthly_watch_district_Linkou_District = pd.concat([monthly_watch_04_district_Linkou_District],ignore_index=True).rename(columns={'觀看人數':'Linkou_District'})
monthly_watch_district_Nangang_District = pd.concat([monthly_watch_03_district_Nangang_District],ignore_index=True).rename(columns={'觀看人數':'Nangang_District'})
monthly_watch_district_Xinyi_District = pd.concat([monthly_watch_03_district_Xinyi_District,monthly_watch_05_district_Xinyi_District],ignore_index=True).rename(columns={'觀看人數':'Xinyi_District'})
monthly_watch_district_Shilin_District = pd.concat([monthly_watch_04_district_Shilin_District],ignore_index=True).rename(columns={'觀看人數':'Shilin_District'})
monthly_watch_district_Wanhua_District = pd.concat([monthly_watch_03_district_Wanhua_District,monthly_watch_05_district_Wanhua_District],ignore_index=True).rename(columns={'觀看人數':'Wanhua_District'})
monthly_watch_district_Banqiao_District = pd.concat([monthly_watch_04_district_Banqiao_District],ignore_index=True).rename(columns={'觀看人數':'Banqiao_District'})
monthly_watch_district_Xindian_District = pd.concat([monthly_watch_05_district_Xindian_District],ignore_index=True).rename(columns={'觀看人數':'Xindian_District'})

data = [monthly_watch_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_watch_district_Daan_District['Daan_District'].astype("float64").values,monthly_watch_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_watch_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_watch_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_watch_district_Datong_District['Datong_District'].astype("float64").values,monthly_watch_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_watch_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_watch_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_watch_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_watch_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_watch_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_watch_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每月各區域的美食觀看人數')
plt.title('District monthly watch')
plt.xlabel('district')
plt.ylabel('watch')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District monthly watch')
plt.xlabel('district')
plt.ylabel('watch')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每月各區域的收藏人數####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有收藏人數####################
monthly_collection_03_district_Zhongshan_Area = df_03[df_03['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
monthly_collection_03_district_Daan_District = df_03[df_03['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
monthly_collection_03_district_Zhongzheng_District = df_03[df_03['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
monthly_collection_03_district_Wanhua_District = df_03[df_03['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()
monthly_collection_03_district_Songshan_District = df_03[df_03['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
monthly_collection_03_district_Nangang_District = df_03[df_03['美食所在區域'] == "南港區"]['收藏人數'].to_frame()
monthly_collection_03_district_Xinyi_District = df_03[df_03['美食所在區域'] == "信義區"]['收藏人數'].to_frame()

monthly_collection_04_district_Zhongshan_Area = df_04[df_04['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
monthly_collection_04_district_Daan_District = df_04[df_04['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
monthly_collection_04_district_Zhongzheng_District = df_04[df_04['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
monthly_collection_04_district_Datong_District = df_04[df_04['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
monthly_collection_04_district_Songshan_District = df_04[df_04['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
monthly_collection_04_district_Shilin_District = df_04[df_04['美食所在區域'] == "士林區"]['收藏人數'].to_frame()
monthly_collection_04_district_Linkou_District = df_04[df_04['美食所在區域'] == "林口區"]['收藏人數'].to_frame()
monthly_collection_04_district_Yonghe_District = df_04[df_04['美食所在區域'] == "永和區"]['收藏人數'].to_frame()
monthly_collection_04_district_Banqiao_District = df_04[df_04['美食所在區域'] == "板橋區"]['收藏人數'].to_frame()

monthly_collection_05_district_Zhongshan_Area = df_05[df_05['美食所在區域'] == "中山區"]['收藏人數'].to_frame()
monthly_collection_05_district_Daan_District = df_05[df_05['美食所在區域'] == "大安區"]['收藏人數'].to_frame()
monthly_collection_05_district_Zhongzheng_District = df_05[df_05['美食所在區域'] == "中正區"]['收藏人數'].to_frame()
monthly_collection_05_district_Songshan_District = df_05[df_05['美食所在區域'] == "松山區"]['收藏人數'].to_frame()
monthly_collection_05_district_Xinyi_District = df_05[df_05['美食所在區域'] == "信義區"]['收藏人數'].to_frame()
monthly_collection_05_district_Datong_District = df_05[df_05['美食所在區域'] == "大同區"]['收藏人數'].to_frame()
monthly_collection_05_district_Xindian_District = df_05[df_05['美食所在區域'] == "新店區"]['收藏人數'].to_frame()
monthly_collection_05_district_Wanhua_District = df_05[df_05['美食所在區域'] == "萬華區"]['收藏人數'].to_frame()

####################將同一區域的所有收藏人數整合起來####################
monthly_collection_district_Zhongzheng_District = pd.concat([monthly_collection_03_district_Zhongzheng_District,monthly_collection_04_district_Zhongzheng_District,monthly_collection_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'收藏人數':'Zhongzheng_District'})
monthly_collection_district_Daan_District = pd.concat([monthly_collection_03_district_Daan_District,monthly_collection_04_district_Daan_District,monthly_collection_05_district_Daan_District],ignore_index=True).rename(columns={'收藏人數':'Daan_District'})
monthly_collection_district_Songshan_District = pd.concat([monthly_collection_03_district_Songshan_District,monthly_collection_04_district_Songshan_District,monthly_collection_05_district_Songshan_District],ignore_index=True).rename(columns={'收藏人數':'Songshan_District'})
monthly_collection_district_Zhongshan_Area = pd.concat([monthly_collection_03_district_Zhongshan_Area,monthly_collection_04_district_Zhongshan_Area,monthly_collection_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'收藏人數':'Zhongshan_Area'})
monthly_collection_district_Yonghe_District = pd.concat([monthly_collection_04_district_Yonghe_District],ignore_index=True).rename(columns={'收藏人數':'Yonghe_District'})
monthly_collection_district_Datong_District = pd.concat([monthly_collection_04_district_Datong_District,monthly_collection_05_district_Datong_District],ignore_index=True).rename(columns={'收藏人數':'Datong_District'})
monthly_collection_district_Linkou_District = pd.concat([monthly_collection_04_district_Linkou_District],ignore_index=True).rename(columns={'收藏人數':'Linkou_District'})
monthly_collection_district_Nangang_District = pd.concat([monthly_collection_03_district_Nangang_District],ignore_index=True).rename(columns={'收藏人數':'Nangang_District'})
monthly_collection_district_Xinyi_District = pd.concat([monthly_collection_03_district_Xinyi_District,monthly_collection_05_district_Xinyi_District],ignore_index=True).rename(columns={'收藏人數':'Xinyi_District'})
monthly_collection_district_Shilin_District = pd.concat([monthly_collection_04_district_Shilin_District],ignore_index=True).rename(columns={'收藏人數':'Shilin_District'})
monthly_collection_district_Wanhua_District = pd.concat([monthly_collection_03_district_Wanhua_District,monthly_collection_05_district_Wanhua_District],ignore_index=True).rename(columns={'收藏人數':'Wanhua_District'})
monthly_collection_district_Banqiao_District = pd.concat([monthly_collection_04_district_Banqiao_District],ignore_index=True).rename(columns={'收藏人數':'Banqiao_District'})
monthly_collection_district_Xindian_District = pd.concat([monthly_collection_05_district_Xindian_District],ignore_index=True).rename(columns={'收藏人數':'Xindian_District'})

data = [monthly_collection_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_collection_district_Daan_District['Daan_District'].astype("float64").values,monthly_collection_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_collection_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_collection_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_collection_district_Datong_District['Datong_District'].astype("float64").values,monthly_collection_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_collection_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_collection_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_collection_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_collection_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_collection_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_collection_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每月各區域的美食收藏人數')
plt.title('District monthly collection')
plt.xlabel('district')
plt.ylabel('collection')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District monthly collection')
plt.xlabel('district')
plt.ylabel('collection')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每月各區域的推薦人數####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有推薦人數####################
monthly_recommend_03_district_Zhongshan_Area = df_03[df_03['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
monthly_recommend_03_district_Daan_District = df_03[df_03['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
monthly_recommend_03_district_Zhongzheng_District = df_03[df_03['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
monthly_recommend_03_district_Wanhua_District = df_03[df_03['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()
monthly_recommend_03_district_Songshan_District = df_03[df_03['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
monthly_recommend_03_district_Nangang_District = df_03[df_03['美食所在區域'] == "南港區"]['推薦人數'].to_frame()
monthly_recommend_03_district_Xinyi_District = df_03[df_03['美食所在區域'] == "信義區"]['推薦人數'].to_frame()

monthly_recommend_04_district_Zhongshan_Area = df_04[df_04['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Daan_District = df_04[df_04['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Zhongzheng_District = df_04[df_04['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Datong_District = df_04[df_04['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Songshan_District = df_04[df_04['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Shilin_District = df_04[df_04['美食所在區域'] == "士林區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Linkou_District = df_04[df_04['美食所在區域'] == "林口區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Yonghe_District = df_04[df_04['美食所在區域'] == "永和區"]['推薦人數'].to_frame()
monthly_recommend_04_district_Banqiao_District = df_04[df_04['美食所在區域'] == "板橋區"]['推薦人數'].to_frame()

monthly_recommend_05_district_Zhongshan_Area = df_05[df_05['美食所在區域'] == "中山區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Daan_District = df_05[df_05['美食所在區域'] == "大安區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Zhongzheng_District = df_05[df_05['美食所在區域'] == "中正區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Songshan_District = df_05[df_05['美食所在區域'] == "松山區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Xinyi_District = df_05[df_05['美食所在區域'] == "信義區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Datong_District = df_05[df_05['美食所在區域'] == "大同區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Xindian_District = df_05[df_05['美食所在區域'] == "新店區"]['推薦人數'].to_frame()
monthly_recommend_05_district_Wanhua_District = df_05[df_05['美食所在區域'] == "萬華區"]['推薦人數'].to_frame()

####################將同一區域的所有推薦人數整合起來####################
monthly_recommend_district_Zhongzheng_District = pd.concat([monthly_recommend_03_district_Zhongzheng_District,monthly_recommend_04_district_Zhongzheng_District,monthly_recommend_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'推薦人數':'Zhongzheng_District'})
monthly_recommend_district_Daan_District = pd.concat([monthly_recommend_03_district_Daan_District,monthly_recommend_04_district_Daan_District,monthly_recommend_05_district_Daan_District],ignore_index=True).rename(columns={'推薦人數':'Daan_District'})
monthly_recommend_district_Songshan_District = pd.concat([monthly_recommend_03_district_Songshan_District,monthly_recommend_04_district_Songshan_District,monthly_recommend_05_district_Songshan_District],ignore_index=True).rename(columns={'推薦人數':'Songshan_District'})
monthly_recommend_district_Zhongshan_Area = pd.concat([monthly_recommend_03_district_Zhongshan_Area,monthly_recommend_04_district_Zhongshan_Area,monthly_recommend_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'推薦人數':'Zhongshan_Area'})
monthly_recommend_district_Yonghe_District = pd.concat([monthly_recommend_04_district_Yonghe_District],ignore_index=True).rename(columns={'推薦人數':'Yonghe_District'})
monthly_recommend_district_Datong_District = pd.concat([monthly_recommend_04_district_Datong_District,monthly_recommend_05_district_Datong_District],ignore_index=True).rename(columns={'推薦人數':'Datong_District'})
monthly_recommend_district_Linkou_District = pd.concat([monthly_recommend_04_district_Linkou_District],ignore_index=True).rename(columns={'推薦人數':'Linkou_District'})
monthly_recommend_district_Nangang_District = pd.concat([monthly_recommend_03_district_Nangang_District],ignore_index=True).rename(columns={'推薦人數':'Nangang_District'})
monthly_recommend_district_Xinyi_District = pd.concat([monthly_recommend_03_district_Xinyi_District,monthly_recommend_05_district_Xinyi_District],ignore_index=True).rename(columns={'推薦人數':'Xinyi_District'})
monthly_recommend_district_Shilin_District = pd.concat([monthly_recommend_04_district_Shilin_District],ignore_index=True).rename(columns={'推薦人數':'Shilin_District'})
monthly_recommend_district_Wanhua_District = pd.concat([monthly_recommend_03_district_Wanhua_District,monthly_recommend_05_district_Wanhua_District],ignore_index=True).rename(columns={'推薦人數':'Wanhua_District'})
monthly_recommend_district_Banqiao_District = pd.concat([monthly_recommend_04_district_Banqiao_District],ignore_index=True).rename(columns={'推薦人數':'Banqiao_District'})
monthly_recommend_district_Xindian_District = pd.concat([monthly_recommend_05_district_Xindian_District],ignore_index=True).rename(columns={'推薦人數':'Xindian_District'})

data = [monthly_recommend_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_recommend_district_Daan_District['Daan_District'].astype("float64").values,monthly_recommend_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_recommend_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_recommend_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_recommend_district_Datong_District['Datong_District'].astype("float64").values,monthly_recommend_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_recommend_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_recommend_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_recommend_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_recommend_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_recommend_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_recommend_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每月各區域的美食推薦人數')
plt.title('District monthly recommend')
plt.xlabel('district')
plt.ylabel('recommend')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District monthly recommend')
plt.xlabel('district')
plt.ylabel('recommend')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每月各區域的多少人來過####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有多少人來過####################
monthly_visit_03_district_Zhongshan_Area = df_03[df_03['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
monthly_visit_03_district_Daan_District = df_03[df_03['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
monthly_visit_03_district_Zhongzheng_District = df_03[df_03['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
monthly_visit_03_district_Wanhua_District = df_03[df_03['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()
monthly_visit_03_district_Songshan_District = df_03[df_03['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
monthly_visit_03_district_Nangang_District = df_03[df_03['美食所在區域'] == "南港區"]['多少人來過'].to_frame()
monthly_visit_03_district_Xinyi_District = df_03[df_03['美食所在區域'] == "信義區"]['多少人來過'].to_frame()

monthly_visit_04_district_Zhongshan_Area = df_04[df_04['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
monthly_visit_04_district_Daan_District = df_04[df_04['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
monthly_visit_04_district_Zhongzheng_District = df_04[df_04['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
monthly_visit_04_district_Datong_District = df_04[df_04['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
monthly_visit_04_district_Songshan_District = df_04[df_04['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
monthly_visit_04_district_Shilin_District = df_04[df_04['美食所在區域'] == "士林區"]['多少人來過'].to_frame()
monthly_visit_04_district_Linkou_District = df_04[df_04['美食所在區域'] == "林口區"]['多少人來過'].to_frame()
monthly_visit_04_district_Yonghe_District = df_04[df_04['美食所在區域'] == "永和區"]['多少人來過'].to_frame()
monthly_visit_04_district_Banqiao_District = df_04[df_04['美食所在區域'] == "板橋區"]['多少人來過'].to_frame()

monthly_visit_05_district_Zhongshan_Area = df_05[df_05['美食所在區域'] == "中山區"]['多少人來過'].to_frame()
monthly_visit_05_district_Daan_District = df_05[df_05['美食所在區域'] == "大安區"]['多少人來過'].to_frame()
monthly_visit_05_district_Zhongzheng_District = df_05[df_05['美食所在區域'] == "中正區"]['多少人來過'].to_frame()
monthly_visit_05_district_Songshan_District = df_05[df_05['美食所在區域'] == "松山區"]['多少人來過'].to_frame()
monthly_visit_05_district_Xinyi_District = df_05[df_05['美食所在區域'] == "信義區"]['多少人來過'].to_frame()
monthly_visit_05_district_Datong_District = df_05[df_05['美食所在區域'] == "大同區"]['多少人來過'].to_frame()
monthly_visit_05_district_Xindian_District = df_05[df_05['美食所在區域'] == "新店區"]['多少人來過'].to_frame()
monthly_visit_05_district_Wanhua_District = df_05[df_05['美食所在區域'] == "萬華區"]['多少人來過'].to_frame()

####################將同一區域的所有多少人來過整合起來####################
monthly_visit_district_Zhongzheng_District = pd.concat([monthly_visit_03_district_Zhongzheng_District,monthly_visit_04_district_Zhongzheng_District,monthly_visit_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'多少人來過':'Zhongzheng_District'})
monthly_visit_district_Daan_District = pd.concat([monthly_visit_03_district_Daan_District,monthly_visit_04_district_Daan_District,monthly_visit_05_district_Daan_District],ignore_index=True).rename(columns={'多少人來過':'Daan_District'})
monthly_visit_district_Songshan_District = pd.concat([monthly_visit_03_district_Songshan_District,monthly_visit_04_district_Songshan_District,monthly_visit_05_district_Songshan_District],ignore_index=True).rename(columns={'多少人來過':'Songshan_District'})
monthly_visit_district_Zhongshan_Area = pd.concat([monthly_visit_03_district_Zhongshan_Area,monthly_visit_04_district_Zhongshan_Area,monthly_visit_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'多少人來過':'Zhongshan_Area'})
monthly_visit_district_Yonghe_District = pd.concat([monthly_visit_04_district_Yonghe_District],ignore_index=True).rename(columns={'多少人來過':'Yonghe_District'})
monthly_visit_district_Datong_District = pd.concat([monthly_visit_04_district_Datong_District,monthly_visit_05_district_Datong_District],ignore_index=True).rename(columns={'多少人來過':'Datong_District'})
monthly_visit_district_Linkou_District = pd.concat([monthly_visit_04_district_Linkou_District],ignore_index=True).rename(columns={'多少人來過':'Linkou_District'})
monthly_visit_district_Nangang_District = pd.concat([monthly_visit_03_district_Nangang_District],ignore_index=True).rename(columns={'多少人來過':'Nangang_District'})
monthly_visit_district_Xinyi_District = pd.concat([monthly_visit_03_district_Xinyi_District,monthly_visit_05_district_Xinyi_District],ignore_index=True).rename(columns={'多少人來過':'Xinyi_District'})
monthly_visit_district_Shilin_District = pd.concat([monthly_visit_04_district_Shilin_District],ignore_index=True).rename(columns={'多少人來過':'Shilin_District'})
monthly_visit_district_Wanhua_District = pd.concat([monthly_visit_03_district_Wanhua_District,monthly_visit_05_district_Wanhua_District],ignore_index=True).rename(columns={'多少人來過':'Wanhua_District'})
monthly_visit_district_Banqiao_District = pd.concat([monthly_visit_04_district_Banqiao_District],ignore_index=True).rename(columns={'多少人來過':'Banqiao_District'})
monthly_visit_district_Xindian_District = pd.concat([monthly_visit_05_district_Xindian_District],ignore_index=True).rename(columns={'多少人來過':'Xindian_District'})

data = [monthly_visit_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_visit_district_Daan_District['Daan_District'].astype("float64").values,monthly_visit_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_visit_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_visit_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_visit_district_Datong_District['Datong_District'].astype("float64").values,monthly_visit_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_visit_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_visit_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_visit_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_visit_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_visit_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_visit_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每月各區域的美食多少人來過')
plt.title('District monthly visit')
plt.xlabel('district')
plt.ylabel('visit')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District monthly visit')
plt.xlabel('district')
plt.ylabel('visit')
plt.show()

# %%
####################視覺化圖表####################
####################整體：每月各區域的多少篇食記####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有多少篇食記####################
monthly_foodrecord_03_district_Zhongshan_Area = df_03[df_03['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
monthly_foodrecord_03_district_Daan_District = df_03[df_03['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
monthly_foodrecord_03_district_Zhongzheng_District = df_03[df_03['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
monthly_foodrecord_03_district_Wanhua_District = df_03[df_03['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()
monthly_foodrecord_03_district_Songshan_District = df_03[df_03['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
monthly_foodrecord_03_district_Nangang_District = df_03[df_03['美食所在區域'] == "南港區"]['多少篇食記'].to_frame()
monthly_foodrecord_03_district_Xinyi_District = df_03[df_03['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()

monthly_foodrecord_04_district_Zhongshan_Area = df_04[df_04['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Daan_District = df_04[df_04['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Zhongzheng_District = df_04[df_04['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Datong_District = df_04[df_04['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Songshan_District = df_04[df_04['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Shilin_District = df_04[df_04['美食所在區域'] == "士林區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Linkou_District = df_04[df_04['美食所在區域'] == "林口區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Yonghe_District = df_04[df_04['美食所在區域'] == "永和區"]['多少篇食記'].to_frame()
monthly_foodrecord_04_district_Banqiao_District = df_04[df_04['美食所在區域'] == "板橋區"]['多少篇食記'].to_frame()

monthly_foodrecord_05_district_Zhongshan_Area = df_05[df_05['美食所在區域'] == "中山區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Daan_District = df_05[df_05['美食所在區域'] == "大安區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Zhongzheng_District = df_05[df_05['美食所在區域'] == "中正區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Songshan_District = df_05[df_05['美食所在區域'] == "松山區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Xinyi_District = df_05[df_05['美食所在區域'] == "信義區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Datong_District = df_05[df_05['美食所在區域'] == "大同區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Xindian_District = df_05[df_05['美食所在區域'] == "新店區"]['多少篇食記'].to_frame()
monthly_foodrecord_05_district_Wanhua_District = df_05[df_05['美食所在區域'] == "萬華區"]['多少篇食記'].to_frame()

####################將同一區域的所有多少篇食記整合起來####################
monthly_foodrecord_district_Zhongzheng_District = pd.concat([monthly_foodrecord_03_district_Zhongzheng_District,monthly_foodrecord_04_district_Zhongzheng_District,monthly_foodrecord_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'多少篇食記':'Zhongzheng_District'})
monthly_foodrecord_district_Daan_District = pd.concat([monthly_foodrecord_03_district_Daan_District,monthly_foodrecord_04_district_Daan_District,monthly_foodrecord_05_district_Daan_District],ignore_index=True).rename(columns={'多少篇食記':'Daan_District'})
monthly_foodrecord_district_Songshan_District = pd.concat([monthly_foodrecord_03_district_Songshan_District,monthly_foodrecord_04_district_Songshan_District,monthly_foodrecord_05_district_Songshan_District],ignore_index=True).rename(columns={'多少篇食記':'Songshan_District'})
monthly_foodrecord_district_Zhongshan_Area = pd.concat([monthly_foodrecord_03_district_Zhongshan_Area,monthly_foodrecord_04_district_Zhongshan_Area,monthly_foodrecord_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'多少篇食記':'Zhongshan_Area'})
monthly_foodrecord_district_Yonghe_District = pd.concat([monthly_foodrecord_04_district_Yonghe_District],ignore_index=True).rename(columns={'多少篇食記':'Yonghe_District'})
monthly_foodrecord_district_Datong_District = pd.concat([monthly_foodrecord_04_district_Datong_District,monthly_foodrecord_05_district_Datong_District],ignore_index=True).rename(columns={'多少篇食記':'Datong_District'})
monthly_foodrecord_district_Linkou_District = pd.concat([monthly_foodrecord_04_district_Linkou_District],ignore_index=True).rename(columns={'多少篇食記':'Linkou_District'})
monthly_foodrecord_district_Nangang_District = pd.concat([monthly_foodrecord_03_district_Nangang_District],ignore_index=True).rename(columns={'多少篇食記':'Nangang_District'})
monthly_foodrecord_district_Xinyi_District = pd.concat([monthly_foodrecord_03_district_Xinyi_District,monthly_foodrecord_05_district_Xinyi_District],ignore_index=True).rename(columns={'多少篇食記':'Xinyi_District'})
monthly_foodrecord_district_Shilin_District = pd.concat([monthly_foodrecord_04_district_Shilin_District],ignore_index=True).rename(columns={'多少篇食記':'Shilin_District'})
monthly_foodrecord_district_Wanhua_District = pd.concat([monthly_foodrecord_03_district_Wanhua_District,monthly_foodrecord_05_district_Wanhua_District],ignore_index=True).rename(columns={'多少篇食記':'Wanhua_District'})
monthly_foodrecord_district_Banqiao_District = pd.concat([monthly_foodrecord_04_district_Banqiao_District],ignore_index=True).rename(columns={'多少篇食記':'Banqiao_District'})
monthly_foodrecord_district_Xindian_District = pd.concat([monthly_foodrecord_05_district_Xindian_District],ignore_index=True).rename(columns={'多少篇食記':'Xindian_District'})

data = [monthly_foodrecord_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_foodrecord_district_Daan_District['Daan_District'].astype("float64").values,monthly_foodrecord_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_foodrecord_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_foodrecord_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_foodrecord_district_Datong_District['Datong_District'].astype("float64").values,monthly_foodrecord_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_foodrecord_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_foodrecord_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_foodrecord_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_foodrecord_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_foodrecord_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_foodrecord_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.xticks(rotation=60)
#plt.title('每月各區域的美食多少篇食記')
plt.title('District monthly foodrecord')
plt.xlabel('district')
plt.ylabel('foodrecord')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('District monthly foodrecord')
plt.xlabel('district')
plt.ylabel('foodrecord')
plt.show()

# %% [markdown]
# # 每週各區域曾經出現的排名(某一區所有的餐廳分別出現在第幾名的紀錄)：

# %%
#將獲得的index值+1轉化成排名
def index_to_ranking(x):
    return x+1

# %%
####################視覺化圖表####################
####################細節：每週各區域曾經出現的排名####################

#print(df_0331_0406['美食所在區域'].value_counts())
#print(df_0407_0413['美食所在區域'].value_counts())
#print(df_0414_0420['美食所在區域'].value_counts())
#print(df_0421_0427['美食所在區域'].value_counts())
#print(df_0428_0504['美食所在區域'].value_counts())
##print(df_0505_0511['美食所在區域'].value_counts())
##print(df_0512_0518['美食所在區域'].value_counts())
##print(df_0519_0525['美食所在區域'].value_counts())
##print(df_0526_0601['美食所在區域'].value_counts())

####################取出同一區域所有名次####################
weekly_rating_0331_0406_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Yonghe_District = pd.DataFrame({'Yonghe_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "永和區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0331_0406_district_Banqiao_District = pd.DataFrame({'Banqiao_District':list(map(index_to_ranking,df_0331_0406[df_0331_0406['美食所在區域'] == "板橋區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0407_0413_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Triple_area = pd.DataFrame({'Triple_area':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "三重區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Yonghe_District = pd.DataFrame({'Yonghe_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "永和區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Tucheng_District = pd.DataFrame({'Tucheng_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "土城區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0407_0413_district_Banqiao_District = pd.DataFrame({'Banqiao_District':list(map(index_to_ranking,df_0407_0413[df_0407_0413['美食所在區域'] == "板橋區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0414_0420_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0414_0420_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0414_0420_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0414_0420_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0414_0420_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0414_0420_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0414_0420_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0414_0420[df_0414_0420['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0421_0427_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Neihu_District = pd.DataFrame({'Neihu_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Linkou_District = pd.DataFrame({'Linkou_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0421_0427_district_Wenshan_District = pd.DataFrame({'Wenshan_District':list(map(index_to_ranking,df_0421_0427[df_0421_0427['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0428_0504_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Taishan_District = pd.DataFrame({'Taishan_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "泰山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0428_0504_district_Wenshan_District = pd.DataFrame({'Wenshan_District':list(map(index_to_ranking,df_0428_0504[df_0428_0504['美食所在區域'] == "文山區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0505_0511_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Yonghe_District = pd.DataFrame({'Yonghe_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "永和區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Triple_area = pd.DataFrame({'Triple_area':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "三重區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0505_0511_district_Neihu_District = pd.DataFrame({'Neihu_District':list(map(index_to_ranking,df_0505_0511[df_0505_0511['美食所在區域'] == "內湖區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0512_0518_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Triple_area = pd.DataFrame({'Triple_area':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "三重區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Xindian_District = pd.DataFrame({'Xindian_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "新店區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Linkou_District = pd.DataFrame({'Linkou_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "林口區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0512_0518_district_Yonghe_District = pd.DataFrame({'Yonghe_District':list(map(index_to_ranking,df_0512_0518[df_0512_0518['美食所在區域'] == "永和區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0519_0525_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Banqiao_District = pd.DataFrame({'Banqiao_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "板橋區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Triple_area = pd.DataFrame({'Triple_area':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "三重區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0519_0525_district_Zhonghe_District = pd.DataFrame({'Zhonghe_District':list(map(index_to_ranking,df_0519_0525[df_0519_0525['美食所在區域'] == "中和區"]['評級'].to_frame().index.tolist()))})

weekly_rating_0526_0601_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Banqiao_District = pd.DataFrame({'Banqiao_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "板橋區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
weekly_rating_0526_0601_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_0526_0601[df_0526_0601['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})

###################將同一區域的所有名次整合起來####################
weekly_rating_district_Zhongzheng_District = pd.concat([weekly_rating_0331_0406_district_Zhongzheng_District,weekly_rating_0407_0413_district_Zhongzheng_District,weekly_rating_0414_0420_district_Zhongzheng_District,weekly_rating_0421_0427_district_Zhongzheng_District,weekly_rating_0428_0504_district_Zhongzheng_District,weekly_rating_0505_0511_district_Zhongzheng_District,weekly_rating_0512_0518_district_Zhongzheng_District,weekly_rating_0519_0525_district_Zhongzheng_District,weekly_rating_0526_0601_district_Zhongzheng_District],ignore_index=True).rename(columns={'評級':'Zhongzheng_District'})
weekly_rating_district_Shilin_District = pd.concat([weekly_rating_0331_0406_district_Shilin_District,weekly_rating_0407_0413_district_Shilin_District,weekly_rating_0414_0420_district_Shilin_District,weekly_rating_0421_0427_district_Shilin_District,weekly_rating_0428_0504_district_Shilin_District,weekly_rating_0512_0518_district_Shilin_District,weekly_rating_0526_0601_district_Shilin_District],ignore_index=True).rename(columns={'評級':'Shilin_District'})
weekly_rating_district_Zhongshan_Area = pd.concat([weekly_rating_0331_0406_district_Zhongshan_Area,weekly_rating_0407_0413_district_Zhongshan_Area,weekly_rating_0414_0420_district_Zhongshan_Area,weekly_rating_0421_0427_district_Zhongshan_Area,weekly_rating_0428_0504_district_Zhongshan_Area,weekly_rating_0505_0511_district_Zhongshan_Area,weekly_rating_0512_0518_district_Zhongshan_Area,weekly_rating_0519_0525_district_Zhongshan_Area,weekly_rating_0526_0601_district_Zhongshan_Area],ignore_index=True).rename(columns={'評級':'Zhongshan_Area'})
weekly_rating_district_Datong_District = pd.concat([weekly_rating_0331_0406_district_Datong_District,weekly_rating_0407_0413_district_Datong_District,weekly_rating_0414_0420_district_Datong_District,weekly_rating_0421_0427_district_Datong_District,weekly_rating_0428_0504_district_Datong_District,weekly_rating_0505_0511_district_Datong_District,weekly_rating_0519_0525_district_Datong_District,weekly_rating_0526_0601_district_Datong_District],ignore_index=True).rename(columns={'評級':'Datong_District'})
weekly_rating_district_Daan_District = pd.concat([weekly_rating_0331_0406_district_Daan_District,weekly_rating_0407_0413_district_Daan_District,weekly_rating_0414_0420_district_Daan_District,weekly_rating_0421_0427_district_Daan_District,weekly_rating_0428_0504_district_Daan_District,weekly_rating_0505_0511_district_Daan_District,weekly_rating_0512_0518_district_Daan_District,weekly_rating_0519_0525_district_Daan_District,weekly_rating_0526_0601_district_Daan_District],ignore_index=True).rename(columns={'評級':'Daan_District'})
weekly_rating_district_Songshan_District = pd.concat([weekly_rating_0331_0406_district_Songshan_District,weekly_rating_0414_0420_district_Songshan_District,weekly_rating_0421_0427_district_Songshan_District,weekly_rating_0428_0504_district_Songshan_District,weekly_rating_0505_0511_district_Songshan_District,weekly_rating_0519_0525_district_Songshan_District,weekly_rating_0526_0601_district_Songshan_District],ignore_index=True).rename(columns={'評級':'Songshan_District'})
weekly_rating_district_Wanhua_District = pd.concat([weekly_rating_0407_0413_district_Wanhua_District,weekly_rating_0414_0420_district_Wanhua_District,weekly_rating_0421_0427_district_Wanhua_District,weekly_rating_0505_0511_district_Wanhua_District,weekly_rating_0519_0525_district_Wanhua_District,weekly_rating_0526_0601_district_Wanhua_District],ignore_index=True).rename(columns={'評級':'Wanhua_District'})
weekly_rating_district_Xinyi_District = pd.concat([weekly_rating_0407_0413_district_Xinyi_District,weekly_rating_0428_0504_district_Xinyi_District,weekly_rating_0505_0511_district_Xinyi_District,weekly_rating_0512_0518_district_Xinyi_District,weekly_rating_0519_0525_district_Xinyi_District,weekly_rating_0526_0601_district_Xinyi_District],ignore_index=True).rename(columns={'評級':'Xinyi_District'})
weekly_rating_district_Yonghe_District = pd.concat([weekly_rating_0331_0406_district_Yonghe_District,weekly_rating_0407_0413_district_Yonghe_District,weekly_rating_0505_0511_district_Yonghe_District,weekly_rating_0512_0518_district_Yonghe_District],ignore_index=True).rename(columns={'評級':'Yonghe_District'})
weekly_rating_district_Wenshan_District = pd.concat([weekly_rating_0421_0427_district_Wenshan_District,weekly_rating_0428_0504_district_Wenshan_District],ignore_index=True).rename(columns={'評級':'Wenshan_District'})
weekly_rating_district_Banqiao_District = pd.concat([weekly_rating_0331_0406_district_Banqiao_District,weekly_rating_0407_0413_district_Banqiao_District,weekly_rating_0519_0525_district_Banqiao_District,weekly_rating_0526_0601_district_Banqiao_District],ignore_index=True).rename(columns={'評級':'Banqiao_District'})
weekly_rating_district_Neihu_District = pd.concat([weekly_rating_0421_0427_district_Neihu_District,weekly_rating_0505_0511_district_Neihu_District],ignore_index=True).rename(columns={'評級':'Neihu_District'})
weekly_rating_district_Triple_area = pd.concat([weekly_rating_0407_0413_district_Triple_area,weekly_rating_0505_0511_district_Triple_area,weekly_rating_0512_0518_district_Triple_area,weekly_rating_0519_0525_district_Triple_area],ignore_index=True).rename(columns={'評級':'Triple_area'})
weekly_rating_district_Tucheng_District = pd.concat([weekly_rating_0407_0413_district_Tucheng_District],ignore_index=True).rename(columns={'評級':'Tucheng_District'})
weekly_rating_district_Taishan_District = pd.concat([weekly_rating_0428_0504_district_Taishan_District],ignore_index=True).rename(columns={'評級':'Taishan_District'})
weekly_rating_district_Linkou_District = pd.concat([weekly_rating_0421_0427_district_Linkou_District,weekly_rating_0512_0518_district_Linkou_District],ignore_index=True).rename(columns={'評級':'Linkou_District'})
weekly_rating_district_Xindian_District = pd.concat([weekly_rating_0512_0518_district_Xindian_District],ignore_index=True).rename(columns={'評級':'Xindian_District'})
weekly_rating_district_Zhonghe_District = pd.concat([weekly_rating_0519_0525_district_Zhonghe_District],ignore_index=True).rename(columns={'評級':'Zhonghe_District'})

data = [weekly_rating_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,weekly_rating_district_Shilin_District['Shilin_District'].astype("float64").values,weekly_rating_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,weekly_rating_district_Datong_District['Datong_District'].astype("float64").values,weekly_rating_district_Daan_District['Daan_District'].astype("float64").values,weekly_rating_district_Songshan_District['Songshan_District'].astype("float64").values,weekly_rating_district_Wanhua_District['Wanhua_District'].astype("float64").values,weekly_rating_district_Xinyi_District['Xinyi_District'].astype("float64").values,weekly_rating_district_Yonghe_District['Yonghe_District'].astype("float64").values,weekly_rating_district_Wenshan_District['Wenshan_District'].astype("float64").values,weekly_rating_district_Banqiao_District['Banqiao_District'].astype("float64").values,weekly_rating_district_Neihu_District['Neihu_District'].astype("float64").values,weekly_rating_district_Triple_area['Triple_area'].astype("float64").values,weekly_rating_district_Tucheng_District['Tucheng_District'].astype("float64").values,weekly_rating_district_Taishan_District['Taishan_District'].astype("float64").values,weekly_rating_district_Linkou_District['Linkou_District'].astype("float64").values,weekly_rating_district_Xindian_District['Xindian_District'].astype("float64").values,weekly_rating_district_Zhonghe_District['Zhonghe_District'].astype("float64").values]

labels = ['Zhongzheng_District','Shilin_District','Zhongshan_Area','Datong_District','Daan_District','Songshan_District','Wanhua_District','Xinyi_District','Yonghe_District','Wenshan_District','Banqiao_District','Neihu_District','Triple_area','Tucheng_District','Taishan_District','Linkou_District','Xindian_District','Zhonghe_District']


fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.ylim(0,21)
plt.xticks(rotation=60)
plt.yticks(np.arange(0, 21, 1))
#plt.title('各週各區域曾經出現的排名')
plt.title('Ranking for District Weekly')
plt.xlabel('district')
plt.ylabel('ranking')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('Ranking for District Weekly')
plt.xlabel('district')
plt.ylabel('ranking')
plt.show()

'''0331_0406
大安區 Daan_District
中正區 Zhongzheng_District
中山區 Zhongshan_Area
大同區 Datong_District
松山區 Songshan_District
永和區 Yonghe_District
士林區 Shilin_District
板橋區 Banqiao_District
'''
'''0407_0413
士林區 Shilin_District
中山區 Zhongshan_Area
三重區 Triple_area
信義區 Xinyi_District
大安區 Daan_District
萬華區 Wanhua_District
中正區 Zhongzheng_District
大同區 Datong_District
永和區 Yonghe_District
土城區 Tucheng_District
板橋區 Banqiao_District
'''
'''0414_0420
中山區 Zhongshan_Area
大安區 Daan_District
松山區 Songshan_District
士林區 Shilin_District
萬華區 Wanhua_District
大同區 Datong_District
中正區 Zhongzheng_District
'''
'''0421_0427
中山區 Zhongshan_Area
大同區 Datong_District
大安區 Daan_District
中正區 Zhongzheng_District
松山區 Songshan_District
內湖區 Neihu_District
士林區 Shilin_District
萬華區 Wanhua_District
林口區 Linkou_District
文山區 Wenshan_District
'''
'''0428_0504
大安區 Daan_District
中山區 Zhongshan_Area
松山區 Songshan_District
大同區 Datong_District
信義區 Xinyi_District
泰山區 Taishan_District
士林區 Shilin_District
中正區 Zhongzheng_District
文山區 Wenshan_District
'''
'''0505_0511
松山區 Songshan District
中正區 Zhongzheng District
永和區 Yonghe District
萬華區 Wanhua District
信義區 Xinyi District
中山區 Zhongshan Area
大同區 Datong District
三重區 Triple area
大安區 Daan District
內湖區 Neihu District
'''
'''0512_0518
中山區 Zhongshan Area
大安區 Daan District
三重區 Triple area
中正區 Zhongzheng District
信義區 Xinyi District
士林區 Shilin District
新店區 Xindian District
林口區 Linkou District
永和區 Yonghe District
'''
'''0519_0525
中山區 Zhong han_Area
大安區 Daan District
松山區 Songshan District
中正區 Zhongzheng District
板橋區 Banqiao District
三重區 Triple area
萬華區 Wanhua District
大同區 Datong District
信義區 Xinyi District
中和區 Zhonghe District
'''
'''0526_0601
松山區 Songshan District
中正區 Zhongzheng District
士林區 Shilin District
大安區 Daan District
中山區 Zhongshan Area
信義區 Xinyi District
板橋區 Banqiao District
大同區 Datong District
萬華區 Wanhua District
'''
# Out:
# '0526_0601\n松山區 Songshan District\n中正區 Zhongzheng District\n士林區 Shilin District\n大安區 Daan District\n中山區 Zhongshan Area\n信義區 Xinyi District\n板橋區 Banqiao District\n大同區 Datong District\n萬華區 Wanhua District\n'

# %% [markdown]
# # 每月各區域曾經出現的排名(某一區所有的餐廳分別出現在第幾名的紀錄)：

# %%
####################視覺化圖表####################
####################細節：每月各區域曾經出現的排名####################

#print(df_03['美食所在區域'].value_counts())
#print(df_04['美食所在區域'].value_counts())
#print(df_05['美食所在區域'].value_counts())

####################取出同一區域所有名次####################
monthly_rating_03_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
monthly_rating_03_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
monthly_rating_03_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
monthly_rating_03_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})
monthly_rating_03_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
monthly_rating_03_district_Nangang_District = pd.DataFrame({'Nangang_District':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "南港區"]['評級'].to_frame().index.tolist()))})
monthly_rating_03_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_03[df_03['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})

monthly_rating_04_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Shilin_District = pd.DataFrame({'Shilin_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "士林區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Linkou_District = pd.DataFrame({'Linkou_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "林口區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Yonghe_District = pd.DataFrame({'Yonghe_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "永和區"]['評級'].to_frame().index.tolist()))})
monthly_rating_04_district_Banqiao_District = pd.DataFrame({'Banqiao_District':list(map(index_to_ranking,df_04[df_04['美食所在區域'] == "板橋區"]['評級'].to_frame().index.tolist()))})

monthly_rating_05_district_Zhongshan_Area = pd.DataFrame({'Zhongshan_Area':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "中山區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Daan_District = pd.DataFrame({'Daan_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "大安區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Zhongzheng_District = pd.DataFrame({'Zhongzheng_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "中正區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Songshan_District = pd.DataFrame({'Songshan_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "松山區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Xinyi_District = pd.DataFrame({'Xinyi_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "信義區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Datong_District = pd.DataFrame({'Datong_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "大同區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Xindian_District = pd.DataFrame({'Xindian_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "新店區"]['評級'].to_frame().index.tolist()))})
monthly_rating_05_district_Wanhua_District = pd.DataFrame({'Wanhua_District':list(map(index_to_ranking,df_05[df_05['美食所在區域'] == "萬華區"]['評級'].to_frame().index.tolist()))})

####################將同一區域的所有名次整合起來####################
monthly_rating_district_Zhongzheng_District = pd.concat([monthly_rating_03_district_Zhongzheng_District,monthly_rating_04_district_Zhongzheng_District,monthly_rating_05_district_Zhongzheng_District],ignore_index=True).rename(columns={'評級':'Zhongzheng_District'})
monthly_rating_district_Daan_District = pd.concat([monthly_rating_03_district_Daan_District,monthly_rating_04_district_Daan_District,monthly_rating_05_district_Daan_District],ignore_index=True).rename(columns={'評級':'Daan_District'})
monthly_rating_district_Songshan_District = pd.concat([monthly_rating_03_district_Songshan_District,monthly_rating_04_district_Songshan_District,monthly_rating_05_district_Songshan_District],ignore_index=True).rename(columns={'評級':'Songshan_District'})
monthly_rating_district_Zhongshan_Area = pd.concat([monthly_rating_03_district_Zhongshan_Area,monthly_rating_04_district_Zhongshan_Area,monthly_rating_05_district_Zhongshan_Area],ignore_index=True).rename(columns={'評級':'Zhongshan_Area'})
monthly_rating_district_Yonghe_District = pd.concat([monthly_rating_04_district_Yonghe_District],ignore_index=True).rename(columns={'評級':'Yonghe_District'})
monthly_rating_district_Datong_District = pd.concat([monthly_rating_04_district_Datong_District,monthly_rating_05_district_Datong_District],ignore_index=True).rename(columns={'評級':'Datong_District'})
monthly_rating_district_Linkou_District = pd.concat([monthly_rating_04_district_Linkou_District],ignore_index=True).rename(columns={'評級':'Linkou_District'})
monthly_rating_district_Nangang_District = pd.concat([monthly_rating_03_district_Nangang_District],ignore_index=True).rename(columns={'評級':'Nangang_District'})
monthly_rating_district_Xinyi_District = pd.concat([monthly_rating_03_district_Xinyi_District,monthly_rating_05_district_Xinyi_District],ignore_index=True).rename(columns={'評級':'Xinyi_District'})
monthly_rating_district_Shilin_District = pd.concat([monthly_rating_04_district_Shilin_District],ignore_index=True).rename(columns={'評級':'Shilin_District'})
monthly_rating_district_Wanhua_District = pd.concat([monthly_rating_03_district_Wanhua_District,monthly_rating_05_district_Wanhua_District],ignore_index=True).rename(columns={'評級':'Wanhua_District'})
monthly_rating_district_Banqiao_District = pd.concat([monthly_rating_04_district_Banqiao_District],ignore_index=True).rename(columns={'評級':'Banqiao_District'})
monthly_rating_district_Xindian_District = pd.concat([monthly_rating_05_district_Xindian_District],ignore_index=True).rename(columns={'評級':'Xindian_District'})

data = [monthly_rating_district_Zhongzheng_District['Zhongzheng_District'].astype("float64").values,monthly_rating_district_Daan_District['Daan_District'].astype("float64").values,monthly_rating_district_Songshan_District['Songshan_District'].astype("float64").values,monthly_rating_district_Zhongshan_Area['Zhongshan_Area'].astype("float64").values,monthly_rating_district_Yonghe_District['Yonghe_District'].astype("float64").values,monthly_rating_district_Datong_District['Datong_District'].astype("float64").values,monthly_rating_district_Linkou_District['Linkou_District'].astype("float64").values,monthly_rating_district_Nangang_District['Nangang_District'].astype("float64").values,monthly_rating_district_Xinyi_District['Xinyi_District'].astype("float64").values,monthly_rating_district_Shilin_District['Shilin_District'].astype("float64").values,monthly_rating_district_Wanhua_District['Wanhua_District'].astype("float64").values,monthly_rating_district_Banqiao_District['Banqiao_District'].astype("float64").values,monthly_rating_district_Xindian_District['Xindian_District'].astype("float64").values]

labels = ['Zhongzheng_District','Daan_District','Songshan_District','Zhongshan_Area','Yonghe_District','Datong_District','Linkou_District','Nangang_District','Xinyi_District','Shilin_District','Wanhua_District','Banqiao_District','Xindian_District']

fig = plt.figure(figsize=(12,6))
plt.boxplot(data,labels = labels)
plt.ylim(0,21)
plt.xticks(rotation=60)
plt.yticks(np.arange(0, 21, 1))
#plt.title('各月各區域曾經出現的排名')
plt.title('Ranking for District monthly')
plt.xlabel('district')
plt.ylabel('ranking')
fig = plt.figure(figsize=(12,6))
violin = sns.violinplot(data=data)
violin.set_xticklabels(labels = labels,rotation=60)
plt.title('Ranking for District monthly')
plt.xlabel('district')
plt.ylabel('ranking')
plt.show()

'''03
中山區 Zhongshan_Area
大安區 Daan_District
中正區 Zhongzheng_District
萬華區 Wanhua_District
松山區 Songshan_District
南港區 Nangang_District
信義區 Xinyi_District
'''
'''04
中山區 Zhongshan_Area
大安區 Daan_District
中正區 Zhongzheng_District
大同區 Datong_District
松山區 Songshan_District
士林區 Shilin_District
林口區 Linkou_District
永和區 Yonghe_District
板橋區 Banqiao_District
'''
'''05
中山區 Zhongshan Area
大安區 Daan District
中正區 Zhongzheng District
松山區 Songshan District
信義區 Xinyi District
大同區 Datong District
新店區 Xindian District
萬華區 Wanhua District
'''
# Out:
# '05\n中山區 Zhongshan Area\n大安區 Daan District\n中正區 Zhongzheng District\n松山區 Songshan District\n信義區 Xinyi District\n大同區 Datong District\n新店區 Xindian District\n萬華區 Wanhua District\n'

# %%
#print(df_0331_0406['美食所在區域'].value_counts().index)#各區域
#print(df_0331_0406['美食所在區域'].value_counts().index[0])#取各區域第一個
